# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.CodeMirror {font-family:Consolas; font-size:10pt;}
div.output {font-size:10pt;}
div.input {font-family:Consolas; font-size:10pt; font-weight:bold;}
div.prompt {min-width:70px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.CodeMirror {font-family:Consolas; font-size:10pt;}
# div.output {font-size:10pt;}
# div.input {font-family:Consolas; font-size:10pt; font-weight:bold;}
# div.prompt {min-width:70px;}
# </style>

# %% [markdown]
# **<font size='6' color='darkred'>ch02. 한글 형태소 분석</font>**

# %% [markdown]
# # 연관분석 개요
# - 데이터들 사이에서 자주 발생하는 속성을 찾고
#   그 속성들 사이에 어느 정도 연관이 있는지를 분석하는 방법
# - 활용분야: 상품 진열, 사기보험 적발, 카탈로그 디자인, 신상품 카테고리 구성 ....
# - 연관성 분석 관련 지표:
#     - 지지도(support) = 조건 결과 항목 수 / 전체 수
#     - 신뢰도(confidence) = 조건 결과 항목 수 / 조건 항목 수
#     - 향상도(lift) = 조건 결과 지지도 / (조건 지지도) * (결과 지지도)
#                     (1: 상관관계 없음, >1: 양의 상관관계, <1: 음의 상관관계)
#
# <pre>
# [조건] => [결과] 지지도 신뢰도 향상도
# [주스] => [생수]  0.4    1   0.4 / (0.4)*1 =1
# [소주] => [맥주]  0.2   0.233.. 0.833...
# </pre>

# %%
# 트랜잭션 데이터 가져오기 
import csv

transaction = []
with open('data/cf_basket.csv', 'r', encoding='utf-8') as cf:
    csvdata = csv.reader(cf)
    
    # transaction = list(csvdata) 리스트로 형변환 
    for row in csvdata: # 혹은 for문 돌리기
        transaction.append(row)
transaction
# Out:
# [['소주', '콜라', '와인'],
#  ['소주', '오렌지주스', '콜라'],
#  ['콜라', '맥주', '와인'],
#  ['소주', '콜라', '맥주'],
#  ['오렌지주스', '와인']]

# %% [markdown]
# # 연관 분석
#
# ## 연관 규칙 생성

# %%
# pip install apyori
from apyori import apriori # 연관성 규칙 생성 

rules = apriori(transaction,
                min_support=0.2, 
                # 지지도가 0.2 이상일 경우만 연관분석해
                min_confidence=0.1)
rules = list(rules)
len(rules)
# Out:
# 18

# %%
rules[1]
# Out:
# RelationRecord(items=frozenset({'소주'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'소주'}), confidence=0.6, lift=1.0)])

# %%
print('조건 => 결과 \t 지지도 \t 신뢰도 \t 향상도')

for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        # 조건 (left hand side)
        lhs = ', '.join(x for x in item[0])
        lhs = [x for x in item[0]]
        # 결과 (right hand side)
        rhs = ', '.join(x for x in item[1])
        rhs = [x for x in item[1]]
        confidence = item[2]
        lift = item[3]
        
        if lift != 1:
            print(lhs, '=>', rhs, 
                  '\t{:5.3f}\t{:5.3f}\t{:5.3f}'.format(
                      support, confidence, lift))
# Out:
# 조건 => 결과 	 지지도 	 신뢰도 	 향상도
# ['맥주'] => ['소주'] 	0.200	0.500	0.833
# ['소주'] => ['맥주'] 	0.200	0.333	0.833
# ['맥주'] => ['와인'] 	0.200	0.500	0.833
# ['와인'] => ['맥주'] 	0.200	0.333	0.833
# ['맥주'] => ['콜라'] 	0.400	1.000	1.250
# ['콜라'] => ['맥주'] 	0.400	0.500	1.250
# ['소주'] => ['오렌지주스'] 	0.200	0.333	0.833
# ['오렌지주스'] => ['소주'] 	0.200	0.500	0.833
# ['소주'] => ['와인'] 	0.200	0.333	0.556
# ['와인'] => ['소주'] 	0.200	0.333	0.556
# ['소주'] => ['콜라'] 	0.600	1.000	1.250
# ['콜라'] => ['소주'] 	0.600	0.750	1.250
# ['오렌지주스'] => ['와인'] 	0.200	0.500	0.833
# ['와인'] => ['오렌지주스'] 	0.200	0.333	0.833
# ['오렌지주스'] => ['콜라'] 	0.200	0.500	0.625
# ['콜라'] => ['오렌지주스'] 	0.200	0.250	0.625
# ['와인'] => ['콜라'] 	0.400	0.667	0.833
# ['콜라'] => ['와인'] 	0.400	0.500	0.833
# ['맥주'] => ['콜라', '소주'] 	0.200	0.500	0.833
# ['소주'] => ['콜라', '맥주'] 	0.200	0.333	0.833
# ['콜라'] => ['소주', '맥주'] 	0.200	0.250	1.250
# ['소주', '맥주'] => ['콜라'] 	0.200	1.000	1.250
# ['콜라', '맥주'] => ['소주'] 	0.200	0.500	0.833
# ['콜라', '소주'] => ['맥주'] 	0.200	0.333	0.833
# ['맥주'] => ['콜라', '와인'] 	0.200	0.500	1.250
# ['와인'] => ['콜라', '맥주'] 	0.200	0.333	0.833
# ['콜라'] => ['와인', '맥주'] 	0.200	0.250	1.250
# ['와인', '맥주'] => ['콜라'] 	0.200	1.000	1.250
# ['콜라', '맥주'] => ['와인'] 	0.200	0.500	0.833
# ['콜라', '와인'] => ['맥주'] 	0.200	0.500	1.250
# ['소주'] => ['콜라', '오렌지주스'] 	0.200	0.333	1.667
# ['오렌지주스'] => ['콜라', '소주'] 	0.200	0.500	0.833
# ['콜라'] => ['소주', '오렌지주스'] 	0.200	0.250	1.250
# ['소주', '오렌지주스'] => ['콜라'] 	0.200	1.000	1.250
# ['콜라', '소주'] => ['오렌지주스'] 	0.200	0.333	0.833
# ['콜라', '오렌지주스'] => ['소주'] 	0.200	1.000	1.667
# ['소주'] => ['콜라', '와인'] 	0.200	0.333	0.833
# ['와인'] => ['콜라', '소주'] 	0.200	0.333	0.556
# ['콜라'] => ['소주', '와인'] 	0.200	0.250	1.250
# ['소주', '와인'] => ['콜라'] 	0.200	1.000	1.250
# ['콜라', '소주'] => ['와인'] 	0.200	0.333	0.556
# ['콜라', '와인'] => ['소주'] 	0.200	0.500	0.833

# %% [markdown]
# # 뉴스기사 연관 분석 실습
#
# ## 뉴스 RSS를 이용하여 기사 검색 후 연관분석

# %%
import requests 
from bs4 import BeautifulSoup

rss_url = 'https://rss.joins.com/joins_money_list.xml'
money_response = requests.get(rss_url)
money_soup = BeautifulSoup(money_response.content, 'xml')
link_list = money_soup.select('item > link')
# link_list = [l.text for l in link_list]
len(link_list)
# Out:
# 30

# %%
from konlpy.tag import Kkma

kkma = Kkma()
news = []

for link in link_list:
    news_response = requests.get(link.text)
    news_soup = BeautifulSoup(news_response.content, 'html.parser')
    content = news_soup.select_one('div#article_body').text
    nouns_list = list(filter(
        lambda word : len(word)>1, kkma.nouns(content)))
    news.append(nouns_list)
news
# Out:
# [['비트',
#   '비트코',
#   '이미지',
#   '중앙',
#   '중앙포토',
#   '포토',
#   '암호화',
#   '암호화폐',
#   '비트코인',
#   '사상',
#   '처음',
#   '개당',
#   '7500',
#   '7500만원',
#   '업비트',
#   '3일',
#   '오후',
#   '7502',
#   '7502만원',
#   '거래',
#   '기관',
#   '기관투자',
#   '투자',
#   '가세',
#   '연초',
#   '대비',
#   '일부',
#   '투기',
#   '투기자산',
#   '자산',
#   '피해',
#   '비관론',
#   '암호',
#   '화폐',
#   '거래소',
#   '4시',
#   '1비트코인은',
#   '인은',
#   '7502만2000원',
#   '2000',
#   '1.58',
#   '상승',
#   '1비트코',
#   '가격',
#   '이번',
#   '시간',
#   '비트코인은',
#   '7477',
#   '7477만8000원',
#   '8000',
#   '최고가',
#   '기록',
#   '주식',
#   '주식시장',
#   '시장',
#   '단위',
#   '때문',
#   '종류',
#   '암호화폐라도',
#   '라도',
#   '차이',
#   '미국',
#   '5만9373달러',
#   '9373',
#   '달러',
#   '6703',
#   '6703만원',
#   '데스크',
#   '1주일',
#   '주일',
#   '15',
#   '가량',
#   '최근',
#   '30',
#   '비교',
#   '상승세',
#   '글로벌',
#   '기관투자가',
#   '투자가',
#   '유입',
#   '풀이',
#   '최대',
#   '투자은행',
#   '은행',
#   '골드',
#   '골드만삭',
#   '만삭',
#   '지난달',
#   '31',
#   '31일',
#   '현지',
#   '현지시간',
#   '6월',
#   '투자상품',
#   '상품',
#   '발표',
#   '메리',
#   '리치',
#   '신임',
#   '골드만',
#   '지털자산',
#   '대표',
#   '인터뷰',
#   '투자자산',
#   '2500',
#   '2500만',
#   '282',
#   '282억원',
#   '이상',
#   '개인',
#   '고객',
#   '대상',
#   '판매',
#   '결정은',
#   '정은',
#   '수요',
#   '대응',
#   '모건',
#   '모건스탠리',
#   '스탠리',
#   '16',
#   '16일',
#   '세계',
#   '주요',
#   '고액',
#   '고액자산',
#   '펀드',
#   '출시',
#   '신용',
#   '신용카드업체',
#   '카드',
#   '업체',
#   '비자',
#   '29',
#   '29일',
#   '코인',
#   '결제',
#   '결제수단',
#   '수단',
#   '포함',
#   '코인은',
#   '달러화',
#   '가치',
#   '고정',
#   '스테이',
#   '시범',
#   '조치',
#   '가능',
#   '온라인',
#   '플랫폼',
#   '페이팔',
#   '거주자',
#   '활용',
#   '구매',
#   '허용',
#   '관련',
#   '관련기사비트코',
#   '기사',
#   '7400',
#   '7400만원선',
#   '하루',
#   '경신',
#   '세금',
#   '폭탄',
#   '머스크',
#   '약발',
#   '파월',
#   '공격',
#   '리스크',
#   '부정적',
#   '견해',
#   '재닛',
#   '재무',
#   '재무장관',
#   '장관',
#   '투자자',
#   '잠재적',
#   '손실',
#   '우려',
#   '차례',
#   '경고',
#   '이주',
#   '한국',
#   '한국은행',
#   '총재',
#   '24',
#   '24일',
#   '현안',
#   '문답',
#   '자료',
#   '향후',
#   '중앙은행',
#   '디지털',
#   '디지털화폐',
#   '도입',
#   '지급',
#   '감소',
#   '변동성',
#   '가치저장',
#   '저장',
#   '기능',
#   '제약',
#   '이상재',
#   '기자'],
#  ['신세계',
#   '신세계그룹',
#   '그룹',
#   '본사',
#   '지분',
#   '50',
#   '인수',
#   '가능성',
#   '타진',
#   '베이',
#   '베이코리아',
#   '코리아',
#   '인수전',
#   '투자금',
#   '자금',
#   '마련',
#   '관건',
#   '정용진',
#   '용진',
#   '부회장',
#   '지난해',
#   '12',
#   '12월',
#   '스타',
#   '스타벅스코리아',
#   '벅스',
#   '유튜브',
#   '튜브',
#   '채널',
#   '스벅',
#   '출연',
#   '사진',
#   '결별',
#   '결별설',
#   '20',
#   '20년',
#   '지기',
#   '1호팬',
#   '자처',
#   '와이',
#   '와이제이',
#   '제이',
#   '스타벅스',
#   '완벽',
#   '주인',
#   '스타벅스',
#   '멤버십',
#   '닉네임',
#   '100',
#   '방안',
#   '검토',
#   '마트',
#   '1997',
#   '1997년',
#   '미국',
#   '절반',
#   '투자',
#   '설립',
#   '운영',
#   '유학',
#   '유학시절',
#   '시절',
#   '경험',
#   '국내',
#   '일화',
#   '유명',
#   '1999',
#   '1999년',
#   '이대',
#   '이대점',
#   '오픈',
#   '시작',
#   '파트너십',
#   '계약',
#   '만료',
#   '매각',
#   '머스',
#   '사업',
#   '확장',
#   '최근',
#   '구단',
#   '창단',
#   '대규모',
#   '조달',
#   '때문',
#   '업계',
#   '관계자',
#   '인터내셔널',
#   '차원',
#   '다양',
#   '고민',
#   '과정',
#   '매각설',
#   '모두',
#   '예상',
#   '추가',
#   '10',
#   '10년',
#   '체결',
#   '완전',
#   '인수로',
#   '입장',
#   '선회',
#   '데는',
#   '견조',
#   '성장세',
#   '한몫',
#   '코로나',
#   '코로나19',
#   '19',
#   '확산',
#   '지속적',
#   '성장',
#   '2016',
#   '2016년',
#   '최초',
#   '매출',
#   '1조',
#   '돌파',
#   '이래',
#   '1조9284억',
#   '9284',
#   '기록',
#   '2조원대',
#   '기간',
#   '점포',
#   '수도',
#   '계속',
#   '증가',
#   '1500',
#   '1500개',
#   '현재',
#   '보유',
#   '경우',
#   '자회사',
#   '회사',
#   '독자',
#   '독자적인',
#   '적인',
#   '추진',
#   '가능',
#   '닷컴',
#   '시너지',
#   '기대',
#   '사이렌',
#   '로고',
#   '온라인',
#   '샵을',
#   '론칭',
#   '스토',
#   '스토조',
#   '실리콘',
#   '구매',
#   '한정',
#   '판매',
#   '5분',
#   '5000',
#   '5000개',
#   '신세계푸드',
#   '푸드',
#   '거래',
#   '카드',
#   '업종',
#   '협업',
#   '야구단',
#   '만큼',
#   '활용',
#   '범위',
#   '무궁무진',
#   '무궁무진하다',
#   '하다',
#   '새벽',
#   '새벽배송',
#   '배송',
#   '장바구니',
#   '장바구니격',
#   '바구니',
#   '알비백',
#   '래버',
#   '래버레이션',
#   '레이션',
#   '디자인',
#   '10만원',
#   '이상',
#   '결제',
#   '증정',
#   '가격',
#   '장벽',
#   '전량',
#   '소진',
#   '정도로',
#   '도로',
#   '브랜드',
#   '파워',
#   '파트너',
#   '이마트',
#   '재무',
#   '재무구조',
#   '구조',
#   '도움',
#   '300',
#   '300억원',
#   '배당금',
#   '2배',
#   '600',
#   '600억원',
#   '매출액',
#   '수준',
#   '로열티',
#   '지급',
#   '배당',
#   '수익',
#   '수익성',
#   '개선',
#   '계산',
#   '2019',
#   '2019년',
#   '당시',
#   '가치',
#   '1조원',
#   '평가',
#   '올해',
#   '전망',
#   '결국',
#   '생각',
#   '적정',
#   '적정가가',
#   '가가',
#   '결정',
#   '중요',
#   '요인',
#   '일각',
#   '공모',
#   '공모형식',
#   '형식',
#   '회사채',
#   '발행',
#   '소식',
#   '지분인수',
#   '구체화',
#   '의견',
#   '금융',
#   '금융투자업계',
#   '4월',
#   '8일',
#   '4000',
#   '4000억원',
#   '어치',
#   '목표',
#   '수요',
#   '수요예측',
#   '예측',
#   '예정일',
#   '일주일',
#   '한국',
#   '한국투자증권',
#   '증권',
#   '대표',
#   '주관',
#   '목적과',
#   '규모',
#   '차환',
#   '차환자금',
#   '목적',
#   '만기',
#   '11',
#   '11일',
#   '1000',
#   '1000억',
#   '전부',
#   '흥행',
#   '흥행시',
#   '최대',
#   '6000',
#   '6000억원',
#   '계획',
#   '실탄',
#   '해석',
#   '유동성',
#   '확보',
#   '대비책',
#   '풀이',
#   '관련',
#   '다각적',
#   '검토중',
#   '되풀이',
#   '일본',
#   '중국',
#   '중국시장',
#   '시장',
#   '직영',
#   '전환',
#   '매장',
#   '방식',
#   '아시아',
#   '공급',
#   '공급계약',
#   '현지',
#   '우선',
#   '진출',
#   '전략',
#   '구사',
#   '합작',
#   '차이나',
#   '2017',
#   '2017년',
#   '인수해',
#   '수해',
#   '자비',
#   '리그',
#   '2014',
#   '2014년',
#   '재팬',
#   '세계',
#   '3위권',
#   '위권',
#   '차지',
#   '대형',
#   '선례',
#   '기준',
#   '직접',
#   '경영',
#   '지배력',
#   '결정권',
#   '정권',
#   '위치',
#   '스타벅스가',
#   '벅스가',
#   '캐시',
#   '중장기',
#   '예고',
#   '만큼',
#   '상존',
#   '분석',
#   '합작사인',
#   '사인',
#   '등에',
#   '프리미엄',
#   '성공',
#   '스타벅',
#   '기업',
#   '연착륙',
#   '다음',
#   '확인',
#   '고수',
#   '하자',
#   '후문',
#   '당장',
#   '이베이코리아',
#   '5조원',
#   '허정연',
#   '정연',
#   '기자'],
#  ['김성일',
#   '퇴직',
#   '퇴직연금',
#   '연금',
#   '이야기',
#   '79',
#   '진통',
#   '근로자',
#   '근로자퇴직급여보장법',
#   '급여',
#   '보장법',
#   '이하',
#   '퇴직연금법',
#   '연금법',
#   '개정안',
#   '3월',
#   '24',
#   '24일',
#   '국회',
#   '통과',
#   '2022',
#   '2022년',
#   '4월',
#   '시행',
#   '그동안',
#   '논의',
#   '내용',
#   '반영',
#   '가입자',
#   '중요',
#   '이번',
#   '가지',
#   '요약',
#   '중소기업',
#   '퇴직연금기금',
#   '기금',
#   '제도',
#   '도입',
#   '적립금',
#   '적립금운용계획서',
#   '운용',
#   '계획서',
#   '작성',
#   '의무화',
#   '교육',
#   '전문',
#   '전문교육기관',
#   '기관',
#   '확대',
#   '그것',
#   '퇴직연금기금제도',
#   '2019',
#   '2019년',
#   '기준',
#   '300',
#   '300인',
#   '이상',
#   '대기업',
#   '88.1',
#   '30',
#   '30인',
#   '미만',
#   '중소',
#   '영세',
#   '사업장',
#   '23.4',
#   '저조',
#   '퇴직연금제의',
#   '제의',
#   '혜택',
#   '개선',
#   '핵심',
#   '사실',
#   '해외',
#   '일반적',
#   '퇴직연금제도',
#   '자산',
#   '자산운용',
#   '노후',
#   '준비',
#   '취지',
#   '경험',
#   '부족',
#   '때문',
#   '기금형',
#   '개정',
#   '국가',
#   '사용자',
#   '부담금',
#   '기금제도',
#   '비용',
#   '일부',
#   '예산',
#   '범위',
#   '지원',
#   '가능성',
#   '사진',
#   '합의',
#   '외부',
#   '외부전문가',
#   '전문가',
#   '도움',
#   '회사',
#   '독립',
#   '별도',
#   '수탁',
#   '수탁법인',
#   '법인',
#   '설립',
#   '운영',
#   '골자',
#   '이번',
#   '근로',
#   '근로복지공단',
#   '복지',
#   '공단',
#   '장점',
#   '촉진',
#   '노사',
#   '이해관계',
#   '의사',
#   '의사결정',
#   '결정',
#   '가능',
#   '수급',
#   '보장',
#   '관련',
#   '확보',
#   '수익률',
#   '확정',
#   '확정급여형',
#   '300명',
#   '대상',
#   '운용목적',
#   '목적',
#   '방법',
#   '목표',
#   '목표수익률',
#   '설정',
#   '운용성과',
#   '성과',
#   '평가',
#   '포함',
#   '심의',
#   '적립금운용위원회',
#   '위원회',
#   '구성',
#   '투자',
#   '기간',
#   '동안',
#   '투자자',
#   '위험',
#   '감내',
#   '수준',
#   '규정',
#   '문서',
#   '유동성',
#   '세금',
#   '사항',
#   '특수',
#   '특수상황',
#   '상황',
#   '고려',
#   '제약',
#   '제약사항',
#   '적립',
#   '자산운용전문가',
#   '참여',
#   '원리금',
#   '보장상품',
#   '상품',
#   '위주',
#   '임금',
#   '임금상승률',
#   '상승률',
#   '담당자',
#   '책임',
#   '문제',
#   '전망',
#   '우리',
#   '우리나라',
#   '나라',
#   '근퇴법',
#   '퇴직연금가입자',
#   '의무',
#   '퇴직연금사업자',
#   '사업자',
#   '위탁',
#   '현행',
#   '이외',
#   '교육만족도',
#   '만족도',
#   '증식',
#   '직결',
#   '경제적',
#   '사회적',
#   '문화적',
#   '환경',
#   '변화',
#   '법적',
#   '안정성',
#   '필요',
#   '퇴직연금제',
#   '연금제',
#   '문제점',
#   '해결',
#   '염두',
#   '첫째',
#   '정부',
#   '구체적',
#   '고용',
#   '고용노동부',
#   '노동부',
#   '장관',
#   '요구',
#   '방향',
#   '금리',
#   '일정',
#   '수익',
#   '합리적',
#   '수탁자',
#   '역할',
#   '수행',
#   '선량',
#   '관리자',
#   '공감',
#   '접근',
#   '둘째',
#   '기존',
#   '기업',
#   '경우',
#   '이제',
#   '실행',
#   '시스템',
#   '보완',
#   '아가',
#   '동기',
#   '동기부여',
#   '부여',
#   '이익',
#   '100',
#   '귀속',
#   '방안',
#   '모색',
#   '배당',
#   '활용',
#   '초과',
#   '초과분',
#   '퇴직급여',
#   '가산',
#   '일종',
#   '기본',
#   '속성',
#   '확정기여형',
#   '기여',
#   '특성',
#   '최종',
#   '최종급여',
#   '근속',
#   '근속연수',
#   '연수',
#   '산출',
#   '누계',
#   '누계액',
#   '자의',
#   '계산',
#   '운용책임',
#   '형의',
#   '형태',
#   '분류',
#   '시장',
#   '운용수익',
#   '지금',
#   '퇴직금',
#   '지급',
#   '유사',
#   '측면',
#   '법정',
#   '셋째',
#   '교육전문기관',
#   '엄격',
#   '마련',
#   '콘텐츠',
#   '인력',
#   '우수성',
#   '대면',
#   '현장',
#   '종합적',
#   '교육의무',
#   '지정',
#   '고민',
#   '입장',
#   '사전',
#   '디폴트',
#   '폴트',
#   '옵션',
#   '부분',
#   '현재',
#   '노후준비',
#   '절망적',
#   '인구',
#   '인구절벽',
#   '절벽',
#   '수시',
#   '발생',
#   '예상',
#   '대응',
#   '신속성',
#   '진화',
#   '노력',
#   '계속',
#   '대표',
#   '관련기사',
#   '기사',
#   '10',
#   '10년',
#   '장기',
#   '증권',
#   '보험',
#   '은행',
#   '입법',
#   '불발',
#   '97',
#   '일시금',
#   '수령',
#   '이유'],
#  ['홍남기',
#   '남기',
#   '부총리',
#   '기획',
#   '정부',
#   '장관',
#   '1일',
#   '정부서울청사',
#   '서울',
#   '청사',
#   '7차',
#   '혁신',
#   '혁신성장',
#   '성장',
#   '빅3',
#   '추진',
#   '추진회의',
#   '회의',
#   '입장',
#   '뉴스',
#   '뉴스1',
#   '3월',
#   '취업자',
#   '수가',
#   '작년',
#   '이상',
#   '회복',
#   '예상',
#   '지난달',
#   '31',
#   '31일',
#   '최근',
#   '발표',
#   '고용',
#   '지표',
#   '개선',
#   '흐름',
#   '시작',
#   '22',
#   '22일',
#   '문재인',
#   '재인',
#   '대통령',
#   '해석',
#   '향후',
#   '희망',
#   '깜빡이',
#   '자신감',
#   '배경',
#   '각종',
#   '경제',
#   '2월',
#   '산업',
#   '생산',
#   '생산지수',
#   '지수',
#   '전월',
#   '대비',
#   '2.1',
#   '상승',
#   '통계',
#   '작성',
#   '이래',
#   '최고',
#   '기록',
#   '업황',
#   '기업',
#   '기업경기실사지수',
#   '경기',
#   '실사',
#   '10',
#   '10년',
#   '실물',
#   '실물경제',
#   '심리',
#   '호조',
#   '예측',
#   '고용시장',
#   '시장',
#   '차가운데',
#   '가운데',
#   '상황',
#   '가능성',
#   '착시',
#   '착시효과',
#   '효과',
#   '12',
#   '12개월',
#   '개월',
#   '연속',
#   '감소',
#   '그래픽',
#   '김영옥',
#   '기자',
#   '지난해',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '영향',
#   '본격화',
#   '전년',
#   '동월',
#   '19만5000명',
#   '5000',
#   '마이너스',
#   '전환',
#   '이후',
#   '월별',
#   '기저',
#   '기저효과',
#   '때문',
#   '비교',
#   '올해',
#   '통계청',
#   '14',
#   '14일',
#   '고용동향',
#   '동향',
#   '공개',
#   '취업',
#   '게다',
#   '104',
#   '104만2000개',
#   '2000',
#   '직접',
#   '직접일자리',
#   '일자리',
#   '공언',
#   '78',
#   '78만7000명',
#   '7000',
#   '기준',
#   '사업',
#   '보건',
#   '사회',
#   '사회복지서비스업',
#   '복지',
#   '서비스',
#   '서비스업',
#   '공공',
#   '공공행정',
#   '행정',
#   '산업과',
#   '60',
#   '60세',
#   '연령',
#   '연령대',
#   '성동',
#   '성동구청',
#   '구청',
#   '희망일자리센터',
#   '센터',
#   '시민',
#   '게시판',
#   '이번',
#   '추가',
#   '추가경정예산',
#   '경정',
#   '예산',
#   '추경',
#   '여성',
#   '청년',
#   '중장년',
#   '장년',
#   '대상',
#   '25',
#   '25만5000개',
#   '창출',
#   '포함',
#   '야당',
#   '분식',
#   '단기',
#   '알바',
#   '비판',
#   '결국',
#   '주도로',
#   '시급',
#   '재활',
#   '재활용품',
#   '용품',
#   '분리',
#   '분리배출',
#   '배출',
#   '축소',
#   '관련',
#   '2조1000억',
#   '1000',
#   '1조8000억',
#   '8000',
#   '감액',
#   '이것',
#   '중요',
#   '낙관',
#   '구직자',
#   '분위기',
#   '암울',
#   '전국',
#   '전국경제인연합회',
#   '경제인',
#   '연합회',
#   '산하',
#   '한국',
#   '한국경제연구원',
#   '연구원',
#   '조사',
#   '결과',
#   '매출액',
#   '500',
#   '500대',
#   '63.6',
#   '상반기',
#   '채용',
#   '계획',
#   '고령',
#   '고용원',
#   '자영',
#   '자영업자',
#   '업자',
#   '15',
#   '15만6000명',
#   '6000',
#   '-10.7',
#   '4만5000명',
#   '1.1',
#   '기존',
#   '자리',
#   '만들기',
#   '포기',
#   '얘기',
#   '전문가',
#   '대신',
#   '이전',
#   '수준',
#   '집중',
#   '지적',
#   '김소영',
#   '서울대',
#   '경제학부',
#   '학부',
#   '교수',
#   '일시적',
#   '수치',
#   '표현',
#   '사실',
#   '필요',
#   '숫자',
#   '세종',
#   '임성빈',
#   '성빈',
#   '관련기사바닥',
#   '기사',
#   '바닥',
#   '본격',
#   '양극화',
#   '자형',
#   '우려',
#   '1년',
#   '8년',
#   '최저',
#   '경제통',
#   '세종시',
#   '결혼',
#   '출산',
#   '주범',
#   '정체',
#   '이제',
#   '60대',
#   '황혼',
#   '신기록',
#   '옥탑방',
#   '4층',
#   '건물',
#   '주택',
#   '양도',
#   '양도세',
#   '사연'],
#  ['오민수',
#   '민수',
#   '생각',
#   '스토리텔링',
#   '사전',
#   '의미',
#   '이야기',
#   '구어',
#   '거짓',
#   '거짓말하기',
#   '말하기',
#   '거짓말',
#   '공식',
#   '성립',
#   '세상',
#   '역설적',
#   '그것',
#   '매력',
#   '우리',
#   '진실',
#   '사실',
#   '자신',
#   '기만',
#   '현실',
#   '외면',
#   '욕구',
#   '사진',
#   '대부분',
#   '골치',
#   '허구적',
#   '보호',
#   '사람',
#   '수천',
#   '사제',
#   '무당',
#   '정치인',
#   '의식',
#   '다음',
#   '정성',
#   '행동',
#   '양식',
#   '옛날',
#   '하늘',
#   '돌덩어리',
#   '덩어리',
#   '운석',
#   '현상',
#   '현상임',
#   '때문',
#   '민심',
#   '분노',
#   '제사',
#   '가뭄',
#   '기우제',
#   '우제',
#   '마찬가지',
#   '역사적',
#   '공자',
#   '공자만큼',
#   '만큼',
#   '중요성',
#   '강조',
#   '의례',
#   '준수',
#   '평화',
#   '사회',
#   '정치',
#   '안정',
#   '열쇠',
#   '주례',
#   '고전',
#   '국가',
#   '절차',
#   '사용',
#   '그릇',
#   '악기',
#   '종류',
#   '참가자',
#   '의복',
#   '색상',
#   '나열',
#   '이것',
#   '문제',
#   '정치적',
#   '해법',
#   '국가적',
#   '위기',
#   '군대',
#   '전투',
#   '패배',
#   '주임',
#   '주임원사',
#   '원사',
#   '군기',
#   '병사',
#   '군화',
#   '이치',
#   '근본',
#   '근본적인',
#   '적인',
#   '해결',
#   '현대',
#   '대중',
#   '술수임',
#   '수임',
#   '혼란',
#   '춘추',
#   '춘추전국시대',
#   '전국',
#   '시대',
#   '우매',
#   '인간',
#   '본성',
#   '비책',
#   '당시',
#   '통제',
#   '골칫거리',
#   '유지',
#   '지속',
#   '이제',
#   '정치공학',
#   '공학',
#   '비가',
#   '문제지',
#   '오늘날',
#   '코로나',
#   '바이러스',
#   '백신',
#   '실패',
#   '부동산',
#   '정책',
#   '투기',
#   '수습',
#   '와중',
#   '선거',
#   '대비',
#   '정당',
#   '후보',
#   '정책적',
#   '방안',
#   '하나',
#   '비방',
#   '통계',
#   '난무',
#   '선거철',
#   '이상',
#   '영웅',
#   '등장',
#   '필요',
#   '건강',
#   '언론',
#   '기사',
#   '여론',
#   '선동',
#   '기우제만큼',
#   '느낌',
#   '쓰레기',
#   '뉴스',
#   '생산',
#   '기레',
#   '선별',
#   '인터넷',
#   '쇼핑',
#   '쇼핑만큼',
#   '영화',
#   '남산',
#   '부장',
#   '출동',
#   '정부',
#   '비판',
#   '대통령',
#   '여야',
#   '모두',
#   '사회적',
#   '분위기',
#   '마음',
#   '어른',
#   '어린아이',
#   '기우',
#   '기우제도',
#   '제도',
#   '조작',
#   '듣기',
#   '이유',
#   '남불',
#   '유체이탈',
#   '이탈',
#   '화법',
#   '목소리',
#   '인류',
#   '역사상',
#   '사상',
#   '신화',
#   '이해',
#   '운명',
#   '우주',
#   '삼라만상',
#   '대변',
#   '신이',
#   '장치',
#   '사피엔스',
#   '저자',
#   '유발',
#   '하라',
#   '하라리',
#   '호모',
#   '무기인',
#   '창조',
#   '종교',
#   '건설',
#   '거기',
#   '이념',
#   '뒷받침',
#   '과정',
#   '중요',
#   '사피',
#   '음모',
#   '마련',
#   '의도',
#   '누군가',
#   '숫자',
#   '단편적',
#   '안목',
#   '너머',
#   '멀티',
#   '멀티캠퍼스',
#   '캠퍼스',
#   '전직',
#   '전직지원사업',
#   '지원',
#   '사업',
#   '총괄',
#   '관련',
#   '관련기사',
#   '토이면서',
#   '이면서',
#   '인턴',
#   '에어',
#   '에어비',
#   '비의',
#   '일터',
#   '현자',
#   '중세',
#   '르네상스',
#   '흑사병',
#   '부메랑',
#   '저성',
#   '저성과자',
#   '과자',
#   '교육',
#   '역설'],
#  ['미국',
#   '텍사스',
#   '텍사스주의',
#   '주의',
#   '삼성',
#   '삼성전자',
#   '전자',
#   '오스틴',
#   '반도체',
#   '반도체공장',
#   '공장',
#   '세계적',
#   '공급',
#   '부족',
#   '사태',
#   '계속',
#   '대통령',
#   '12',
#   '12일',
#   '글로벌',
#   '자동차',
#   '업체',
#   '리더',
#   '자리',
#   '참석',
#   '텍사스주',
#   '운영',
#   '포함',
#   '3일',
#   '블룸',
#   '블룸버그통신',
#   '버그',
#   '통신',
#   '1일',
#   '현지',
#   '현지시간',
#   '시간',
#   '제이',
#   '설리번',
#   '백악관',
#   '국가',
#   '국가안보보좌관',
#   '안보',
#   '보좌관',
#   '브라',
#   '브라이언',
#   '이언',
#   '디스',
#   '국제',
#   '국제경제위원회',
#   '경제',
#   '위원회',
#   '위원장',
#   '업계',
#   '경영진',
#   '회동',
#   '수급',
#   '문제',
#   '집중',
#   '논의',
#   '보도',
#   '이날',
#   '초청',
#   '제너럴',
#   '제너럴모터스',
#   '모터스',
#   '글로벌파운드리',
#   '파운드리',
#   '코로나',
#   '코로나19',
#   '19',
#   '원격',
#   '수업',
#   '재택',
#   '재택근무',
#   '근무',
#   '머스',
#   '급성장',
#   '노트북',
#   '홈네트워크장비',
#   '네트워크',
#   '장비',
#   '가전',
#   '가전제품',
#   '제품',
#   '수요',
#   '최근',
#   '현상',
#   '심화',
#   '지난해',
#   '하반기',
#   '판매량',
#   '급증',
#   '차량',
#   '대란',
#   '도요타',
#   '요타',
#   '물론',
#   '애플',
#   '월풀',
#   '생산량',
#   '차질',
#   '상황',
#   '반도체업계',
#   '관계자',
#   '가격',
#   '물건',
#   '분위기',
#   '정부',
#   '국내',
#   '생산',
#   '확대',
#   '인센티브',
#   '검토',
#   '공급망',
#   '취약성',
#   '권지',
#   '권지예',
#   '기자'],
#  ['한화',
#   '한화리조트',
#   '리조트',
#   '거제',
#   '벨버디',
#   '버디',
#   '호텔',
#   '기념품',
#   '제공',
#   '일회용',
#   '위생',
#   '위생용품',
#   '용품',
#   '내년',
#   '환경부',
#   '규제',
#   '조치',
#   '고객',
#   '공유',
#   '대용량',
#   '디스펜서',
#   '사용법',
#   '고심',
#   '3일',
#   '호텔업계',
#   '업계',
#   '50',
#   '50실',
#   '이상',
#   '숙박',
#   '숙박업소',
#   '업소',
#   '무상',
#   '대비',
#   '비누',
#   '액체',
#   '액체형',
#   '샴푸',
#   '컨디셔너',
#   '바디',
#   '바디워시',
#   '워시',
#   '로션',
#   '다회',
#   '용기',
#   '전망',
#   '롯데',
#   '롯데호텔',
#   '운영',
#   '비즈니스',
#   '비즈니스호텔',
#   '브랜드',
#   '롯데시티호텔',
#   '시티',
#   '7호텔',
#   '대체',
#   '300',
#   '300㎖',
#   '용량',
#   '주문',
#   '제작',
#   '상태',
#   '방침',
#   '한화호텔앤드리조트',
#   '앤드',
#   '욕실',
#   '방안',
#   '검토',
#   '중이',
#   '관계자',
#   '일부',
#   '객실',
#   '사용',
#   '중인',
#   '변경',
#   '지리적',
#   '특성',
#   '제품',
#   '선정',
#   '만족도',
#   '예정',
#   '7월',
#   '그랜드',
#   '오픈',
#   '호반',
#   '호반호텔',
#   '레스트',
#   '레스트리',
#   '리솜',
#   '고민',
#   '입장',
#   '관심도',
#   '영향',
#   '만큼',
#   '방식',
#   '최근',
#   '경영계',
#   '전반',
#   '환경',
#   '사회',
#   '지배',
#   '지배구조',
#   '구조',
#   '일회용품',
#   '퇴출',
#   '수긍',
#   '분위기',
#   '서도',
#   '자연',
#   '변화',
#   '권지',
#   '권지예',
#   '기자'],
#  ['서울',
#   '송파',
#   '강남',
#   '일대',
#   '아파트',
#   '단지',
#   '모습',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '한국',
#   '한국부동산원',
#   '부동',
#   '산원',
#   '하루',
#   '차이',
#   '지난달',
#   '강남',
#   '강남구',
#   '아파트값',
#   '상승률',
#   '자료',
#   '시계열',
#   '통계',
#   '상반',
#   '결과',
#   '시장',
#   '혼선',
#   '전달',
#   '2월',
#   '발표',
#   '다음',
#   '평균',
#   '매매',
#   '매매가격',
#   '가격',
#   '846',
#   '846만원',
#   '때문',
#   '3일',
#   '부동산',
#   '1일',
#   '전국',
#   '전국주택가격동향',
#   '주택',
#   '동향',
#   '전월',
#   '0.46',
#   '상승',
#   '파악',
#   '2일',
#   '17',
#   '17억6016만',
#   '6016',
#   '그다음',
#   '800',
#   '800만원',
#   '정도',
#   '표본',
#   '표본주택',
#   '교체',
#   '과정',
#   '현상',
#   '해명',
#   '실제',
#   '부연',
#   '부동산원',
#   '조사',
#   '조정',
#   '정확도',
#   '6월',
#   '월간',
#   '2만8360가구',
#   '8360',
#   '가구',
#   '4만6170가구',
#   '6170',
#   '확대',
#   '민감도',
#   '주간',
#   '주간조사',
#   '9400',
#   '9400가구',
#   '1만3720가구',
#   '3720',
#   '예정',
#   '수시',
#   '1곳',
#   '건축',
#   '철거',
#   '선정',
#   '영향',
#   '설명',
#   '관계자',
#   '기존',
#   '멸실',
#   '연령',
#   '규모',
#   '격차',
#   '평균가격',
#   '대비',
#   '상승폭',
#   '상승세',
#   '확인',
#   '원석',
#   '기자'],
#  ['경기',
#   '경기도',
#   '용인',
#   '조성',
#   '중인',
#   '반도체',
#   '러스터',
#   '스터',
#   '인근',
#   '투기',
#   '의혹',
#   '도마',
#   '프로젝트',
#   '주도',
#   '하이닉스',
#   '곤혹',
#   '표정',
#   '연말',
#   '착공',
#   '가운데',
#   '일정',
#   '차질',
#   '구설',
#   '집적',
#   '집적단지',
#   '단지',
#   '122',
#   '122조원',
#   '투자',
#   '반도체공장',
#   '공장',
#   '4곳',
#   '예정',
#   '2024',
#   '2024년',
#   '생산',
#   '생산라인',
#   '라인',
#   '1기',
#   '완료',
#   '4년',
#   '단위',
#   '추가',
#   '건설',
#   '방침',
#   '이곳',
#   '국내외',
#   '소재',
#   '부품',
#   '장비',
#   '업체',
#   '50',
#   '50여',
#   '입주',
#   '불씨',
#   '악재',
#   '최근',
#   '전직',
#   '경기',
#   '투자진흥',
#   '진흥',
#   '소속',
#   '공무원',
#   '아내',
#   '대표',
#   '회사',
#   '부지',
#   '매입',
#   '3년',
#   '시세',
#   '25',
#   '25억원가량',
#   '가량',
#   '경찰',
#   '2일',
#   '구속',
#   '구속영장',
#   '영장',
#   '신청',
#   '상태',
#   '입장',
#   '추진',
#   '잡음',
#   '관련',
#   '조사',
#   '지면',
#   '내부',
#   '직원',
#   '불안감',
#   '이천',
#   '사진',
#   '당시',
#   '단속',
#   '120',
#   '120조원',
#   '조원',
#   '무산',
#   '토지',
#   '바람',
#   '지불',
#   '땅값',
#   '만큼',
#   '불리',
#   '상황',
#   '기도',
#   '하다',
#   '사업',
#   '최종',
#   '최종승인',
#   '승인',
#   '행정',
#   '행정절차',
#   '절차',
#   '마무리',
#   '3일',
#   '용인',
#   '용인시',
#   '지난달',
#   '29',
#   '29일',
#   '주요한',
#   '클러스터',
#   '처인구',
#   '인구',
#   '원삼',
#   '원삼면',
#   '독성',
#   '고당',
#   '죽능리',
#   '능리',
#   '일대',
#   '416',
#   '416만㎡',
#   '126',
#   '126만',
#   '차세대',
#   '생산기지',
#   '기지',
#   '구축',
#   '2019',
#   '2019년',
#   '3월',
#   '국토',
#   '국토교통부',
#   '교통부',
#   '수도권',
#   '수도권정비위원회의',
#   '정비',
#   '위원',
#   '회의',
#   '산업',
#   '산업단지',
#   '특별',
#   '특별물량',
#   '물량',
#   '배당',
#   '지방',
#   '지방산업단지계획',
#   '계획',
#   '심의',
#   '1월',
#   '수도권정비위원회',
#   '위원회',
#   '통과',
#   '올해',
#   '보상',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '개발',
#   '소식',
#   '직접',
#   '고용',
#   '1만5000여',
#   '5000',
#   '협력',
#   '협력업체',
#   '포함',
#   '5만여',
#   '명의',
#   '효과',
#   '예상',
#   '중심',
#   '지역',
#   '지역경제',
#   '경제',
#   '발전',
#   '기대',
#   '부동산',
#   '업계',
#   '1000',
#   '1000억원',
#   '거래',
#   '기대감',
#   '1000억대',
#   '확대',
#   '필요',
#   '총량',
#   '제한',
#   '처지',
#   '보유',
#   '1982',
#   '1982년',
#   '제정',
#   '수도권정비계획',
#   '서울',
#   '인천',
#   '면적',
#   '해당',
#   '범위',
#   '연면적',
#   '500',
#   '500㎡',
#   '이상',
#   '증설',
#   '허용',
#   '제도',
#   '외부',
#   '외부시설',
#   '시설',
#   '임대',
#   '정부',
#   '해외',
#   '유턴',
#   '기업',
#   '대상',
#   '규제',
#   '일부',
#   '완화',
#   '혜택',
#   '선택',
#   '이유',
#   '때문',
#   '우수',
#   '인력',
#   '확보',
#   '특성',
#   '고급',
#   '두뇌',
#   '유치',
#   '유기적',
#   '연계',
#   '중요',
#   '여기',
#   '전력',
#   '용수',
#   '교통망',
#   '인프라',
#   '한국',
#   '한국반도체산업협회',
#   '협회',
#   '국내',
#   '회원',
#   '회원사',
#   '기준',
#   '80',
#   '성사',
#   '불똥',
#   '노심초사',
#   '분위기',
#   '조심',
#   '지자체',
#   '최현주',
#   '현주',
#   '기자'],
#  ['네이버',
#   '서비스',
#   '최단',
#   '기간',
#   '최대',
#   '규모',
#   '글로벌',
#   '사용자',
#   '게다',
#   '대부분',
#   '세대',
#   '출시',
#   '3년차',
#   '페토',
#   '수식어',
#   '제페토',
#   '증강',
#   '증강현실',
#   '현실',
#   '아바',
#   '아바타로',
#   '타로',
#   '소셜네트워크',
#   '네트워크',
#   '가입자',
#   '2억명',
#   '해외',
#   '비중',
#   '90',
#   '165',
#   '165개국',
#   '개국',
#   '이용자',
#   '80',
#   '10',
#   '10대',
#   '팩플레터',
#   '레터',
#   '83',
#   '83호',
#   '요약',
#   '김대',
#   '네이버제트',
#   '제트',
#   '공동',
#   '공동대표',
#   '대표',
#   '인터뷰',
#   '최근',
#   '메타',
#   '메타버스',
#   '버스',
#   '플랫폼',
#   '사회',
#   '경제',
#   '문화적',
#   '활동',
#   '가능',
#   '가상공간',
#   '온라인',
#   '친구',
#   '게임',
#   '포스트',
#   '코로나',
#   '일상',
#   '일상이자',
#   '이자',
#   '12',
#   '12일',
#   '경기',
#   '경기도',
#   '판교',
#   '본사',
#   '33',
#   '지난해',
#   '5월',
#   '스노우',
#   '분사',
#   '모바일',
#   '사업',
#   '다각화',
#   '2세대',
#   '자회사',
#   '3세대',
#   '대표주자',
#   '주자',
#   '이충민',
#   '사업총괄',
#   '총괄',
#   '동석',
#   '운영',
#   '경기',
#   '성남',
#   '성남시',
#   '분당',
#   '분당구',
#   '중앙',
#   '중앙일보',
#   '일보',
#   '포즈',
#   '김상선',
#   '상선',
#   '기자',
#   '가상',
#   '양방향',
#   '방향',
#   '소통',
#   '접점',
#   '나의',
#   '부캐',
#   '직업',
#   '인간',
#   '인간관계',
#   '관계',
#   '중요',
#   '조건',
#   '사람',
#   '기업',
#   '통제',
#   '통제해선',
#   '해선',
#   '초반',
#   '개념',
#   '염두',
#   '세상',
#   '구상',
#   '초기',
#   '이것',
#   '요즘',
#   '말로',
#   '의상',
#   '아이템',
#   '제작',
#   '판매',
#   '기능',
#   '스튜디오',
#   '교실',
#   '쇼핑몰',
#   '테마',
#   '테마별',
#   '월드',
#   '참여',
#   '기반',
#   '계속',
#   '추가',
#   '이유',
#   '미래',
#   '젠간',
#   '자체',
#   '아이',
#   '아이돌',
#   '블랙',
#   '블랙핑크',
#   '핑크',
#   '사진',
#   '이상',
#   '경우',
#   '하루',
#   '7000',
#   '8000',
#   '8000개',
#   '신제품',
#   '우리',
#   '다양',
#   '실험',
#   '우리',
#   '아래',
#   '투명',
#   '투명인간',
#   '강아지',
#   '신발',
#   '웃음',
#   '구찌',
#   '크리스',
#   '크리스찬',
#   '루부탱',
#   '명품',
#   '브랜드',
#   '아이돌이',
#   '돌이',
#   '무엇',
#   '소비자',
#   '기존',
#   '미디어',
#   '마케팅',
#   '경험',
#   '쌍방',
#   '쌍방소통',
#   '매력',
#   '때문',
#   '코로나19',
#   '19',
#   '영향',
#   '대면',
#   '행사',
#   '팬사인회',
#   '사인',
#   '패션쇼',
#   '부탱',
#   '제페토에',
#   '활용',
#   '액세서리',
#   '60',
#   '60여종',
#   '여종',
#   '이탈리아',
#   '피렌체',
#   '배경',
#   '월드맵',
#   '드맵',
#   '빌라',
#   '빅히트',
#   '히트',
#   '120',
#   '120억원',
#   '50',
#   '50억원',
#   '투자',
#   '엔터',
#   '킬러',
#   '콘텐츠',
#   '가운데',
#   '하나',
#   '스포츠',
#   '패션',
#   '만화',
#   '나중',
#   '교육',
#   '포괄',
#   '영역',
#   '어디',
#   '확장',
#   '생각',
#   '여기',
#   '매출',
#   '8억원',
#   '누적',
#   '창작자',
#   '숫자',
#   '6만명',
#   '직장',
#   '전업',
#   '디자이너',
#   '아바타',
#   '유통',
#   '건축가',
#   '이중',
#   '300',
#   '300만원',
#   '순수익',
#   '정도',
#   '무대',
#   '지금',
#   '제휴',
#   '제휴사',
#   '임대료',
#   '세계',
#   '대상',
#   '수익',
#   '연애',
#   '결혼식',
#   '캐릭터',
#   '아기',
#   '아바타가',
#   '타가',
#   '동일',
#   '필요',
#   '고등학생',
#   '기획사',
#   '사장',
#   '일종',
#   '역할',
#   '역할놀이',
#   '놀이',
#   '드라마',
#   '감독',
#   '크리',
#   '띠미',
#   '바탕',
#   '유튜브',
#   '튜브',
#   '영상',
#   '반응',
#   '인스타그램',
#   '스타',
#   '그램',
#   '언서',
#   '본인',
#   '본인만',
#   '특기',
#   '실존',
#   '인물',
#   '매력자본',
#   '자본',
#   '누구',
#   '연령층',
#   '스타그램',
#   '페이스',
#   '페이스북',
#   '시작',
#   '특정',
#   '전체',
#   '75',
#   '결제',
#   '수수료',
#   '30',
#   '수익구조',
#   '구조',
#   '강화',
#   '노스페이스',
#   '스페이스',
#   '경쟁사',
#   '로블록스',
#   '포트',
#   '포트나이트',
#   '나이트',
#   '마인',
#   '마인크래프트',
#   '크래프트',
#   '개성',
#   '중요하다',
#   '하다',
#   '공통점',
#   '집중',
#   '코스',
#   '코스모폴리',
#   '폴리',
#   '2020',
#   '2020년',
#   '9월호',
#   '표지',
#   '표지모델',
#   '모델',
#   '중앙포토',
#   '포토',
#   '이해',
#   '창업자',
#   '업자',
#   '회사',
#   '성공',
#   '2019',
#   '2019년',
#   '6월',
#   '기대',
#   '지원',
#   '미국',
#   '증시',
#   '상장',
#   '계획',
#   '성장',
#   '기회',
#   '김정민',
#   '정민',
#   '기사',
#   '4월',
#   '1일',
#   '팩플',
#   '뉴스',
#   '뉴스레터',
#   '구독자',
#   '발송',
#   '버전',
#   '구력',
#   '20',
#   '20년',
#   '혁신',
#   '준비',
#   '조직',
#   '조직이자',
#   '핫하다',
#   '이월',
#   '구현',
#   '전문',
#   '이메일',
#   '구독',
#   '신청',
#   '테크',
#   '테크기업',
#   '소식',
#   '입체적',
#   '구독신청',
#   '코드'],
#  ['안녕',
#   '건강',
#   '주식',
#   '맛집',
#   '앤츠랩',
#   '한국',
#   '한국조선해양',
#   '조선',
#   '해양',
#   '현대',
#   '현대중공업그룹',
#   '중공업',
#   '그룹',
#   '부문',
#   '중간',
#   '중간지주',
#   '지주',
#   '회사',
#   '부회장',
#   '산하',
#   '현대중공업',
#   '현대미포조선',
#   '현대삼호중공업',
#   '삼호',
#   '현대오일뱅크',
#   '오일',
#   '뱅크',
#   '현대건설기계',
#   '건설',
#   '기계',
#   '에너지',
#   '나머지',
#   '현대중공업지주',
#   '별도',
#   '현대미',
#   '상장',
#   '울산',
#   '조선소',
#   '사진',
#   '임성',
#   '기자',
#   '컨테이너',
#   '컨테이너선',
#   '수요',
#   '증가',
#   '조선업',
#   '업황',
#   '회복',
#   '선가도',
#   '가도',
#   '작년',
#   '국내',
#   '조선3사',
#   '수주',
#   '지속',
#   '수소',
#   '신사업',
#   '발표',
#   '대우',
#   '대우조선해양',
#   '결합',
#   '심사',
#   '핵심',
#   '자회사',
#   '변수',
#   '요즘',
#   '주식시장',
#   '시장',
#   '관심',
#   '현대상선',
#   '대상',
#   '3월',
#   '2500',
#   '2500원',
#   '얼마',
#   '3만원',
#   '테슬라',
#   '저리',
#   '종목',
#   '10',
#   '10일',
#   '뉴스',
#   '뉴스레터',
#   '레터',
#   '참조',
#   '운임',
#   '뱃삯',
#   '급등',
#   '때문',
#   '해운',
#   '해운사',
#   '주문',
#   '결국',
#   '선가',
#   '배의',
#   '가격',
#   '영국',
#   '전문',
#   '기관',
#   '선가지수',
#   '지수',
#   '올해',
#   '10주',
#   '연속',
#   '상승',
#   '2019',
#   '2019년',
#   '8월',
#   '이후',
#   '처음',
#   '130',
#   '130포인트',
#   '포인트',
#   '도달',
#   '최근',
#   '코로나',
#   '경기',
#   '상승세',
#   '전망',
#   '확실시',
#   '상황',
#   '기타',
#   '선주',
#   '주인',
#   '계속',
#   '삼성',
#   '삼성중공업',
#   '에버그린으로',
#   '20',
#   '20척',
#   '단일',
#   '계약',
#   '역대',
#   '최대',
#   '규모',
#   '중국',
#   '일본',
#   '조선회사',
#   '발주',
#   '예상',
#   '1000',
#   '1000억',
#   '2000',
#   '2000억원',
#   '계산',
#   '보세',
#   '도크',
#   '모습',
#   '하이',
#   '하이라인',
#   '라인',
#   '5척',
#   '4월',
#   '1일',
#   '3척',
#   '선박',
#   '7척',
#   '3사',
#   '카타르',
#   '100',
#   '100척',
#   '이것',
#   '본계약',
#   '세계',
#   '최고',
#   '수준',
#   '기술력',
#   '생산력',
#   '자랑',
#   '국뽕',
#   '1위',
#   '이마',
#   '이마바리조선',
#   '바리',
#   '관계자',
#   '일본경제신문',
#   '경제',
#   '신문',
#   '인터뷰',
#   '유럽',
#   '시찰',
#   '작업',
#   '작업효율',
#   '효율',
#   '측면',
#   '능가',
#   '경우',
#   '품질',
#   '문제',
#   '발생',
#   '부족',
#   '납기',
#   '납기일',
#   '비일비재',
#   '생산',
#   '생산설비',
#   '설비',
#   '업종',
#   '자체',
#   '쇠락',
#   '경쟁',
#   '대장',
#   '대장주',
#   '선전',
#   '기대',
#   '이유',
#   '프로',
#   '프로축구팀',
#   '축구팀',
#   '정승',
#   '정승현',
#   '조현우',
#   '현우',
#   '주총',
#   '디지털',
#   '혁신',
#   '밸류',
#   '밸류체인',
#   '체인',
#   '구축',
#   '요소',
#   '주가',
#   '도움',
#   '미래',
#   '전략',
#   '유럽연합',
#   '연합',
#   '기업',
#   '기업결합',
#   '6월',
#   '예정',
#   '결과',
#   '인수',
#   '재무',
#   '재무구조',
#   '구조',
#   '개선',
#   '유상',
#   '유상증자',
#   '증자',
#   '진행',
#   '계획',
#   '사람',
#   '매력적',
#   '주주',
#   '주주총회',
#   '총회',
#   '울산대학교',
#   '대학교',
#   '체육관',
#   '기업분할',
#   '분할',
#   '반대',
#   '노사',
#   '갈등',
#   '아수라장',
#   '송봉근',
#   '인도',
#   '2년',
#   '이상',
#   '중요',
#   '그것',
#   '실적',
#   '기여',
#   '필요',
#   '결론',
#   '6개월',
#   '개월',
#   '관련',
#   '대책',
#   '앤츠랩',
#   '콘텐츠',
#   '구독',
#   '관련기사1년',
#   '기사',
#   '3억',
#   '14',
#   '14억',
#   '전기차',
#   '기차',
#   '자율',
#   '자율주행',
#   '주행',
#   '이래',
#   '다음',
#   '우리',
#   '머스크',
#   '우주',
#   '관련주'],
#  ['현예',
#   '리뷰',
#   '106',
#   '영화',
#   '소녀',
#   '스포일러',
#   '요즘',
#   '인기',
#   '인기리',
#   '방영',
#   '드라마',
#   '역인',
#   '송중기',
#   '중기',
#   '배우',
#   '배우만큼',
#   '만큼',
#   '화제',
#   '캐릭터',
#   '전여',
#   '연기',
#   '홍차',
#   '홍차영',
#   '변호사',
#   '초기',
#   '부정확',
#   '발음',
#   '오버',
#   '혹평',
#   '회차',
#   '호평',
#   '독립',
#   '상업',
#   '상업영화',
#   '조연',
#   '단역',
#   '얼굴',
#   '오늘',
#   '소개',
#   '사람',
#   '각인',
#   '10',
#   '10대',
#   '심리',
#   '현대',
#   '사회',
#   '단면',
#   '덕분',
#   '지난해',
#   '제56회',
#   '56',
#   '대종상',
#   '영화제',
#   '신인',
#   '신인여자배우',
#   '여자',
#   '하루',
#   '하루아침',
#   '아침',
#   '친구',
#   '경민',
#   '전소니',
#   '소니',
#   '모든',
#   '어젯밤',
#   '마지막',
#   '영희',
#   '의심',
#   '사진',
#   '아트',
#   '아트하우스',
#   '하우스',
#   '형사',
#   '조사',
#   '학교',
#   '나름',
#   '담임',
#   '선생님',
#   '아이',
#   '이것저것',
#   '그중',
#   '유서',
#   '시신',
#   '발견',
#   '실종',
#   '상태',
#   '가해자',
#   '폭행까지',
#   '사건',
#   '성과',
#   '속이',
#   '행방',
#   '행방불명',
#   '불명',
#   '이유',
#   '경민의',
#   '민의',
#   '엄마',
#   '화살',
#   '수색',
#   '종료',
#   '이야기',
#   '때쯤',
#   '강가',
#   '장례식',
#   '궁지',
#   '자신',
#   '결백',
#   '증명',
#   '극단적',
#   '선택',
#   '목숨',
#   '이제',
#   '사이',
#   '해자',
#   '피해자',
#   '경민의',
#   '한솔',
#   '고원희',
#   '원희',
#   '속사정',
#   '용서',
#   '치료',
#   '목소리',
#   '소리',
#   '그녀',
#   '수화',
#   '여기',
#   '시작',
#   '장면',
#   '전반부',
#   '후반부',
#   '반복',
#   '자막',
#   '여부',
#   '무엇',
#   '소름',
#   '손짓',
#   '박수',
#   '모습',
#   '경악',
#   '만약',
#   '이해',
#   '흐름',
#   '여고생',
#   '대다수',
#   '군중',
#   '군중심리',
#   '있습니다',
#   '치부',
#   '눈길',
#   '한번',
#   '이후',
#   '미안',
#   '사과',
#   '내기',
#   '어른',
#   '이기심',
#   '호칭',
#   '만큼',
#   '노력',
#   '눈곱',
#   '치도',
#   '성적',
#   '공부',
#   '소란',
#   '서로',
#   '잔인',
#   '왼쪽',
#   '김의석',
#   '의석',
#   '감독',
#   '오른쪽',
#   '시나리',
#   '직접',
#   '자전',
#   '이야기임',
#   '자책',
#   '스토리',
#   '사실',
#   '그때',
#   '죽음',
#   '정도',
#   '생각',
#   '인정',
#   '느낌',
#   '의외',
#   '인물',
#   '음악',
#   '음악감독',
#   '과거',
#   '기억',
#   '등장',
#   '가수',
#   '선우',
#   '선우정아',
#   '정아',
#   '처음',
#   '장편',
#   '장편영화',
#   '곳곳',
#   '출연',
#   '포스터',
#   '각본',
#   '서영화',
#   '이태',
#   '이태경',
#   '유재명',
#   '재명',
#   '현우',
#   '장르',
#   '미스터',
#   '미스터리',
#   '상영',
#   '상영시간',
#   '시간',
#   '113',
#   '113분',
#   '등급',
#   '15',
#   '15세',
#   '관람',
#   '관람가',
#   '개봉',
#   '개봉일',
#   '2018',
#   '2018년',
#   '9월',
#   '13',
#   '13일',
#   '관련',
#   '관련기사',
#   '기사',
#   '당신',
#   '인생',
#   '행복',
#   '재현',
#   '명망',
#   '시니어',
#   '케어',
#   '기업',
#   '여성',
#   '12',
#   '12살',
#   '불량',
#   '꼬마',
#   '전직',
#   '매춘부',
#   '사랑'],
#  ['서울',
#   '지하철',
#   '동대문',
#   '동대문역',
#   '1번',
#   '출구',
#   '골목',
#   '언덕배기',
#   '봉제',
#   '공장',
#   '지금',
#   '쇠락',
#   '모습',
#   '과거',
#   '패션',
#   '메카',
#   '영광',
#   '거리',
#   '원단',
#   '의상',
#   '오토바이',
#   '소리',
#   '끝자락',
#   '역사관',
#   '사관',
#   '국내',
#   '의류',
#   '봉제산업',
#   '산업',
#   '역사',
#   '가치',
#   '조명',
#   '이곳',
#   '3층',
#   '전시실',
#   '무명천',
#   '드레스',
#   '마네킹',
#   '색도',
#   '디자인',
#   '실루엣',
#   '실루엣만큼',
#   '만큼',
#   '눈길',
#   '최초',
#   '양장',
#   '부문',
#   '패턴',
#   '명장',
#   '선정',
#   '67',
#   '패턴사의',
#   '사의',
#   '작품',
#   '24',
#   '24일',
#   '오후',
#   '종로',
#   '종로구',
#   '중앙',
#   '중앙일보',
#   '일보',
#   '인터뷰',
#   '장진영',
#   '진영',
#   '기자',
#   '입체',
#   '모델',
#   '모델리스트',
#   '리스트',
#   '설계자',
#   '지난해',
#   '10',
#   '10월',
#   '내달',
#   '30',
#   '30일',
#   '진행',
#   '기획',
#   '전시',
#   '입체패턴',
#   '선구자',
#   '대한',
#   '대한민국',
#   '민국',
#   '그동안',
#   '업계',
#   '패턴사',
#   '재단사',
#   '역할',
#   '의미',
#   '디자이너',
#   '구성',
#   '바탕',
#   '인체',
#   '사이즈',
#   '체형',
#   '반영',
#   '마름질',
#   '사람',
#   '실제',
#   '구현',
#   '설계사',
#   '그중',
#   '전문가',
#   '평면',
#   '종이',
#   '옷본',
#   '신체',
#   '곡선',
#   '옷감',
#   '특성',
#   '고등',
#   '고등학교',
#   '학교',
#   '졸업',
#   '명동',
#   '국제',
#   '국제복장학원',
#   '복장',
#   '학원',
#   '1974',
#   '1974년',
#   '1973',
#   '1973년',
#   '회사',
#   '신원',
#   '우리',
#   '우리나라',
#   '나라',
#   '기성복',
#   '태생',
#   '당시',
#   '양장점',
#   '시절',
#   '의상실',
#   '개념',
#   '잡지',
#   '보고',
#   '패턴사가',
#   '사가',
#   '회상',
#   '표면',
#   '부착',
#   '수정',
#   '방식',
#   '소재',
#   '특징',
#   '사진',
#   '이후',
#   '10여년간',
#   '안정적',
#   '세미나',
#   '이야기',
#   '시대',
#   '확신',
#   '1982',
#   '1982년',
#   '일본',
#   '유학길',
#   '도쿄',
#   '디자인연구소',
#   '연구소',
#   '공부',
#   '1984',
#   '1984년',
#   '입체패턴연구소',
#   '제일',
#   '제일모직',
#   '모직',
#   '업체',
#   '기술',
#   '지도',
#   '후배',
#   '양성',
#   '열정적',
#   '1997',
#   '1997년',
#   '1회',
#   '패션위크',
#   '위크',
#   '전시회',
#   '10점',
#   '출품',
#   '패션계',
#   '주목',
#   '2004',
#   '2004년',
#   '대통령령',
#   '패션디자인',
#   '379',
#   '379호',
#   '자격',
#   '최초이자',
#   '이자',
#   '유일한',
#   '선구자이자',
#   '디자인만큼',
#   '중요',
#   '세계적',
#   '이유',
#   '불편',
#   '형태',
#   '생각',
#   '경우',
#   '문제',
#   '문제라기',
#   '중요하다',
#   '하다',
#   '강조',
#   '대우',
#   '숙련',
#   '기술인',
#   '현실',
#   '해외',
#   '출신',
#   '프랑스',
#   '여성복',
#   '브랜드',
#   '아가',
#   '대표적',
#   '자신',
#   '독특',
#   '창조',
#   '하나',
#   '이해',
#   '부족',
#   '때문',
#   '지적',
#   '기준',
#   '바지',
#   '옆선',
#   '엉덩이',
#   '허벅지',
#   '한국인',
#   '6.5',
#   '6.5등신',
#   '등신',
#   '평균',
#   '최근',
#   '7.5',
#   '7.5등신',
#   '정장',
#   '스웨트셔츠',
#   '청바지',
#   '티셔츠',
#   '캐주얼',
#   '대중적',
#   '인기',
#   '중요성',
#   '룩일수록',
#   '수록',
#   '요즘',
#   '오버',
#   '오버핏',
#   '경향',
#   '스타일',
#   '얼마',
#   '신세계',
#   '신세계인터내셔날',
#   '인터내셔날',
#   '온라인',
#   '전용',
#   '먼스',
#   '협업',
#   '작업',
#   '10개월간',
#   '개월',
#   '기본',
#   '아이템',
#   '무엇',
#   '편안',
#   '필요',
#   '명장의',
#   '장의',
#   '노하우',
#   '마스터',
#   '슈트',
#   '텐먼스',
#   '대표',
#   '상품',
#   '상품이자',
#   '지난달',
#   '22',
#   '22일',
#   '론칭',
#   '남성복',
#   '손길',
#   '모든',
#   '전문',
#   '마스터핏',
#   '40',
#   '40년간',
#   '안감',
#   '조언',
#   '명품',
#   '마무리',
#   '엉망',
#   '움직임',
#   '불편하다',
#   '온라인상',
#   '옷걸이',
#   '걸이',
#   '전체적',
#   '말미',
#   '한국',
#   '증인',
#   '예전',
#   '시장',
#   '중국',
#   '광저우',
#   '인력',
#   '기술자',
#   '연령',
#   '추세',
#   '인프라',
#   '성장',
#   '기대',
#   '유지연',
#   '지연',
#   '관련',
#   '관련기사명품',
#   '기사',
#   '르메스',
#   '메스',
#   '600',
#   '600만원',
#   '버섯',
#   '가방',
#   '공개',
#   '비건',
#   '열광',
#   '시계도',
#   '당신',
#   '회색',
#   '츄리닝',
#   '여심',
#   '코로나',
#   '공주',
#   '원피스'],
#  ['현대',
#   '현대차',
#   '번째',
#   '전용',
#   '전기차',
#   '기차',
#   '아이오',
#   '아이오닉5',
#   '사진',
#   '2월',
#   '글로벌',
#   '판매',
#   '급증',
#   '전통적',
#   '비수기',
#   '수요',
#   '세계',
#   '모든',
#   '시장',
#   '폭등',
#   '시장조사기관',
#   '조사',
#   '기관',
#   '볼륨',
#   '볼륨즈',
#   '포함',
#   '대수',
#   '27',
#   '27만8000대',
#   '8000',
#   '잠정',
#   '집계',
#   '2일',
#   '지난해',
#   '2배',
#   '이상',
#   '수치',
#   '기간',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '자동차',
#   '감소분',
#   '고려',
#   '상승세',
#   '2019',
#   '2019년',
#   '기준',
#   '155',
#   '증가',
#   '판매량',
#   '바탕',
#   '올해',
#   '600',
#   '600만대',
#   '전인',
#   '1월',
#   '추정',
#   '460',
#   '460만대',
#   '30',
#   '350',
#   '350만대',
#   '국가',
#   '중국',
#   '미국',
#   '유럽',
#   '각국',
#   '전기',
#   '달간',
#   '10',
#   '10만7797대',
#   '7797',
#   '38',
#   '차지',
#   '독일',
#   '여대',
#   '3만4000여',
#   '4000',
#   '프랑스',
#   '1만8000대',
#   '노르웨이',
#   '8000여대',
#   '한국',
#   '5456',
#   '5456대',
#   '26.7',
#   '국가별',
#   '모델',
#   '모델별',
#   '테슬라',
#   '보급',
#   '보급형',
#   '2만8000여대',
#   '1위',
#   '상하이',
#   '우링',
#   '소형',
#   '미니',
#   '2만대',
#   '1만4000여',
#   '대로',
#   '상하이기가팩토리',
#   '기가',
#   '팩토리',
#   '양산',
#   '안착',
#   '모양새',
#   '7월',
#   '이후',
#   '출시',
#   '포드',
#   '브랜드',
#   '머스탱',
#   '마하',
#   '성장세',
#   '시작',
#   '298',
#   '298대',
#   '4023',
#   '4023대',
#   '신형',
#   '폴크스바겐',
#   '크스',
#   '바겐',
#   '피아트',
#   '아트',
#   '500',
#   '6가',
#   '하반기',
#   '공세',
#   '보조금',
#   '정책',
#   '연초',
#   '2분기',
#   '분기',
#   '반도체',
#   '품귀',
#   '현상',
#   '부품',
#   '공급',
#   '차질',
#   '걸림돌',
#   '전망',
#   '실적',
#   '확산',
#   '원재료',
#   '가격',
#   '상승',
#   '일본',
#   '사스',
#   '제조사',
#   '화재',
#   '화재사고',
#   '사고',
#   '성장',
#   '마이너스',
#   '요인',
#   '공존',
#   '영향',
#   '업계',
#   '차량',
#   '반도',
#   '반도체인',
#   '체인',
#   '마이크',
#   '컨트롤러',
#   '유닛',
#   '특정',
#   '시스템',
#   '제어',
#   '프로세서',
#   '예년',
#   '최소',
#   '15',
#   '유통',
#   '이달',
#   '웃돈',
#   '정도',
#   '도요타',
#   '요타',
#   '감산',
#   '계획',
#   '발표',
#   '마킷',
#   '1분기',
#   '부족',
#   '생산',
#   '감소',
#   '130',
#   '130만대',
#   '추산',
#   '원가',
#   '리튬',
#   '리튬이온',
#   '이온',
#   '이차',
#   '이차전지',
#   '전지',
#   '런던',
#   '금속',
#   '금속거래소',
#   '거래소',
#   '니켈',
#   '1㎏당',
#   '18.5',
#   '18.5달러',
#   '달러',
#   '62',
#   '코발트',
#   '75',
#   '이항구',
#   '항구',
#   '한국자동차연구원',
#   '연구원',
#   '선임',
#   '선임연구위원',
#   '연구',
#   '위원',
#   '측면',
#   '원년',
#   '완성',
#   '완성차업체',
#   '업체',
#   '우선',
#   '때문',
#   '500만대',
#   '난관',
#   '소매',
#   '아이오닉5가',
#   '모터',
#   '7일',
#   '울산',
#   '1공장',
#   '가동',
#   '중단',
#   '하루',
#   '400',
#   '400대',
#   '평균',
#   '9000',
#   '9000대',
#   '예정',
#   '익명',
#   '요구',
#   '관계자',
#   '4월',
#   '대수가',
#   '수가',
#   '당초',
#   '3분',
#   '관련',
#   '관련기사반도체',
#   '기사',
#   '대란',
#   '공장',
#   '재가동',
#   '시일',
#   '결국',
#   '1주일',
#   '주일',
#   '김영주',
#   '영주',
#   '기자'],
#  ['기아',
#   '조지아',
#   '애틀란타',
#   '란타',
#   '공장',
#   '자료',
#   '자료사진',
#   '사진',
#   '중앙',
#   '중앙포토',
#   '포토',
#   '기아자',
#   '기아자동차',
#   '동차',
#   '미국',
#   '조지',
#   '조지아주',
#   '아주',
#   '가동',
#   '이틀',
#   '동안',
#   '2일',
#   '현지',
#   '현지시간',
#   '시간',
#   '발표',
#   '세계적',
#   '차량',
#   '반도체',
#   '공급',
#   '부족',
#   '현상',
#   '때문',
#   '이날',
#   '로이터',
#   '로이터통신',
#   '통신',
#   '기아차',
#   '가동중단',
#   '중단',
#   '이유',
#   '이달',
#   '기간',
#   '지속',
#   '공급망',
#   '마련',
#   '설명',
#   '이번',
#   '결정',
#   '최근',
#   '품귀',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '가전',
#   '가전제품',
#   '제품',
#   '수요',
#   '완성',
#   '완성차',
#   '업체',
#   '생산',
#   '차질',
#   '24',
#   '24일',
#   '제너럴',
#   '제너럴모터스',
#   '모터스',
#   '감산',
#   '연간',
#   '이익',
#   '2조3000억',
#   '3000',
#   '전망',
#   '원석',
#   '기자'],
#  ['백화점',
#   '미술계',
#   '큰손',
#   '신세계',
#   '신세계백화점',
#   '강남',
#   '매장',
#   '광주',
#   '텀시티',
#   '시티',
#   '신세계갤러리',
#   '갤러리',
#   '전시',
#   '수만',
#   '예술품',
#   '일한',
#   '작가',
#   '2000',
#   '2000여명',
#   '16',
#   '16년',
#   '큐레이터',
#   '오명란',
#   '명란',
#   '41',
#   '미술관',
#   '미술관팀',
#   '수석',
#   '수석큐레이터',
#   '이야기',
#   '잡썰',
#   '국내',
#   '역사',
#   '50',
#   '50여년',
#   '1969',
#   '1969년',
#   '본점',
#   '시초',
#   '현재',
#   '롯데',
#   '롯데백화점',
#   '각각',
#   '5곳',
#   '현대',
#   '현대백화점',
#   '6곳',
#   '운영',
#   '팀장',
#   '제외',
#   '팀원',
#   '20',
#   '20여명',
#   '큐레이터인',
#   '업계',
#   '최대',
#   '규모',
#   '그중',
#   '베테랑',
#   '300',
#   '300여회',
#   '통념',
#   '일상',
#   '우아함',
#   '아함',
#   '거리',
#   '하루',
#   '많으',
#   '수십',
#   '수십명',
#   '필요',
#   '작품',
#   '밤낮',
#   '전화기',
#   '도록',
#   '사진',
#   '예사',
#   '시간대',
#   '설치',
#   '현장',
#   '작업복',
#   '차림',
#   '인부',
#   '감독',
#   '취급',
#   '경우',
#   '직접',
#   '허드렛일',
#   '공립',
#   '시민',
#   '문화',
#   '목표',
#   '차별화',
#   '경험',
#   '제공',
#   '아트',
#   '마케팅',
#   '성격',
#   '일부',
#   '상업적',
#   '공간',
#   '의미',
#   '훼손',
#   '거부',
#   '영리',
#   '비영리',
#   '전문',
#   '전문성과',
#   '성과',
#   '대중성',
#   '사이',
#   '외줄',
#   '타기',
#   '작업',
#   '예술',
#   '사람',
#   '친숙',
#   '2011',
#   '2011년',
#   '전시실',
#   '지난해',
#   '3층',
#   '단장',
#   '명품',
#   '사이사이',
#   '판매',
#   '마련',
#   '맥락',
#   '반응',
#   '폭발적',
#   '손님',
#   '리뉴얼',
#   '28',
#   '28점',
#   '모습',
#   '브랜드',
#   '기획',
#   '내가',
#   '이해',
#   '마음가짐',
#   '미술',
#   '대중',
#   '간극',
#   '고민',
#   '테마',
#   '선정',
#   '감상',
#   '개념',
#   '테리',
#   '미술품',
#   '자연',
#   '설명',
#   '예술관',
#   '인간',
#   '위엄',
#   '기품',
#   '효용',
#   '가치',
#   '예술가',
#   '자신',
#   '시대',
#   '통찰',
#   '자기',
#   '방식',
#   '해석',
#   '처음',
#   '김환기',
#   '천경자',
#   '경자',
#   '가슴',
#   '조르조',
#   '모란',
#   '모란디',
#   '근대',
#   '이탈리아',
#   '화가',
#   '피터',
#   '피터르',
#   '브뤼',
#   '르네상스',
#   '플랑',
#   '시간',
#   '동안',
#   '짝사랑',
#   '표현',
#   '20세기',
#   '세기',
#   '정물화',
#   '하나',
#   '빌바오',
#   '구겐하임',
#   '요즘',
#   '대전',
#   '대전신세계갤러리',
#   '개관',
#   '준비',
#   '정신',
#   '2005',
#   '2005년',
#   '입사',
#   '당시',
#   '지금',
#   '상상',
#   '석사',
#   '논문',
#   '도전',
#   '시작',
#   '공부',
#   '덕업',
#   '덕업일치',
#   '일치',
#   '직업',
#   '신조어',
#   '만족',
#   '중요',
#   '중요하다',
#   '하다',
#   '지론',
#   '때문',
#   '생각',
#   '자체',
#   '그것',
#   '관심',
#   '이병',
#   '기자',
#   '관련',
#   '관련기사일년',
#   '기사',
#   '산다',
#   '자취생',
#   '아빠',
#   '남자',
#   '11',
#   '11년',
#   '아기',
#   '아기똥',
#   '카레',
#   '프로',
#   '절대',
#   '18',
#   '18년간',
#   '5000',
#   '5000번',
#   '매일',
#   '놀이',
#   '놀이기구',
#   '기구'],
#  ['최용준',
#   '절세',
#   '기술',
#   '79',
#   '15',
#   '15년',
#   '농지',
#   '상속',
#   '김씨',
#   '고향',
#   '부모님',
#   '농사',
#   '그동안',
#   '제안',
#   '처분',
#   '지금',
#   '보유',
#   '이번',
#   '정부',
#   '발표',
#   '양도',
#   '부담',
#   '소식',
#   '걱정',
#   '3월',
#   '29',
#   '29일',
#   '부동산',
#   '투기',
#   '투기근절',
#   '근절',
#   '재발',
#   '재발방지대책',
#   '방지',
#   '대책',
#   '사태',
#   '계기',
#   '토지',
#   '불법',
#   '다양',
#   '조치',
#   '문제',
#   '토지거래',
#   '거래',
#   '기대',
#   '기대수익',
#   '수익',
#   '축소',
#   '명분',
#   '비사업',
#   '사업',
#   '부분',
#   '현재',
#   '변화',
#   '각별',
#   '주의',
#   '필요',
#   '경작',
#   '배우자',
#   '8년',
#   '이상',
#   '자경',
#   '증여',
#   '해당',
#   '경우',
#   '양도세',
#   '대비',
#   '사진',
#   '본래',
#   '목적',
#   '사용',
#   '세법',
#   '일종',
#   '간주',
#   '일반',
#   '양도세율',
#   '세율',
#   '45',
#   '10',
#   '포인트',
#   '16',
#   '55',
#   '중과세',
#   '과세',
#   '3년',
#   '양도차익',
#   '차익',
#   '30',
#   '장기',
#   '장기보유공제',
#   '공제',
#   '요건',
#   '동시',
#   '거주',
#   '직선',
#   '직선거리',
#   '거리',
#   '30㎞',
#   '이내',
#   '농작물',
#   '재배',
#   '상시',
#   '종사',
#   '배제',
#   '예외',
#   '촌자경',
#   '공익',
#   '공익사업',
#   '관련',
#   '토지보상',
#   '보상',
#   '사업인정고시일로',
#   '인정',
#   '고시',
#   '일로',
#   '2년',
#   '이전',
#   '취득',
#   '1000',
#   '1000㎡',
#   '주말',
#   '주말농장',
#   '농장',
#   '양도세가',
#   '세가',
#   '내년',
#   '예정',
#   '가산',
#   '20',
#   '26',
#   '65',
#   '적용',
#   '구체적',
#   '계산',
#   '2억원',
#   '8억원',
#   '6억원',
#   '1억',
#   '8000',
#   '8000만원',
#   '중과',
#   '중과세율',
#   '지방',
#   '지방소득세',
#   '소득세',
#   '포함',
#   '양도세로',
#   '세로',
#   '3억',
#   '7000',
#   '7000만원',
#   '내야',
#   '세금',
#   '6700',
#   '6700만원',
#   '1.8',
#   '1.8배',
#   '염두',
#   '때문',
#   '사업인정고시일',
#   '농지도',
#   '지도',
#   '5년',
#   '범위',
#   '올해',
#   '계획',
#   '대책일',
#   '이대',
#   '개정',
#   '부작용',
#   '지적도',
#   '일부',
#   '완화',
#   '가능성',
#   '만일',
#   '강행',
#   '만큼',
#   '당초',
#   '사유',
#   '장기적',
#   '관점',
#   '미래',
#   '미래가치',
#   '가치',
#   '고려',
#   '계속',
#   '상황',
#   '향후',
#   '가족',
#   '생각',
#   '오래전',
#   '당시',
#   '취득가액',
#   '가액',
#   '이유',
#   '상속일로',
#   '세무사',
#   '관련기사',
#   '기사',
#   '사람',
#   '증여세',
#   '절약',
#   '아들',
#   '주택',
#   '아버지',
#   '국세청',
#   '조사',
#   '부모',
#   '자녀',
#   '전세',
#   '계약'],
#  ['암호',
#   '암호화폐',
#   '화폐',
#   '대명',
#   '대명사인',
#   '사인',
#   '비트',
#   '비트코인',
#   '최고가',
#   '돌파',
#   '시도',
#   '2일',
#   '사이트',
#   '코인데스크',
#   '데스크',
#   '비트코',
#   '가격',
#   '이날',
#   '오후',
#   '9시',
#   '기준',
#   '5만9600달러',
#   '9600',
#   '달러',
#   '6729',
#   '6729만원',
#   '거래',
#   '1주일',
#   '주일',
#   '14',
#   '가량',
#   '25',
#   '25일',
#   '5만1000선',
#   '1000',
#   '이후',
#   '오름세',
#   '6만',
#   '6774',
#   '6774만원',
#   '전후',
#   '등락',
#   '중이',
#   '역대',
#   '지난달',
#   '14일',
#   '6만1556달러',
#   '1556',
#   '달러',
#   '전문가',
#   '상승세',
#   '시작',
#   '뉴스',
#   '뉴스1',
#   '골드만',
#   '2분기',
#   '분기',
#   '투자',
#   '제안',
#   '계획',
#   '급등',
#   '글로벌',
#   '기관',
#   '투자가',
#   '시장',
#   '영향',
#   '분석',
#   '불법',
#   '취급',
#   '제도권',
#   '의미',
#   '신용',
#   '신용카드',
#   '카드',
#   '업체',
#   '비자',
#   '29',
#   '29일',
#   '현지',
#   '현지시간',
#   '시간',
#   '결제',
#   '수단',
#   '스테이',
#   '코인',
#   '하나',
#   '하나인',
#   '시범',
#   '포함',
#   '코인은',
#   '인은',
#   '기존',
#   '등에',
#   '가치',
#   '고정',
#   '변동성',
#   '가상',
#   '가상화폐',
#   '달러화',
#   '이튿날',
#   '30',
#   '30일',
#   '미국',
#   '온라인',
#   '결제업체',
#   '페이팔',
#   '거주자',
#   '대상',
#   '활용',
#   '구매',
#   '허용',
#   '2600',
#   '개의',
#   '가맹점',
#   '물건',
#   '여기',
#   '월가',
#   '최대',
#   '투자은행',
#   '은행',
#   '골드',
#   '골드만삭스의',
#   '만삭',
#   '스의',
#   '방침',
#   '상승',
#   '기름',
#   '31',
#   '31일',
#   '골드만삭',
#   '올해',
#   '투자상품',
#   '상품',
#   '메리',
#   '리치',
#   '신임',
#   '지털',
#   '자산',
#   '대표',
#   '인터뷰',
#   '자산관리',
#   '관리',
#   '투자자산',
#   '2500',
#   '2500만',
#   '282',
#   '282억4000만',
#   '4000',
#   '이상',
#   '고객',
#   '암호화',
#   '인플레이션',
#   '물가',
#   '이번',
#   '결정',
#   '요청',
#   '대형',
#   '로이',
#   '큰손',
#   '참여로',
#   '수요',
#   '급증',
#   '모건',
#   '모건스탠리',
#   '스탠리',
#   '이달',
#   '고액',
#   '자산가',
#   '상대',
#   '출시',
#   '예고',
#   '골드만삭스도',
#   '스도',
#   '대열',
#   '합류',
#   '1일',
#   '로이터',
#   '로이터통신',
#   '통신',
#   '신탁',
#   '신탁상품',
#   '트러스트',
#   '선물',
#   '관련',
#   '투자전략',
#   '전략',
#   '변경',
#   '외신',
#   '대체',
#   '보도',
#   '경제',
#   '경제매체',
#   '매체',
#   '최고',
#   '최고투자책임자',
#   '책임자',
#   '전략가',
#   '100',
#   '100명',
#   '설문',
#   '응답자',
#   '41',
#   '인식',
#   '양상',
#   '크리스',
#   '크리스티나',
#   '티나',
#   '오르기',
#   '오르기예바',
#   '국제',
#   '국제통화기금',
#   '통화',
#   '기금',
#   '총재',
#   '투자자로',
#   '자로',
#   '신뢰',
#   '하나',
#   '다수',
#   '국가',
#   '정부',
#   '당국',
#   '회의적',
#   '파월',
#   '연방',
#   '연방준비제도',
#   '준비',
#   '제도',
#   '의장',
#   '재닛',
#   '재무',
#   '재무장관',
#   '장관',
#   '비트코인은',
#   '투기성',
#   '입장',
#   '황의',
#   '황의영',
#   '기자',
#   '관련기사비트코',
#   '기사',
#   '7400',
#   '7400만원선',
#   '하루',
#   '경신',
#   '세금',
#   '폭탄',
#   '머스크',
#   '약발',
#   '투기',
#   '투기자산',
#   '공격',
#   '리스크'],
#  ['올해',
#   '공동',
#   '공동주택',
#   '주택',
#   '공시',
#   '공시가격',
#   '가격',
#   '1위',
#   '크기',
#   '층간',
#   '격차',
#   '최대',
#   '40',
#   '40억원',
#   '서울',
#   '강남',
#   '강남구',
#   '청담',
#   '청담동',
#   '펜트하우스청담',
#   '트하우스',
#   '청담',
#   '뉴시스',
#   '시스',
#   '배우',
#   '장동',
#   '장동건과',
#   '건과',
#   '골프',
#   '골프선수',
#   '선수',
#   '아파트',
#   '지난해',
#   '준공',
#   '20',
#   '20층',
#   '1개',
#   '29',
#   '29가구',
#   '가구',
#   '빌라',
#   '소규모',
#   '단지',
#   '2개층',
#   '개층',
#   '407',
#   '407㎡',
#   '이하',
#   '전용',
#   '전용면적',
#   '면적',
#   '펜트',
#   '펜트하우스',
#   '하우스',
#   '2가구',
#   '제외',
#   '나머지',
#   '27',
#   '27가구',
#   '273',
#   '273㎡로',
#   '3가구',
#   '장동건',
#   '비가',
#   '집도',
#   '273㎡',
#   '안장원',
#   '장원',
#   '부동산',
#   '부동산노트',
#   '노트',
#   '공시가',
#   '43',
#   '43억원',
#   '한강',
#   '조망',
#   '반영',
#   '가치',
#   '지적도',
#   '예상',
#   '보유세',
#   '재산',
#   '종부세',
#   '부세',
#   '1주택',
#   '보유',
#   '기준',
#   '1억원가량',
#   '가량',
#   '차이',
#   '세무사',
#   '의뢰',
#   '추정',
#   '결과',
#   '장동건',
#   '동건',
#   '집이',
#   '1억8700만',
#   '8700',
#   '8700만원',
#   '대부분',
#   '재산세',
#   '3500',
#   '3500만원',
#   '2100',
#   '2100만원',
#   '종부',
#   '종부세가',
#   '세가',
#   '1억5200만',
#   '5200',
#   '6600',
#   '6600만원',
#   '14',
#   '14층',
#   '40억원가량',
#   '57',
#   '57억93000만',
#   '93000',
#   '97',
#   '97억1000만',
#   '1000',
#   '라인',
#   '본지',
#   '공시가격안',
#   '조사',
#   '역대',
#   '18',
#   '18층',
#   '2층',
#   '73',
#   '43억2400만',
#   '2400',
#   '1억1000만',
#   '4억9000만',
#   '9000',
#   '6억5300만',
#   '5300',
#   '아래',
#   '층간은',
#   '간은',
#   '1000만',
#   '1500',
#   '1500만원',
#   '한국',
#   '한국부동산원',
#   '관계자',
#   '분양가',
#   '양가',
#   '산정',
#   '분양',
#   '영향',
#   '영동',
#   '영동대교',
#   '대교',
#   '남단',
#   '북쪽',
#   '고층',
#   '현실화',
#   '적용',
#   '시세',
#   '저층',
#   '50',
#   '50억원',
#   '정도',
#   '조금',
#   '1억7000만',
#   '7000',
#   '400',
#   '400여만원',
#   '그래픽',
#   '기자',
#   '위치',
#   '남쪽',
#   '강북',
#   '청담대교',
#   '북단',
#   '광진',
#   '광진구',
#   '자양',
#   '자양동',
#   '광진트라팰리스',
#   '트라',
#   '팰리스',
#   '169',
#   '169㎡도',
#   '위층',
#   '28',
#   '28층',
#   '아래층',
#   '15',
#   '15억9600만',
#   '9600',
#   '10',
#   '10억1400만',
#   '1400',
#   '용산',
#   '용산구',
#   '산구',
#   '이촌',
#   '이촌동',
#   '래미',
#   '래미안첼리',
#   '투스',
#   '124',
#   '124㎡',
#   '21',
#   '21억6300만',
#   '6300',
#   '56',
#   '56층',
#   '27억9800만',
#   '9800',
#   '30',
#   '실제',
#   '거래',
#   '거래가격',
#   '12',
#   '12월',
#   '35',
#   '35층',
#   '36',
#   '36억5000만',
#   '5000',
#   '29억원',
#   '26',
#   '꼭대기',
#   '초구',
#   '반포',
#   '반포동',
#   '래미안퍼스',
#   '퍼스',
#   '222',
#   '222㎡의',
#   '경우',
#   '1층',
#   '26층',
#   '11',
#   '4억원',
#   '남산',
#   '상당',
#   '중구',
#   '남대',
#   '남대문로5',
#   '문로',
#   '남산트라팰리스',
#   '148',
#   '148㎡',
#   '36층',
#   '13',
#   '13억600만',
#   '600',
#   '3층',
#   '10억1500만',
#   '아파트인',
#   '용산',
#   '용산구',
#   '중앙',
#   '중앙포토',
#   '포토',
#   '강변',
#   '최근',
#   '2017',
#   '2017년',
#   '비교',
#   '47',
#   '52',
#   '상승',
#   '상승률',
#   '정부',
#   '70',
#   '고가',
#   '해운대',
#   '엘시티',
#   '시티',
#   '10억원',
#   '부산',
#   '해운대해수욕장',
#   '해수욕장',
#   '국내',
#   '85',
#   '85층',
#   '앞바다',
#   '186',
#   '186㎡',
#   '9층',
#   '13억7400만',
#   '7400',
#   '83',
#   '83층',
#   '20억8500만',
#   '8500',
#   '7월',
#   '31',
#   '31층',
#   '25',
#   '25억원',
#   '9월',
#   '60',
#   '60층',
#   '35억원',
#   '조망이',
#   '망이',
#   '초고층',
#   '지적',
#   '주변',
#   '상지리츠',
#   '지리',
#   '카일룸2차',
#   '일룸',
#   '인근',
#   '상지',
#   '상지카일룸',
#   '23',
#   '10위',
#   '마크힐스',
#   '19',
#   '19층',
#   '업계',
#   '주인',
#   '이의',
#   '제기'],
#  ['공매도',
#   '세력',
#   '상대',
#   '게임',
#   '게임스톱',
#   '스톱',
#   '주식',
#   '개미',
#   '반란',
#   '키스',
#   '유튜브',
#   '튜브',
#   '캡처',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '미국',
#   '증시',
#   '1분기',
#   '분기',
#   '개인',
#   '개인투자자',
#   '투자자',
#   '치열',
#   '전투',
#   '거대',
#   '주도',
#   '개인투자가',
#   '투자가',
#   '34',
#   '3980',
#   '3980만',
#   '달러',
#   '한화',
#   '450',
#   '450억원',
#   '계좌',
#   '인증',
#   '2일',
#   '마켓워치',
#   '보유',
#   '가치',
#   '1900',
#   '1900만',
#   '214',
#   '214억',
#   '관련',
#   '옵션',
#   '890',
#   '890만',
#   '100',
#   '100억',
#   '별도',
#   '주식계좌',
#   '1190',
#   '1190만',
#   '134',
#   '134억',
#   '현금',
#   '확인',
#   '총액',
#   '공개',
#   '인터넷',
#   '2019',
#   '2019년',
#   '6월',
#   '5만3000',
#   '3000',
#   '5900',
#   '5900만',
#   '게임스',
#   '투자',
#   '이후',
#   '레딧',
#   '주식토론방인',
#   '토론',
#   '방인',
#   '월스',
#   '베츠',
#   '자신',
#   '채널',
#   '링키티',
#   '펀드',
#   '종목',
#   '성적',
#   '수천만',
#   '수익',
#   '분석',
#   '2월',
#   '중순',
#   '주가',
#   '폭등',
#   '폭등세',
#   '급락',
#   '하루',
#   '동안',
#   '1000',
#   '1000만',
#   '위기',
#   '지난해',
#   '11',
#   '11월',
#   '10',
#   '10달러',
#   '올해',
#   '1월',
#   '28',
#   '28일',
#   '483',
#   '483달러',
#   '48',
#   '48배',
#   '급등',
#   '3일',
#   '현재',
#   '가격',
#   '191.45',
#   '191.45달러',
#   '달러',
#   '대학',
#   '재학',
#   '장거리',
#   '달리기',
#   '선수',
#   '활약',
#   '최근',
#   '월스트리트저널',
#   '스트리트',
#   '저널',
#   '과의',
#   '인터뷰',
#   '고향',
#   '실내',
#   '트랙',
#   '급등락',
#   '등락',
#   '가운데',
#   '손실',
#   '대장',
#   '실현',
#   '도덕적',
#   '논란',
#   '제기',
#   '의견',
#   '이해',
#   '기자'],
#  ['중국',
#   '테슬라',
#   '매장',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '미국',
#   '전기차회사',
#   '기차',
#   '회사',
#   '시장',
#   '전망',
#   '실적',
#   '2일',
#   '현지',
#   '현지시간',
#   '시간',
#   '올해',
#   '1분기',
#   '분기',
#   '세계',
#   '18',
#   '18만4800대',
#   '4800',
#   '고객',
#   '인도',
#   '방송',
#   '통신',
#   '지난해',
#   '8만8400대',
#   '8400',
#   '2배',
#   '이상',
#   '급증',
#   '수치',
#   '직전',
#   '작년',
#   '4분기',
#   '18만570대',
#   '570',
#   '소폭',
#   '증가',
#   '도량',
#   '금융',
#   '금융정보업체',
#   '정보',
#   '업체',
#   '팩트셋',
#   '집계',
#   '전문가',
#   '16',
#   '16만8000대',
#   '8000',
#   '대부분',
#   '모델',
#   '모델3과',
#   '2000',
#   '2000대',
#   '가량',
#   '이날',
#   '성명',
#   '호평',
#   '고무적',
#   '수요',
#   '생산',
#   '능력',
#   '신규',
#   '장비',
#   '설치',
#   '테스트',
#   '파격적',
#   '호응',
#   '생산량',
#   '확대',
#   '초기',
#   '단계',
#   '고객인도',
#   '글로벌',
#   '소비자',
#   '전기',
#   '전기차',
#   '측정',
#   '바로미터',
#   '이번',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '대유행',
#   '사태',
#   '상대적',
#   '고가',
#   '기자'],
#  ['대치',
#   '대치동',
#   '최초',
#   '1000',
#   '1000억원',
#   '매출',
#   '학원',
#   '등장',
#   '자본력',
#   '콘텐트',
#   '텐트',
#   '경쟁력',
#   '좌우',
#   '학원가',
#   '부익부',
#   '빈익빈',
#   '시대',
#   '서울',
#   '학생',
#   '발걸음',
#   '사진',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '경기',
#   '업종',
#   '폐업',
#   '속출',
#   '코로나',
#   '코로나19',
#   '19',
#   '여파',
#   '집합',
#   '집합금지',
#   '금지',
#   '명령',
#   '지난해',
#   '80',
#   '80일',
#   '서울시',
#   '서울시교육청',
#   '교육청',
#   '강남',
#   '강남구',
#   '235',
#   '235곳',
#   '개업',
#   '228',
#   '228곳',
#   '추월',
#   '사교육',
#   '1번지',
#   '번지',
#   '예외',
#   '고등',
#   '단과',
#   '단과시장',
#   '시장',
#   '기준',
#   '7위권',
#   '위권',
#   '업체',
#   '이상',
#   '경쟁',
#   '경쟁학원',
#   '인수',
#   '동시',
#   '초대형',
#   '사업자',
#   '예고',
#   '업계',
#   '1위',
#   '시대인',
#   '시대인재학원',
#   '이하',
#   '시대인재',
#   '인재',
#   '임원',
#   '내달',
#   '공시',
#   '매출액',
#   '1070',
#   '1070억원',
#   '수준',
#   '인터넷',
#   '인터넷강의',
#   '강의',
#   '인강',
#   '메가',
#   '메가스터디교육',
#   '스터디',
#   '교육',
#   '3143',
#   '3143억원',
#   '고등사업부',
#   '사업부',
#   '고지',
#   '현장',
#   '현장강의',
#   '처음',
#   '다음',
#   '수치',
#   '시대인재가',
#   '재가',
#   '대치',
#   '대치동의',
#   '동의',
#   '고등부',
#   '입시',
#   '입시학원',
#   '실적',
#   '경우',
#   '2018',
#   '2018년',
#   '90',
#   '90억원',
#   '추정',
#   '평균',
#   '75',
#   '75만원',
#   '소속',
#   '강사',
#   '바탕',
#   '추산',
#   '대부분',
#   '관련',
#   '주식',
#   '주식회사',
#   '회사',
#   '외부',
#   '외부감사',
#   '감사',
#   '법률',
#   '영업',
#   '영업실적',
#   '추산치가',
#   '치가',
#   '4위',
#   '해당',
#   '대성',
#   '대성학원',
#   '비전',
#   '비전21학원',
#   '21',
#   '2019',
#   '2019년',
#   '11',
#   '11월',
#   '재개',
#   '재수',
#   '재수종합반',
#   '종합',
#   '유명',
#   '강남',
#   '강남대성학원',
#   '3위',
#   '디지털',
#   '디지털대성',
#   '1406',
#   '1406억원',
#   '경영',
#   '진출',
#   '이번',
#   '고사',
#   '문제',
#   '하나',
#   '하나당',
#   '100',
#   '100만원',
#   '일부',
#   '기회',
#   '모색',
#   '7위',
#   '대전',
#   '해운대',
#   '제주',
#   '등에',
#   '캠퍼스',
#   '설립',
#   '결과',
#   '신통',
#   '모양새',
#   '지역',
#   '고교',
#   '내신',
#   '내신시험',
#   '시험',
#   '출제',
#   '경향',
#   '정보',
#   '진입',
#   '진입장벽',
#   '장벽',
#   '역할',
#   '기온',
#   '대전제일학원',
#   '제일',
#   '이사장',
#   '브랜드',
#   '2군데',
#   '군데',
#   '수강생',
#   '이탈',
#   '마찬가지',
#   '전국',
#   '명문',
#   '명문학원',
#   '설립자',
#   '모임',
#   '수험생',
#   '선호',
#   '중심',
#   '작용',
#   '대입',
#   '대입학원',
#   '관계자',
#   '과거',
#   '자리',
#   '강의실',
#   '확보',
#   '중요',
#   '그만큼',
#   '남북',
#   '700',
#   '동서',
#   '500',
#   '남짓',
#   '마아파트',
#   '아파트',
#   '입구',
#   '사거리',
#   '400',
#   '400곳',
#   '접근',
#   '공간',
#   '인기',
#   '섭외',
#   '임대업',
#   '정도',
#   '2010',
#   '2010년대',
#   '년대',
#   '자체',
#   '개발',
#   '모의고사',
#   '수능',
#   '수능시험',
#   '적중률',
#   '이듬해',
#   '능력',
#   '상황',
#   '형성',
#   '대입강사',
#   '가운데',
#   '수익',
#   '300',
#   '300억원',
#   '내외',
#   '메가스터디',
#   '수학',
#   '현우',
#   '현우진',
#   '34',
#   '대표적',
#   '모의',
#   '공모',
#   '만큼',
#   '심혈',
#   '현씨',
#   '학부',
#   '졸업',
#   '서초',
#   '서초구',
#   '교대역',
#   '대역',
#   '인근',
#   '대치동',
#   '경력',
#   '2014',
#   '2014년',
#   '개원',
#   '성장',
#   '영역',
#   '국어',
#   '25',
#   '25회분',
#   '회분',
#   '43',
#   '43회분',
#   '제공',
#   '수량',
#   '문제지',
#   '온라인',
#   '중고',
#   '중고거래',
#   '거래',
#   '플랫폼',
#   '회당',
#   '1만원',
#   '가격',
#   '원생',
#   '콘텐트여서다',
#   '서다',
#   '풀이',
#   '흔적',
#   '시중',
#   '3회분',
#   '문제집',
#   '1만5000원',
#   '5000',
#   '2만원',
#   '판매',
#   '감안',
#   '금액',
#   '스카이',
#   '1타',
#   '70',
#   '하락',
#   '강대',
#   '강대마이맥학원',
#   '마이',
#   '영어',
#   '강대모',
#   '대모',
#   '2017',
#   '2017년',
#   '개발업체',
#   '이감',
#   '지분',
#   '50',
#   '51',
#   '51억원',
#   '현재',
#   '480',
#   '480여',
#   '공급',
#   '163',
#   '163억원',
#   '순이익',
#   '54',
#   '54억원',
#   '창립자',
#   '김봉소',
#   '봉소',
#   '55',
#   '대표',
#   '출신',
#   '문항',
#   '학생과',
#   '학부모',
#   '사이',
#   '입소문',
#   '소문',
#   '히트',
#   '유사',
#   '상위권',
#   '겨냥',
#   '난이',
#   '난이도의',
#   '도의',
#   '특징',
#   '자본',
#   '30',
#   '30년',
#   '활동',
#   '5회분',
#   '분량',
#   '1억원가량',
#   '가량',
#   '소요',
#   '30문제',
#   '문제당',
#   '50만',
#   '내용',
#   '조금',
#   '문제도',
#   '제도',
#   '대학원',
#   '대학원생과',
#   '생과',
#   '의뢰',
#   '62',
#   '62억9000만',
#   '9000',
#   '용역',
#   '용역비로',
#   '비로',
#   '지출',
#   '강사의',
#   '사의',
#   '영향력',
#   '학원간',
#   '주요',
#   '요소',
#   '섭외만큼',
#   '유무',
#   '전통적',
#   '강사가',
#   '사가',
#   '생산',
#   '때문',
#   '무시',
#   '예로',
#   '법인',
#   '법인명',
#   '현현교육',
#   '패키지',
#   '할인',
#   '상품',
#   '프리',
#   '프리패스',
#   '패스',
#   '도입',
#   '1년여',
#   '40',
#   '2016',
#   '2016년',
#   '973',
#   '973억원',
#   '정점',
#   '291',
#   '291억원',
#   '결정적',
#   '사회',
#   '사회탐구',
#   '탐구',
#   '전체',
#   '지영',
#   '38',
#   '12',
#   '12월',
#   '2위',
#   '투스',
#   '투스교육',
#   '이적',
#   '단적',
#   '자본잠식',
#   '잠식',
#   '상태',
#   '경영난',
#   '매각',
#   '매각설',
#   '스카이에듀',
#   '운영',
#   '유니',
#   '유니타스',
#   '타스',
#   '손호',
#   '홍보',
#   '홍보팀장',
#   '팀장',
#   '검토',
#   '흑자',
#   '전환',
#   '올해',
#   '반등',
#   '설명',
#   '직면',
#   '허들',
#   '코로나19뿐',
#   '학령',
#   '학령인구',
#   '인구',
#   '감소',
#   '위기',
#   '응시자',
#   '역대',
#   '40만명대',
#   '49',
#   '49만3433명',
#   '3433',
#   '3개',
#   '대형',
#   '대형학원',
#   '구조',
#   '구조조정',
#   '조정',
#   '전망',
#   '문상덕',
#   '상덕',
#   '기자'],
#  ['시스',
#   '브랜드',
#   '2일',
#   '현지',
#   '현지시간',
#   '시간',
#   '중국',
#   '상하이',
#   '국제',
#   '국제크루즈터미널',
#   '크루즈',
#   '터미널',
#   '나이트',
#   '고급',
#   '고급차',
#   '시장',
#   '겨냥',
#   '론칭',
#   '사진',
#   '본격',
#   '진출',
#   '현대',
#   '현대차그룹',
#   '그룹',
#   '현지시각',
#   '시각',
#   '공식',
#   '출범',
#   '장재',
#   '장재훈',
#   '현대차',
#   '사장',
#   '영상',
#   '인사',
#   '소비자',
#   '차별화',
#   '가치',
#   '제공',
#   '80',
#   '하반기',
#   '동시',
#   '출시',
#   '럭셔리',
#   '진면목',
#   '중국법인장',
#   '법인',
#   '미국',
#   '캐나다',
#   '호주',
#   '러시아',
#   '중동',
#   '고객',
#   '사랑',
#   '기대',
#   '2017',
#   '2017년',
#   '고고도',
#   '미사일',
#   '방어',
#   '체계',
#   '사드',
#   '배치',
#   '이후',
#   '관계',
#   '악화',
#   '결정적',
#   '이유',
#   '북미',
#   '성과',
#   '3월',
#   '8222',
#   '8222대',
#   '지난해',
#   '기간',
#   '3955',
#   '3955대',
#   '2배',
#   '이상',
#   '증가',
#   '메르',
#   '데스',
#   '벤츠',
#   '경쟁',
#   '캐딜',
#   '캐딜락',
#   '12',
#   '정도',
#   '성장',
#   '상승세',
#   '부담',
#   '고태',
#   '고태봉',
#   '하이',
#   '하이투자증권',
#   '투자',
#   '증권',
#   '리서치',
#   '리서치센터장',
#   '센터',
#   '완성',
#   '완성차',
#   '제조',
#   '제조업체',
#   '업체',
#   '플랫폼',
#   '플랫폼당',
#   '수익',
#   '중요',
#   '때문',
#   '한국',
#   '세계',
#   '최대',
#   '퇴근',
#   '판매량',
#   '경쟁력',
#   '김준규',
#   '준규',
#   '조사',
#   '조사연구실장',
#   '연구',
#   '실장',
#   '자동차',
#   '친환경',
#   '환경',
#   '양분',
#   '2019',
#   '2019년',
#   '수요',
#   '지금',
#   '적기',
#   '한편',
#   '자동차산업협회',
#   '산업',
#   '협회',
#   '호화',
#   '253',
#   '253만대',
#   '규모',
#   '4분',
#   '차지',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '전체',
#   '감소',
#   '분야',
#   '14.5',
#   '김영주',
#   '영주',
#   '기자',
#   '관련',
#   '관련기사현대차',
#   '기사',
#   '효과',
#   '4분기',
#   '분기',
#   '영업익',
#   '업익',
#   '1조6000억',
#   '6000'],
#  ['30',
#   '30일',
#   '오후',
#   '서울',
#   '중구',
#   '웨스',
#   '조선',
#   '조선호텔',
#   '호텔',
#   '랜더스',
#   '더스',
#   '창단식',
#   '단식',
#   '구단',
#   '구단주인',
#   '주인',
#   '정용진',
#   '용진',
#   '신세계',
#   '부회장',
#   '창단',
#   '포부',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '롯데',
#   '야구',
#   '야구판',
#   '신세계그룹',
#   '그룹',
#   '2일',
#   '음성',
#   '기반',
#   '소셜미디어',
#   '미디어',
#   '클럽',
#   '클럽하우스',
#   '하우스',
#   '등장',
#   '지난달',
#   '새벽',
#   '관련',
#   '도발',
#   '발언',
#   '우리',
#   '유통',
#   '라이',
#   '프로',
#   '프로야구',
#   '라이벌',
#   '의식',
#   '30년',
#   '동반자',
#   '덕분',
#   '본업',
#   '연결',
#   '게임',
#   '마케팅',
#   '만큼',
#   '롯데자이언츠',
#   '이언츠',
#   '3일',
#   '2021',
#   '리그',
#   '개막전',
#   '구장',
#   '승부',
#   '오프라인',
#   '한창',
#   '롯데마트',
#   '마트',
#   '29',
#   '29일',
#   '연중',
#   '최대',
#   '규모',
#   '할인',
#   '행사',
#   '제목',
#   '보도',
#   '보도자료',
#   '자료',
#   '시간',
#   '이후',
#   '이마트',
#   '야구단',
#   '기념',
#   '상반기',
#   '데이',
#   '롯데온',
#   '홈페이지',
#   '이벤트',
#   '소식',
#   '원정',
#   '문구',
#   '온라인',
#   '명칭',
#   '홈구장',
#   '인천',
#   '필드',
#   '만큼',
#   '경기',
#   '승리',
#   '맞불',
#   '구도',
#   '내가',
#   '의도',
#   '대로',
#   '반응',
#   '평가',
#   '전력',
#   '변수',
#   '상대',
#   '연패',
#   '관련기사네이버',
#   '기사',
#   '네이버',
#   '이해',
#   '이번',
#   '2000',
#   '2000억',
#   '컨셉',
#   '리테일',
#   '테일',
#   '더비',
#   '시작',
#   '반값',
#   '경쟁',
#   '강기',
#   '기자'],
#  ['아시아',
#   '태평양',
#   '지역',
#   '솔루션',
#   '제공',
#   '기업',
#   '켈리서비스',
#   '서비스',
#   '코리아',
#   '4월',
#   '1일',
#   '사명',
#   '솔켈리',
#   '확정',
#   '변경',
#   '동시',
#   '인사',
#   '채용',
#   '부문',
#   '선두',
#   '주자',
#   '포함',
#   '포트폴리오',
#   '브랜드',
#   '통합',
#   '반영',
#   '아이덴티티',
#   '공개',
#   '증가',
#   '인력',
#   '고용',
#   '요구',
#   '부응',
#   '홀딩',
#   '홀딩스와',
#   '스와',
#   '사이',
#   '2016',
#   '2016년',
#   '설립',
#   '전역',
#   '2,000',
#   '2,000여',
#   '기준',
#   '직원',
#   '보유',
#   '출범',
#   '고객',
#   '급성장',
#   '다양',
#   '인재',
#   '탐색',
#   '선도',
#   '플랫폼',
#   '구축',
#   '노력',
#   '정점',
#   '퍼솔켈리',
#   '집중',
#   '분야',
#   '분야일',
#   '우리',
#   '전문',
#   '독특',
#   '동안',
#   '명성',
#   '신뢰',
#   '관리',
#   '성장',
#   '한편',
#   '로고',
#   '비쥬얼',
#   '비쥬얼적인',
#   '적인',
#   '사람',
#   '개인',
#   '초점',
#   '표현',
#   '뷰파인더',
#   '파인더',
#   '상승',
#   '문제',
#   '지속적',
#   '최적',
#   '우선',
#   '비즈니스',
#   '주요',
#   '가치',
#   '리브',
#   '리브랜딩',
#   '랜딩',
#   '마케팅',
#   '자료',
#   '개편',
#   '디지털',
#   '채널',
#   '자산',
#   '모습',
#   '온라인',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['미국',
#   '하버드',
#   '하버드대',
#   '연구진',
#   '만성',
#   '스트레스',
#   '분비',
#   '호르몬',
#   '탈모',
#   '원인',
#   '중앙',
#   '중앙포토',
#   '포토',
#   '경기',
#   '경기도',
#   '성남',
#   '성남시',
#   '분당',
#   '분당구',
#   '정보',
#   '정보기술',
#   '기술',
#   '기업',
#   '39',
#   '연말',
#   '머리',
#   '평소',
#   '인사',
#   '인사평가',
#   '평가',
#   '기간',
#   '직장',
#   '상사',
#   '동료',
#   '부정적',
#   '우울',
#   '경우',
#   '때문',
#   '계절적',
#   '요인',
#   '배제',
#   '압박',
#   '원인일',
#   '확률',
#   '연구',
#   '결과',
#   '발표',
#   '주입',
#   '연도별',
#   '탈모증',
#   '환자',
#   '현황',
#   '그래픽',
#   '김주원',
#   '주원',
#   '기자',
#   '국제',
#   '국제학술지',
#   '학술지',
#   '네이처',
#   '지난달',
#   '31',
#   '31일',
#   '현지',
#   '현지시각',
#   '시각',
#   '줄기',
#   '줄기세포',
#   '세포',
#   '재생',
#   '재생생물학과',
#   '생물',
#   '학과',
#   '모낭',
#   '소개',
#   '피부',
#   '머리카락',
#   '털이',
#   '주머니',
#   '모양',
#   '기관',
#   '성장기',
#   '시기',
#   '8년',
#   '퇴행기',
#   '3주',
#   '휴식기',
#   '활동',
#   '반복',
#   '생성',
#   '조절',
#   '활성화',
#   '반대',
#   '조직',
#   '발생',
#   '생쥐',
#   '관찰',
#   '영향',
#   '사실',
#   '발견',
#   '코르티',
#   '코르티코스테',
#   '코스',
#   '인위적',
#   '증가',
#   '척추',
#   '척추동물',
#   '동물',
#   '부신',
#   '피질',
#   '인간',
#   '코르티솔',
#   '역할',
#   '인체',
#   '외부',
#   '자극',
#   '혈압',
#   '포도당',
#   '수치',
#   '이때',
#   '물질',
#   '수야츠',
#   '줄기세포연구소',
#   '연구소',
#   '재생생물학',
#   '생물학',
#   '교수',
#   '지연',
#   '빈도',
#   '근본적',
#   '의미',
#   '설명',
#   '제거',
#   '노화',
#   '발모',
#   '원형',
#   '원형탈모',
#   '임상',
#   '임상증상',
#   '증상',
#   '사진',
#   '분당',
#   '분당서울대병원',
#   '서울대',
#   '병원',
#   '차단',
#   '시간',
#   '극적',
#   '계속',
#   '통상',
#   '수록',
#   '나이',
#   '유지',
#   '본질적',
#   '진입',
#   '행위',
#   '되풀이',
#   '아가',
#   '과정',
#   '규정',
#   '뿌리',
#   '부분',
#   '특정',
#   '유두',
#   '유두진피세포',
#   '진피',
#   '단백질',
#   '모발',
#   '성장',
#   '촉진',
#   '국민',
#   '국민건강보험공단',
#   '건강',
#   '보험',
#   '공단',
#   '자료',
#   '국내',
#   '인구',
#   '1000',
#   '1000만명',
#   '추정',
#   '이번',
#   '모인',
#   '소식',
#   '확인',
#   '조건',
#   '치료',
#   '기술개발사무소',
#   '개발',
#   '사무소',
#   '관련',
#   '지식',
#   '지식재산권',
#   '재산권',
#   '확보',
#   '사업',
#   '모색',
#   '중이',
#   '대상',
#   '실시',
#   '실험',
#   '향후',
#   '안전',
#   '유효',
#   '적용',
#   '문희철',
#   '희철'],
#  ['대한',
#   '대한민국',
#   '대한민국환경대상위원회',
#   '민국',
#   '환경',
#   '대상',
#   '위원회',
#   '위원장',
#   '규용',
#   '환경부',
#   '장관',
#   '한국',
#   '한국환경한림원',
#   '한림원',
#   '회장',
#   '이하',
#   '3월',
#   '29',
#   '29일',
#   '16',
#   '16회',
#   '2021',
#   '2021대한민국환경대상',
#   '사전',
#   '사전회의',
#   '회의',
#   '진행',
#   '주요',
#   '키워드',
#   '이번',
#   '전년도',
#   '행사',
#   '행사결과',
#   '결과',
#   '보고',
#   '올해',
#   '시상식',
#   '일정',
#   '계획',
#   '논의',
#   '지난해',
#   '대한민국환경대상',
#   '정부',
#   '정부포상',
#   '포상',
#   '15',
#   '15점',
#   '21',
#   '21점',
#   '36',
#   '36여',
#   '명의',
#   '수상자',
#   '탄생',
#   '예년',
#   '규모',
#   '시상',
#   '예정',
#   '부문',
#   '상은',
#   '각계',
#   '각계각층',
#   '각층',
#   '저명',
#   '인사',
#   '심사',
#   '수상',
#   '수상여부',
#   '여부',
#   '결정',
#   '정부포상은',
#   '추천',
#   '부처',
#   '결격',
#   '결격사유',
#   '사유',
#   '검토',
#   '교육부',
#   '농림',
#   '농림축산식품부',
#   '축산',
#   '식품',
#   '장관표창',
#   '표창',
#   '산업',
#   '산업통상자원부',
#   '통상',
#   '자원부',
#   '해양',
#   '해양수산부',
#   '수산부',
#   '수여',
#   '내용',
#   '선정',
#   '초점',
#   '기업',
#   '기회',
#   '발굴',
#   '노력',
#   '환경보호',
#   '보호',
#   '사회',
#   '사회공헌',
#   '공헌',
#   '윤리',
#   '윤리경영',
#   '경영',
#   '말로',
#   '기여',
#   '법과',
#   '지표',
#   '지속',
#   '지속가능',
#   '가능',
#   '가늠',
#   '척도',
#   '중요',
#   '환경대상',
#   '우수',
#   '우수대상자',
#   '대상자',
#   '선별',
#   '의도',
#   '홍보',
#   '중요하다',
#   '하다',
#   '의견',
#   '활용',
#   '공모',
#   '환경관련',
#   '관련',
#   '단체',
#   '협회',
#   '전문',
#   '전문분야',
#   '분야',
#   '후보군',
#   '보군',
#   '적극',
#   '공모기간',
#   '기간',
#   '연장',
#   '7월',
#   '연기',
#   '한편',
#   '주거',
#   '정책',
#   '교육',
#   '문화',
#   '예술',
#   '제품',
#   '건설',
#   '기술',
#   '서비스',
#   '보건',
#   '의약',
#   '안전',
#   '에너지',
#   '자연',
#   '자연생태',
#   '생태',
#   '자원',
#   '자원순환',
#   '순환',
#   '농수산',
#   '농수산식품',
#   '공공',
#   '특별',
#   '특별부문',
#   '의식주',
#   '생활환경',
#   '생산',
#   '유통',
#   '소비',
#   '신청',
#   '신청서',
#   '1부',
#   '직인',
#   '관인',
#   '날인',
#   '공적',
#   '공적내용',
#   '증빙',
#   '증빙서류',
#   '서류',
#   '첨부',
#   '필요시',
#   '4월',
#   '26',
#   '26일',
#   '사무국',
#   '우편',
#   '이메일',
#   '접수',
#   '자세',
#   '홈페이지',
#   '확인',
#   '온라인',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['경기',
#   '경기평택항만',
#   '항만',
#   '공사',
#   '사장',
#   '문학',
#   '문학진',
#   '코로나',
#   '코로나19',
#   '19',
#   '지속',
#   '수출입',
#   '어려움',
#   '중소기업',
#   '물류',
#   '지원',
#   '마케팅',
#   '강화',
#   '평택항',
#   '신규',
#   '물동량',
#   '유치',
#   '1일',
#   '딸기',
#   '포도',
#   '체인',
#   '전문',
#   '전문기업',
#   '기업',
#   '태흥',
#   '태흥무역',
#   '무역',
#   '대표',
#   '대표이사',
#   '이사',
#   '김준규',
#   '준규',
#   '방문',
#   '애로',
#   '애로사항',
#   '사항',
#   '청취',
#   '베트남',
#   '태국',
#   '동남아',
#   '지역',
#   '수출',
#   '실시',
#   '2018',
#   '2018년',
#   '경기',
#   '경기도',
#   '경기도내',
#   '대상',
#   '파악',
#   '현장',
#   '활동',
#   '120',
#   '120여개',
#   '중소',
#   '중소수출기업',
#   '올해',
#   '중부권',
#   '수도권',
#   '범위',
#   '확대',
#   '계획',
#   '인력',
#   '부족',
#   '초기',
#   '해외',
#   '바이어',
#   '발굴',
#   '외국어',
#   '홍보물',
#   '제작',
#   '상담',
#   '통역',
#   '전시회',
#   '참가',
#   '판로',
#   '개척',
#   '자체',
#   '보유',
#   '화주',
#   '데이터',
#   '데이터베이스',
#   '베이스',
#   '품목',
#   '분석',
#   '타깃',
#   '고객',
#   '선정',
#   '맞춤',
#   '적극',
#   '희망',
#   '물류마케팅팀',
#   '문의',
#   '한편',
#   '지난해',
#   '적극적',
#   '전국',
#   '주요',
#   '컨테이너',
#   '증가율',
#   '기록',
#   '개항',
#   '이래',
#   '사상',
#   '최대',
#   '온라인',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['한국',
#   '한국동서발전',
#   '동서',
#   '발전',
#   '사장',
#   '회사',
#   '창립',
#   '20',
#   '20주년',
#   '주년',
#   '지속',
#   '지속가능',
#   '가능',
#   '미래',
#   '성장',
#   '성장동력',
#   '동력',
#   '창출',
#   '환경',
#   '사회',
#   '지배',
#   '지배구조',
#   '구조',
#   '경영',
#   '강화',
#   '동서발전',
#   '2일',
#   '울산',
#   '본사',
#   '강당',
#   '기념식',
#   '선포',
#   '기념사',
#   '시상',
#   '진행',
#   '행사',
#   '정부',
#   '사회적',
#   '거리',
#   '방침',
#   '준수',
#   '경영진',
#   '노조',
#   '노조위원장',
#   '위원장',
#   '모범',
#   '모범직원',
#   '직원',
#   '최소',
#   '인원',
#   '현장',
#   '참석',
#   '사무실',
#   '온라인',
#   '생방송',
#   '참여',
#   '임직원',
#   '에너지',
#   '에너지기업',
#   '기업',
#   '안전',
#   '강조',
#   '협력사',
#   '대표',
#   '안전기원',
#   '기원',
#   '메시지',
#   '작성',
#   '조형물',
#   '부착',
#   '점등',
#   '퍼포먼스',
#   '의지',
#   '도약',
#   '우선',
#   '실천',
#   '생산',
#   '기반',
#   '사회적가치',
#   '가치',
#   '실현',
#   '4차',
#   '산업',
#   '산업기술',
#   '기술',
#   '에너지산업',
#   '선도',
#   '가지',
#   '당부',
#   '20년',
#   '100',
#   '100년',
#   '변화',
#   '대응',
#   '체질',
#   '다짐',
#   '영상',
#   '결의',
#   '국회의원',
#   '울산시장',
#   '시장',
#   '각계',
#   '각계각층',
#   '각층',
#   '인사',
#   '축하',
#   '의미',
#   '이날',
#   '오후',
#   '사회문제',
#   '문제',
#   '연계',
#   '사회공헌활동',
#   '공헌',
#   '활동',
#   '복지',
#   '복지사각지대',
#   '사각지대',
#   '해소',
#   '30',
#   '30명',
#   '영양식',
#   '지역',
#   '지역농산물',
#   '농산물',
#   '안전용품',
#   '용품',
#   '구성',
#   '꾸러미',
#   '취약',
#   '취약계층',
#   '계층',
#   '200',
#   '200가구',
#   '가구',
#   '지원',
#   '물품',
#   '소상공인',
#   '상공인',
#   '구매',
#   '포장재',
#   '대신',
#   '폐플라스틱',
#   '플라스틱',
#   '에코',
#   '에코백',
#   '활용',
#   '기후',
#   '기후변화',
#   '탄소',
#   '탄소상쇄숲',
#   '상쇄',
#   '조성',
#   '식목',
#   '식목행사',
#   '환경정화활동',
#   '정화',
#   '소소한',
#   '소한',
#   '지구',
#   '지구살리기',
#   '살리기',
#   '시행',
#   '60',
#   '60명',
#   '동천',
#   '동천강',
#   '주변',
#   '황방산',
#   '방산',
#   '산책로',
#   '정화활동',
#   '편백',
#   '편백나무',
#   '나무',
#   '300',
#   '300그루',
#   '그루',
#   '사업소',
#   '당진',
#   '울산발전본부',
#   '본부',
#   '건강',
#   '건강증진식품',
#   '증진',
#   '식품',
#   '식료품',
#   '전달',
#   '호남',
#   '음성',
#   '하천',
#   '해변가',
#   '일산',
#   '효율',
#   '사업',
#   '일환',
#   '노후',
#   '등기',
#   '등기구의',
#   '구의',
#   '교체',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['조원',
#   '조원태',
#   '한진',
#   '한진그룹회장',
#   '그룹',
#   '회장',
#   '왼쪽',
#   '조현',
#   '대한',
#   '대한항공',
#   '항공',
#   '부사장',
#   '오른쪽',
#   '사진',
#   '한진그룹',
#   '경영권',
#   '분쟁',
#   '결국',
#   '승리',
#   '동맹',
#   '맺었',
#   '행동',
#   '행동주의',
#   '주의',
#   '사모',
#   '사모펀드',
#   '펀드',
#   '반도',
#   '반도건설',
#   '건설',
#   '3자연합',
#   '연합',
#   '공식',
#   '해체',
#   '조양호',
#   '양호',
#   '별세',
#   '이후',
#   '1년',
#   '3개월',
#   '개월',
#   '공동',
#   '보유',
#   '보유계약',
#   '계약',
#   '해지',
#   '견제',
#   '감시',
#   '지속',
#   '2일',
#   '보도',
#   '보도자료',
#   '자료',
#   '전일',
#   '1일',
#   '합의',
#   '주주',
#   '주주연합간의',
#   '간의',
#   '공동보유계약',
#   '공시',
#   '지배',
#   '지배구조개선',
#   '구조',
#   '개선',
#   '기업',
#   '기업가치',
#   '가치',
#   '제고',
#   '경영진',
#   '결정',
#   '지지',
#   '동시',
#   '필요',
#   '부분',
#   '지속적',
#   '지분',
#   '산하',
#   '그레이스',
#   '그레이스홀딩스',
#   '딩스',
#   '17.54',
#   '계열',
#   '계열사인',
#   '사인',
#   '대호',
#   '대호개발',
#   '개발',
#   '17.15',
#   '5.71',
#   '지난해',
#   '아시아',
#   '인수',
#   '산업',
#   '산업은행',
#   '은행',
#   '한진칼',
#   '10.66',
#   '확보',
#   '45.24',
#   '40.4',
#   '우호',
#   '47.33',
#   '인천',
#   '인천국제공항',
#   '국제공항',
#   '주기장',
#   '항공기',
#   '연합뉴스',
#   '뉴스',
#   '신주',
#   '3자',
#   '배정',
#   '유상',
#   '유상증자',
#   '증자',
#   '형식',
#   '주주권',
#   '침해',
#   '발행',
#   '금지',
#   '가처분',
#   '신청',
#   '서울',
#   '서울중앙지법',
#   '중앙',
#   '지법',
#   '기각',
#   '당시',
#   '입장',
#   '입장문',
#   '전문',
#   '경영인',
#   '체제',
#   '독립적',
#   '이사회',
#   '소신',
#   '고민',
#   '노력',
#   '계속',
#   '예고',
#   '지난달',
#   '주총',
#   '주주제',
#   '주주제안',
#   '백기',
#   '당장',
#   '처분',
#   '만큼',
#   '통합',
#   '통합항공사',
#   '항공사',
#   '출범',
#   '상황',
#   '대형',
#   '대형항공사',
#   '2019',
#   '2019년',
#   '참여',
#   '일관',
#   '주장',
#   '사안',
#   '정보',
#   '정보기술',
#   '기술',
#   '강국',
#   '대한민국',
#   '민국',
#   '위상',
#   '세계',
#   '세계항공물류',
#   '물류',
#   '3위',
#   '여객',
#   '5위의',
#   '위의',
#   '인천공항',
#   '공항',
#   '감안',
#   '시너지',
#   '창출',
#   '기대',
#   '절차',
#   '문제',
#   '결과적',
#   '차례',
#   '재무',
#   '재무구조',
#   '독단적',
#   '행사',
#   '대주주',
#   '최소한',
#   '장치',
#   '마련',
#   '생각',
#   '평가',
#   '최대',
#   '수혜',
#   '글로벌',
#   '10',
#   '10위권',
#   '위권',
#   '국적',
#   '두고',
#   '업계',
#   '수혜자',
#   '분석',
#   '관계자',
#   '등장',
#   '투쟁',
#   '명분',
#   '동력',
#   '자금력',
#   '공권력',
#   '궁지',
#   '한편',
#   '올해',
#   '각국',
#   '공정',
#   '공정거래',
#   '거래',
#   '당국',
#   '결합',
#   '결합승인',
#   '승인',
#   '2024',
#   '2024년',
#   '작업',
#   '마무리',
#   '예정',
#   '기자',
#   '관련',
#   '관련기사4.8조',
#   '기사',
#   '4.8',
#   '구조조정',
#   '조정',
#   '독과점',
#   '항공빅딜',
#   '빅딜',
#   '이륙',
#   '걸림돌',
#   '합병',
#   '인위적',
#   '가격',
#   '인상']]

# %%
from apyori import apriori

rules = apriori(news, 
                min_support=0.3,
                min_confidence=0.2)
result = list(rules)

# %%
for r in result:
    print(r, end='\n\n')
# Out:
# RelationRecord(items=frozenset({'10'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'10'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'1000'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'1000'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'19'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'19'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'1일'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'1일'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'2019'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2019'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'2019년'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2019년'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'2일'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2일'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'30'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'30'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'가격'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'가격'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'가치'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'가치'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'경우'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'경우'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'계획'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'계획'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'관계자'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관계자'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'관련'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련'}), confidence=0.6666666666666666, lift=1.0)])
#
# RelationRecord(items=frozenset({'기사'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사'}), confidence=0.5, lift=1.0)])
#
# RelationRecord(items=frozenset({'기업'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기업'}), confidence=0.43333333333333335, lift=1.0)])
#
# RelationRecord(items=frozenset({'기자'}), support=0.7333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자'}), confidence=0.7333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'기준'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기준'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'뉴스'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'뉴스'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'대상'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'대상'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'대표'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'대표'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'때문'}), support=0.5666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'때문'}), confidence=0.5666666666666667, lift=1.0)])
#
# RelationRecord(items=frozenset({'만큼'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'만큼'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'문제'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'문제'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'미국'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'미국'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'브랜드'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'브랜드'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'사진'}), support=0.5333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사진'}), confidence=0.5333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'생산'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'생산'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'성장'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'성장'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'수요'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'수요'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'시간'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시간'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'시장'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시장'}), confidence=0.43333333333333335, lift=1.0)])
#
# RelationRecord(items=frozenset({'업계'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'업계'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'업체'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'업체'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'온라인'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'온라인'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'올해'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'올해'}), confidence=0.4666666666666667, lift=1.0)])
#
# RelationRecord(items=frozenset({'이번'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이번'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'이상'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이상'}), confidence=0.5, lift=1.0)])
#
# RelationRecord(items=frozenset({'이유'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이유'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'이후'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이후'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'전문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'전문'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'정부'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'정부'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'중앙'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'중앙'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'중요'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'중요'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'지난달'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'지난달'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'지난해'}), support=0.5333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'지난해'}), confidence=0.5333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'최근'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'최근'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'최대'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'최대'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'코로나'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나'}), confidence=0.43333333333333335, lift=1.0)])
#
# RelationRecord(items=frozenset({'코로나19'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나19'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'포함'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포함'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'필요'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'필요'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'한국'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'한국'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'회사'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'회사'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'관련', '10'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '10'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'관련'}), confidence=0.8333333333333333, lift=1.25), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'10'}), confidence=0.5, lift=1.25)])
#
# RelationRecord(items=frozenset({'10', '기사'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'10', '기사'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'기사'}), confidence=0.7499999999999999, lift=1.4999999999999998), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'10'}), confidence=0.6, lift=1.4999999999999998)])
#
# RelationRecord(items=frozenset({'기자', '10'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '10'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'기자'}), confidence=0.7499999999999999, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'10'}), confidence=0.4090909090909091, lift=1.0227272727272727)])
#
# RelationRecord(items=frozenset({'10', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'10', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'사진'}), confidence=0.7499999999999999, lift=1.4062499999999998), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'10'}), confidence=0.5625, lift=1.40625)])
#
# RelationRecord(items=frozenset({'10', '지난해'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'10', '지난해'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'지난해'}), confidence=0.7499999999999999, lift=1.4062499999999998), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'10'}), confidence=0.5625, lift=1.40625)])
#
# RelationRecord(items=frozenset({'관련', '1000'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '1000'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'1000'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.35), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'1000'}), confidence=0.45, lift=1.35)])
#
# RelationRecord(items=frozenset({'1000', '기자'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'1000', '기자'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'1000'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2272727272727273), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'1000'}), confidence=0.4090909090909091, lift=1.2272727272727275)])
#
# RelationRecord(items=frozenset({'1000', '올해'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'1000', '올해'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'1000'}), items_add=frozenset({'올해'}), confidence=0.9, lift=1.9285714285714286), OrderedStatistic(items_base=frozenset({'올해'}), items_add=frozenset({'1000'}), confidence=0.6428571428571428, lift=1.9285714285714284)])
#
# RelationRecord(items=frozenset({'기자', '19'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '19'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'기자'}), confidence=0.9090909090909091, lift=1.2396694214876034), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'19'}), confidence=0.45454545454545453, lift=1.2396694214876034)])
#
# RelationRecord(items=frozenset({'19', '지난해'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'19', '지난해'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'지난해'}), confidence=0.9090909090909091, lift=1.7045454545454546), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'19'}), confidence=0.625, lift=1.7045454545454546)])
#
# RelationRecord(items=frozenset({'19', '코로나'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'19', '코로나'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'코로나'}), confidence=0.9090909090909091, lift=2.097902097902098), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'19'}), confidence=0.7692307692307692, lift=2.097902097902098)])
#
# RelationRecord(items=frozenset({'코로나19', '19'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나19', '19'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'코로나19'}), confidence=0.9090909090909091, lift=2.7272727272727275), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'19'}), confidence=1.0, lift=2.7272727272727275)])
#
# RelationRecord(items=frozenset({'2019', '2019년'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2019', '2019년'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'2019'}), items_add=frozenset({'2019년'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'2019년'}), items_add=frozenset({'2019'}), confidence=1.0, lift=3.0)])
#
# RelationRecord(items=frozenset({'관련', '2019'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '2019'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'2019'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.35), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'2019'}), confidence=0.45, lift=1.35)])
#
# RelationRecord(items=frozenset({'기자', '2019'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '2019'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'2019'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2272727272727273), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'2019'}), confidence=0.4090909090909091, lift=1.2272727272727275)])
#
# RelationRecord(items=frozenset({'2019', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2019', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'2019'}), items_add=frozenset({'사진'}), confidence=0.9, lift=1.6875), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'2019'}), confidence=0.5625, lift=1.6875)])
#
# RelationRecord(items=frozenset({'관련', '2019년'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '2019년'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'2019년'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.35), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'2019년'}), confidence=0.45, lift=1.35)])
#
# RelationRecord(items=frozenset({'기자', '2019년'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '2019년'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'2019년'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2272727272727273), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'2019년'}), confidence=0.4090909090909091, lift=1.2272727272727275)])
#
# RelationRecord(items=frozenset({'2019년', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2019년', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'2019년'}), items_add=frozenset({'사진'}), confidence=0.9, lift=1.6875), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'2019년'}), confidence=0.5625, lift=1.6875)])
#
# RelationRecord(items=frozenset({'2일', '기자'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2일', '기자'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'2일'}), items_add=frozenset({'기자'}), confidence=0.9090909090909091, lift=1.2396694214876034), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'2일'}), confidence=0.45454545454545453, lift=1.2396694214876034)])
#
# RelationRecord(items=frozenset({'기자', '가격'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '가격'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'가격'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'가격'}), confidence=0.5, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'가치', '관련'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'가치', '관련'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'가치'}), items_add=frozenset({'관련'}), confidence=0.7499999999999999, lift=1.125), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'가치'}), confidence=0.45, lift=1.125)])
#
# RelationRecord(items=frozenset({'가치', '기자'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'가치', '기자'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'가치'}), items_add=frozenset({'기자'}), confidence=0.7499999999999999, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'가치'}), confidence=0.4090909090909091, lift=1.0227272727272727)])
#
# RelationRecord(items=frozenset({'경우', '때문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'경우', '때문'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'경우'}), items_add=frozenset({'때문'}), confidence=0.9, lift=1.5882352941176472), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'경우'}), confidence=0.5294117647058824, lift=1.5882352941176472)])
#
# RelationRecord(items=frozenset({'경우', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'경우', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'경우'}), items_add=frozenset({'사진'}), confidence=0.9, lift=1.6875), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'경우'}), confidence=0.5625, lift=1.6875)])
#
# RelationRecord(items=frozenset({'계획', '올해'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'계획', '올해'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'계획'}), items_add=frozenset({'올해'}), confidence=0.9, lift=1.9285714285714286), OrderedStatistic(items_base=frozenset({'올해'}), items_add=frozenset({'계획'}), confidence=0.6428571428571428, lift=1.9285714285714284)])
#
# RelationRecord(items=frozenset({'기자', '관계자'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '관계자'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관계자'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'관계자'}), confidence=0.4090909090909091, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'관련', '기사'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기사'}), confidence=0.4666666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기사'}), confidence=0.7000000000000001, lift=1.4000000000000001), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'관련'}), confidence=0.9333333333333333, lift=1.4000000000000001)])
#
# RelationRecord(items=frozenset({'관련', '기업'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기업'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기업'}), confidence=0.45, lift=1.0384615384615385), OrderedStatistic(items_base=frozenset({'기업'}), items_add=frozenset({'관련'}), confidence=0.6923076923076923, lift=1.0384615384615385)])
#
# RelationRecord(items=frozenset({'관련', '기자'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기자'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기자'}), confidence=0.75, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'관련'}), confidence=0.6818181818181819, lift=1.022727272727273)])
#
# RelationRecord(items=frozenset({'관련', '뉴스'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '뉴스'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'뉴스'}), confidence=0.45, lift=1.125), OrderedStatistic(items_base=frozenset({'뉴스'}), items_add=frozenset({'관련'}), confidence=0.7499999999999999, lift=1.125)])
#
# RelationRecord(items=frozenset({'관련', '때문'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '때문'}), confidence=0.4666666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'때문'}), confidence=0.7000000000000001, lift=1.2352941176470589), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'관련'}), confidence=0.823529411764706, lift=1.235294117647059)])
#
# RelationRecord(items=frozenset({'관련', '만큼'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '만큼'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'만큼'}), confidence=0.45, lift=1.35), OrderedStatistic(items_base=frozenset({'만큼'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.35)])
#
# RelationRecord(items=frozenset({'관련', '사진'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '사진'}), confidence=0.4666666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'사진'}), confidence=0.7000000000000001, lift=1.3125000000000002), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'관련'}), confidence=0.875, lift=1.3125)])
#
# RelationRecord(items=frozenset({'관련', '시장'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '시장'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'시장'}), confidence=0.5, lift=1.1538461538461537), OrderedStatistic(items_base=frozenset({'시장'}), items_add=frozenset({'관련'}), confidence=0.7692307692307692, lift=1.1538461538461537)])
#
# RelationRecord(items=frozenset({'관련', '올해'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '올해'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'올해'}), confidence=0.55, lift=1.1785714285714286), OrderedStatistic(items_base=frozenset({'올해'}), items_add=frozenset({'관련'}), confidence=0.7857142857142857, lift=1.1785714285714286)])
#
# RelationRecord(items=frozenset({'관련', '이번'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '이번'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'이번'}), confidence=0.45, lift=1.2272727272727273), OrderedStatistic(items_base=frozenset({'이번'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.2272727272727275)])
#
# RelationRecord(items=frozenset({'관련', '이상'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '이상'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'이상'}), confidence=0.6000000000000001, lift=1.2000000000000002), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'관련'}), confidence=0.8, lift=1.2000000000000002)])
#
# RelationRecord(items=frozenset({'관련', '이후'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '이후'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'이후'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'이후'}), items_add=frozenset({'관련'}), confidence=1.0, lift=1.5)])
#
# RelationRecord(items=frozenset({'관련', '중요'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '중요'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'중요'}), confidence=0.55, lift=1.375), OrderedStatistic(items_base=frozenset({'중요'}), items_add=frozenset({'관련'}), confidence=0.9166666666666665, lift=1.3749999999999998)])
#
# RelationRecord(items=frozenset({'관련', '지난해'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '지난해'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'지난해'}), confidence=0.55, lift=1.03125), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'관련'}), confidence=0.6875, lift=1.03125)])
#
# RelationRecord(items=frozenset({'관련', '필요'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '필요'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'필요'}), confidence=0.45, lift=1.35), OrderedStatistic(items_base=frozenset({'필요'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.35)])
#
# RelationRecord(items=frozenset({'관련', '한국'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '한국'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'한국'}), confidence=0.45, lift=1.125), OrderedStatistic(items_base=frozenset({'한국'}), items_add=frozenset({'관련'}), confidence=0.7499999999999999, lift=1.125)])
#
# RelationRecord(items=frozenset({'기자', '기사'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '기사'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'기자'}), confidence=0.7333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'기사'}), confidence=0.5, lift=1.0)])
#
# RelationRecord(items=frozenset({'기사', '때문'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사', '때문'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'때문'}), confidence=0.7333333333333333, lift=1.2941176470588234), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'기사'}), confidence=0.6470588235294117, lift=1.2941176470588234)])
#
# RelationRecord(items=frozenset({'기사', '사진'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사', '사진'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'사진'}), confidence=0.7333333333333333, lift=1.375), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'기사'}), confidence=0.6875, lift=1.375)])
#
# RelationRecord(items=frozenset({'이상', '기사'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사', '이상'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'이상'}), confidence=0.6666666666666666, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'기사'}), confidence=0.6666666666666666, lift=1.3333333333333333)])
#
# RelationRecord(items=frozenset({'이후', '기사'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이후', '기사'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'이후'}), confidence=0.6, lift=1.8), OrderedStatistic(items_base=frozenset({'이후'}), items_add=frozenset({'기사'}), confidence=0.9, lift=1.8)])
#
# RelationRecord(items=frozenset({'필요', '기사'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'필요', '기사'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'필요'}), confidence=0.6, lift=1.8), OrderedStatistic(items_base=frozenset({'필요'}), items_add=frozenset({'기사'}), confidence=0.9, lift=1.8)])
#
# RelationRecord(items=frozenset({'기자', '뉴스'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '뉴스'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'뉴스'}), confidence=0.5, lift=1.25), OrderedStatistic(items_base=frozenset({'뉴스'}), items_add=frozenset({'기자'}), confidence=0.9166666666666665, lift=1.2499999999999998)])
#
# RelationRecord(items=frozenset({'기자', '때문'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '때문'}), confidence=0.4666666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'때문'}), confidence=0.6363636363636365, lift=1.1229946524064174), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'기자'}), confidence=0.823529411764706, lift=1.1229946524064174)])
#
# RelationRecord(items=frozenset({'기자', '미국'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '미국'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'미국'}), confidence=0.5, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'미국'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'기자', '사진'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '사진'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'사진'}), confidence=0.5454545454545455, lift=1.022727272727273), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'기자'}), confidence=0.75, lift=1.0227272727272727)])
#
# RelationRecord(items=frozenset({'기자', '수요'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '수요'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'수요'}), confidence=0.4090909090909091, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'수요'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'기자', '시간'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '시간'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'시간'}), confidence=0.4090909090909091, lift=1.2272727272727275), OrderedStatistic(items_base=frozenset({'시간'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2272727272727273)])
#
# RelationRecord(items=frozenset({'기자', '시장'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '시장'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'시장'}), confidence=0.5, lift=1.1538461538461537), OrderedStatistic(items_base=frozenset({'시장'}), items_add=frozenset({'기자'}), confidence=0.846153846153846, lift=1.1538461538461537)])
#
# RelationRecord(items=frozenset({'기자', '업계'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '업계'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'업계'}), confidence=0.45454545454545453, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'업계'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'기자', '업체'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '업체'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'업체'}), confidence=0.45454545454545453, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'업체'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'기자', '올해'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '올해'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'올해'}), confidence=0.5, lift=1.0714285714285714), OrderedStatistic(items_base=frozenset({'올해'}), items_add=frozenset({'기자'}), confidence=0.7857142857142857, lift=1.0714285714285714)])
#
# RelationRecord(items=frozenset({'기자', '이상'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '이상'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'이상'}), confidence=0.5454545454545455, lift=1.090909090909091), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'기자'}), confidence=0.8, lift=1.090909090909091)])
#
# RelationRecord(items=frozenset({'기자', '이후'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '이후'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'이후'}), confidence=0.4090909090909091, lift=1.2272727272727275), OrderedStatistic(items_base=frozenset({'이후'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2272727272727273)])
#
# RelationRecord(items=frozenset({'기자', '중요'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '중요'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'중요'}), confidence=0.4090909090909091, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'중요'}), items_add=frozenset({'기자'}), confidence=0.7499999999999999, lift=1.0227272727272727)])
#
# RelationRecord(items=frozenset({'기자', '지난달'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '지난달'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'지난달'}), confidence=0.4090909090909091, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'지난달'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'기자', '지난해'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '지난해'}), confidence=0.43333333333333335, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'지난해'}), confidence=0.5909090909090909, lift=1.1079545454545456), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'기자'}), confidence=0.8125, lift=1.1079545454545456)])
#
# RelationRecord(items=frozenset({'기자', '최근'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '최근'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'최근'}), confidence=0.5454545454545455, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'최근'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'기자', '최대'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '최대'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'최대'}), confidence=0.45454545454545453, lift=1.2396694214876034), OrderedStatistic(items_base=frozenset({'최대'}), items_add=frozenset({'기자'}), confidence=0.9090909090909091, lift=1.2396694214876034)])
#
# RelationRecord(items=frozenset({'기자', '코로나'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '코로나'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'코로나'}), confidence=0.5, lift=1.1538461538461537), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'기자'}), confidence=0.846153846153846, lift=1.1538461538461537)])
#
# RelationRecord(items=frozenset({'기자', '코로나19'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '코로나19'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'코로나19'}), confidence=0.4090909090909091, lift=1.2272727272727275), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2272727272727273)])
#
# RelationRecord(items=frozenset({'기자', '한국'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '한국'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'한국'}), confidence=0.45454545454545453, lift=1.1363636363636362), OrderedStatistic(items_base=frozenset({'한국'}), items_add=frozenset({'기자'}), confidence=0.8333333333333333, lift=1.1363636363636362)])
#
# RelationRecord(items=frozenset({'때문', '사진'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'때문', '사진'}), confidence=0.4666666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'사진'}), confidence=0.823529411764706, lift=1.5441176470588236), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'때문'}), confidence=0.875, lift=1.5441176470588236)])
#
# RelationRecord(items=frozenset({'때문', '시장'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'때문', '시장'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'시장'}), confidence=0.5882352941176471, lift=1.3574660633484164), OrderedStatistic(items_base=frozenset({'시장'}), items_add=frozenset({'때문'}), confidence=0.7692307692307692, lift=1.3574660633484161)])
#
# RelationRecord(items=frozenset({'이상', '때문'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이상', '때문'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'이상'}), confidence=0.7058823529411765, lift=1.411764705882353), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'때문'}), confidence=0.8, lift=1.411764705882353)])
#
# RelationRecord(items=frozenset({'이유', '때문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이유', '때문'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'이유'}), confidence=0.5294117647058824, lift=1.5882352941176472), OrderedStatistic(items_base=frozenset({'이유'}), items_add=frozenset({'때문'}), confidence=0.9, lift=1.5882352941176472)])
#
# RelationRecord(items=frozenset({'중요', '때문'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'중요', '때문'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'중요'}), confidence=0.6470588235294117, lift=1.6176470588235292), OrderedStatistic(items_base=frozenset({'중요'}), items_add=frozenset({'때문'}), confidence=0.9166666666666665, lift=1.6176470588235292)])
#
# RelationRecord(items=frozenset({'코로나', '때문'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나', '때문'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'코로나'}), confidence=0.5882352941176471, lift=1.3574660633484164), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'때문'}), confidence=0.7692307692307692, lift=1.3574660633484161)])
#
# RelationRecord(items=frozenset({'필요', '때문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'필요', '때문'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'필요'}), confidence=0.5294117647058824, lift=1.5882352941176472), OrderedStatistic(items_base=frozenset({'필요'}), items_add=frozenset({'때문'}), confidence=0.9, lift=1.5882352941176472)])
#
# RelationRecord(items=frozenset({'한국', '때문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'한국', '때문'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'한국'}), confidence=0.5294117647058824, lift=1.3235294117647058), OrderedStatistic(items_base=frozenset({'한국'}), items_add=frozenset({'때문'}), confidence=0.7499999999999999, lift=1.3235294117647056)])
#
# RelationRecord(items=frozenset({'이상', '사진'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이상', '사진'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'이상'}), confidence=0.625, lift=1.25), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'사진'}), confidence=0.6666666666666666, lift=1.25)])
#
# RelationRecord(items=frozenset({'이유', '사진'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이유', '사진'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'이유'}), confidence=0.625, lift=1.875), OrderedStatistic(items_base=frozenset({'이유'}), items_add=frozenset({'사진'}), confidence=1.0, lift=1.875)])
#
# RelationRecord(items=frozenset({'중요', '사진'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'중요', '사진'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'중요'}), confidence=0.625, lift=1.5625), OrderedStatistic(items_base=frozenset({'중요'}), items_add=frozenset({'사진'}), confidence=0.8333333333333333, lift=1.5624999999999998)])
#
# RelationRecord(items=frozenset({'지난해', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'지난해', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'지난해'}), confidence=0.5625, lift=1.0546875), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'사진'}), confidence=0.5625, lift=1.0546875)])
#
# RelationRecord(items=frozenset({'코로나', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'코로나'}), confidence=0.5625, lift=1.2980769230769231), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'사진'}), confidence=0.6923076923076923, lift=1.2980769230769231)])
#
# RelationRecord(items=frozenset({'필요', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'필요', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'필요'}), confidence=0.5625, lift=1.6875), OrderedStatistic(items_base=frozenset({'필요'}), items_add=frozenset({'사진'}), confidence=0.9, lift=1.6875)])
#
# RelationRecord(items=frozenset({'이상', '시장'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이상', '시장'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'시장'}), items_add=frozenset({'이상'}), confidence=0.7692307692307692, lift=1.5384615384615383), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'시장'}), confidence=0.6666666666666666, lift=1.5384615384615383)])
#
# ...
#
# RelationRecord(items=frozenset({'이유', '때문', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이유', '때문', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'이유', '사진'}), confidence=0.5294117647058824, lift=1.5882352941176472), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'이유', '때문'}), confidence=0.5625, lift=1.875), OrderedStatistic(items_base=frozenset({'이유'}), items_add=frozenset({'때문', '사진'}), confidence=0.9, lift=1.9285714285714286), OrderedStatistic(items_base=frozenset({'때문', '사진'}), items_add=frozenset({'이유'}), confidence=0.6428571428571428, lift=1.9285714285714284), OrderedStatistic(items_base=frozenset({'이유', '때문'}), items_add=frozenset({'사진'}), confidence=1.0, lift=1.875), OrderedStatistic(items_base=frozenset({'이유', '사진'}), items_add=frozenset({'때문'}), confidence=0.9, lift=1.5882352941176472)])
#
# RelationRecord(items=frozenset({'중요', '때문', '사진'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'중요', '때문', '사진'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'중요', '사진'}), confidence=0.5882352941176471, lift=1.7647058823529413), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'중요', '때문'}), confidence=0.625, lift=1.7045454545454546), OrderedStatistic(items_base=frozenset({'중요'}), items_add=frozenset({'때문', '사진'}), confidence=0.8333333333333333, lift=1.7857142857142856), OrderedStatistic(items_base=frozenset({'때문', '사진'}), items_add=frozenset({'중요'}), confidence=0.7142857142857142, lift=1.7857142857142854), OrderedStatistic(items_base=frozenset({'중요', '때문'}), items_add=frozenset({'사진'}), confidence=0.9090909090909091, lift=1.7045454545454546), OrderedStatistic(items_base=frozenset({'중요', '사진'}), items_add=frozenset({'때문'}), confidence=1.0, lift=1.7647058823529411)])
#
# RelationRecord(items=frozenset({'코로나', '때문', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나', '때문', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'코로나', '사진'}), confidence=0.5294117647058824, lift=1.7647058823529413), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'코로나', '때문'}), confidence=0.5625, lift=1.6875), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'때문', '사진'}), confidence=0.6923076923076923, lift=1.4835164835164834), OrderedStatistic(items_base=frozenset({'때문', '사진'}), items_add=frozenset({'코로나'}), confidence=0.6428571428571428, lift=1.4835164835164834), OrderedStatistic(items_base=frozenset({'코로나', '때문'}), items_add=frozenset({'사진'}), confidence=0.9, lift=1.6875), OrderedStatistic(items_base=frozenset({'코로나', '사진'}), items_add=frozenset({'때문'}), confidence=1.0, lift=1.7647058823529411)])
#
# RelationRecord(items=frozenset({'중요', '이상', '때문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'중요', '이상', '때문'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'중요', '이상'}), confidence=0.5294117647058824, lift=1.7647058823529413), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'중요', '때문'}), confidence=0.6, lift=1.6363636363636365), OrderedStatistic(items_base=frozenset({'중요'}), items_add=frozenset({'이상', '때문'}), confidence=0.7499999999999999, lift=1.8749999999999996), OrderedStatistic(items_base=frozenset({'이상', '때문'}), items_add=frozenset({'중요'}), confidence=0.7499999999999999, lift=1.8749999999999996), OrderedStatistic(items_base=frozenset({'중요', '때문'}), items_add=frozenset({'이상'}), confidence=0.8181818181818182, lift=1.6363636363636365), OrderedStatistic(items_base=frozenset({'중요', '이상'}), items_add=frozenset({'때문'}), confidence=1.0, lift=1.7647058823529411)])
#
# RelationRecord(items=frozenset({'코로나19', '지난해', '코로나'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나19', '지난해', '코로나'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'코로나19', '코로나'}), confidence=0.5625, lift=1.6875), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'코로나19', '지난해'}), confidence=0.6923076923076923, lift=2.307692307692308), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'지난해', '코로나'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'지난해', '코로나'}), items_add=frozenset({'코로나19'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'코로나19', '지난해'}), items_add=frozenset({'코로나'}), confidence=1.0, lift=2.3076923076923075), OrderedStatistic(items_base=frozenset({'코로나19', '코로나'}), items_add=frozenset({'지난해'}), confidence=0.9, lift=1.6875)])
#
# RelationRecord(items=frozenset({'기자', '19', '코로나19', '코로나'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '19', '코로나19', '코로나'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'기자', '코로나19', '코로나'}), confidence=0.8181818181818182, lift=2.7272727272727275), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'코로나19', '19', '코로나'}), confidence=0.4090909090909091, lift=1.2272727272727275), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'기자', '19', '코로나19'}), confidence=0.6923076923076923, lift=2.307692307692308), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'기자', '19', '코로나'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'기자', '19'}), items_add=frozenset({'코로나19', '코로나'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'19', '코로나'}), items_add=frozenset({'기자', '코로나19'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'코로나19', '19'}), items_add=frozenset({'기자', '코로나'}), confidence=0.9, lift=2.4545454545454546), OrderedStatistic(items_base=frozenset({'기자', '코로나'}), items_add=frozenset({'코로나19', '19'}), confidence=0.8181818181818182, lift=2.454545454545455), OrderedStatistic(items_base=frozenset({'기자', '코로나19'}), items_add=frozenset({'19', '코로나'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'코로나19', '코로나'}), items_add=frozenset({'기자', '19'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'기자', '19', '코로나'}), items_add=frozenset({'코로나19'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'기자', '19', '코로나19'}), items_add=frozenset({'코로나'}), confidence=1.0, lift=2.3076923076923075), OrderedStatistic(items_base=frozenset({'코로나19', '19', '코로나'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2272727272727273), OrderedStatistic(items_base=frozenset({'기자', '코로나19', '코로나'}), items_add=frozenset({'19'}), confidence=1.0, lift=2.7272727272727275)])
#
# RelationRecord(items=frozenset({'코로나19', '19', '지난해', '코로나'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나19', '19', '지난해', '코로나'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'코로나19', '지난해', '코로나'}), confidence=0.8181818181818182, lift=2.7272727272727275), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'코로나19', '19', '코로나'}), confidence=0.5625, lift=1.6875), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'코로나19', '19', '지난해'}), confidence=0.6923076923076923, lift=2.307692307692308), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'19', '지난해', '코로나'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'19', '지난해'}), items_add=frozenset({'코로나19', '코로나'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'19', '코로나'}), items_add=frozenset({'코로나19', '지난해'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'코로나19', '19'}), items_add=frozenset({'지난해', '코로나'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'지난해', '코로나'}), items_add=frozenset({'코로나19', '19'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'코로나19', '지난해'}), items_add=frozenset({'19', '코로나'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'코로나19', '코로나'}), items_add=frozenset({'19', '지난해'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'19', '지난해', '코로나'}), items_add=frozenset({'코로나19'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'코로나19', '19', '지난해'}), items_add=frozenset({'코로나'}), confidence=1.0, lift=2.3076923076923075), OrderedStatistic(items_base=frozenset({'코로나19', '19', '코로나'}), items_add=frozenset({'지난해'}), confidence=0.9, lift=1.6875), OrderedStatistic(items_base=frozenset({'코로나19', '지난해', '코로나'}), items_add=frozenset({'19'}), confidence=1.0, lift=2.7272727272727275)])
#
# RelationRecord(items=frozenset({'관련', '기자', '때문', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기자', '때문', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기자', '때문', '사진'}), confidence=0.45, lift=1.2272727272727273), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'관련', '때문', '사진'}), confidence=0.4090909090909091, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'관련', '기자', '사진'}), confidence=0.5294117647058824, lift=1.5882352941176472), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'관련', '기자', '때문'}), confidence=0.5625, lift=1.5340909090909092), OrderedStatistic(items_base=frozenset({'관련', '기자'}), items_add=frozenset({'때문', '사진'}), confidence=0.6, lift=1.2857142857142856), OrderedStatistic(items_base=frozenset({'관련', '때문'}), items_add=frozenset({'기자', '사진'}), confidence=0.6428571428571428, lift=1.607142857142857), OrderedStatistic(items_base=frozenset({'관련', '사진'}), items_add=frozenset({'기자', '때문'}), confidence=0.6428571428571428, lift=1.3775510204081631), OrderedStatistic(items_base=frozenset({'기자', '때문'}), items_add=frozenset({'관련', '사진'}), confidence=0.6428571428571428, lift=1.3775510204081631), OrderedStatistic(items_base=frozenset({'기자', '사진'}), items_add=frozenset({'관련', '때문'}), confidence=0.7499999999999999, lift=1.607142857142857), OrderedStatistic(items_base=frozenset({'때문', '사진'}), items_add=frozenset({'관련', '기자'}), confidence=0.6428571428571428, lift=1.2857142857142856), OrderedStatistic(items_base=frozenset({'관련', '기자', '때문'}), items_add=frozenset({'사진'}), confidence=0.8181818181818182, lift=1.5340909090909092), OrderedStatistic(items_base=frozenset({'관련', '기자', '사진'}), items_add=frozenset({'때문'}), confidence=0.9, lift=1.5882352941176472), OrderedStatistic(items_base=frozenset({'관련', '때문', '사진'}), items_add=frozenset({'기자'}), confidence=0.7499999999999999, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'기자', '때문', '사진'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.2272727272727275)])
#
# RelationRecord(items=frozenset({'관련', '이상', '때문', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '이상', '때문', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'이상', '때문', '사진'}), confidence=0.45, lift=1.35), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'관련', '이상', '사진'}), confidence=0.5294117647058824, lift=1.7647058823529413), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'관련', '이상', '때문'}), confidence=0.5625, lift=1.5340909090909092), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'관련', '때문', '사진'}), confidence=0.6, lift=1.4999999999999998), OrderedStatistic(items_base=frozenset({'관련', '때문'}), items_add=frozenset({'이상', '사진'}), confidence=0.6428571428571428, lift=1.9285714285714284), OrderedStatistic(items_base=frozenset({'관련', '사진'}), items_add=frozenset({'이상', '때문'}), confidence=0.6428571428571428, lift=1.607142857142857), OrderedStatistic(items_base=frozenset({'관련', '이상'}), items_add=frozenset({'때문', '사진'}), confidence=0.7499999999999999, lift=1.607142857142857), OrderedStatistic(items_base=frozenset({'때문', '사진'}), items_add=frozenset({'관련', '이상'}), confidence=0.6428571428571428, lift=1.607142857142857), OrderedStatistic(items_base=frozenset({'이상', '때문'}), items_add=frozenset({'관련', '사진'}), confidence=0.7499999999999999, lift=1.607142857142857), OrderedStatistic(items_base=frozenset({'이상', '사진'}), items_add=frozenset({'관련', '때문'}), confidence=0.9, lift=1.9285714285714286), OrderedStatistic(items_base=frozenset({'관련', '때문', '사진'}), items_add=frozenset({'이상'}), confidence=0.7499999999999999, lift=1.4999999999999998), OrderedStatistic(items_base=frozenset({'관련', '이상', '때문'}), items_add=frozenset({'사진'}), confidence=0.8181818181818182, lift=1.5340909090909092), OrderedStatistic(items_base=frozenset({'관련', '이상', '사진'}), items_add=frozenset({'때문'}), confidence=1.0, lift=1.7647058823529411), OrderedStatistic(items_base=frozenset({'이상', '때문', '사진'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.35)])
#
# RelationRecord(items=frozenset({'관련', '중요', '때문', '사진'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '중요', '때문', '사진'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'중요', '때문', '사진'}), confidence=0.45, lift=1.35), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'관련', '중요', '사진'}), confidence=0.5294117647058824, lift=1.7647058823529413), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'관련', '중요', '때문'}), confidence=0.5625, lift=1.6875), OrderedStatistic(items_base=frozenset({'중요'}), items_add=frozenset({'관련', '때문', '사진'}), confidence=0.7499999999999999, lift=1.8749999999999996), OrderedStatistic(items_base=frozenset({'관련', '때문'}), items_add=frozenset({'중요', '사진'}), confidence=0.6428571428571428, lift=1.9285714285714284), OrderedStatistic(items_base=frozenset({'관련', '사진'}), items_add=frozenset({'중요', '때문'}), confidence=0.6428571428571428, lift=1.7532467532467533), OrderedStatistic(items_base=frozenset({'관련', '중요'}), items_add=frozenset({'때문', '사진'}), confidence=0.8181818181818182, lift=1.7532467532467533), OrderedStatistic(items_base=frozenset({'때문', '사진'}), items_add=frozenset({'관련', '중요'}), confidence=0.6428571428571428, lift=1.7532467532467533), OrderedStatistic(items_base=frozenset({'중요', '때문'}), items_add=frozenset({'관련', '사진'}), confidence=0.8181818181818182, lift=1.7532467532467533), OrderedStatistic(items_base=frozenset({'중요', '사진'}), items_add=frozenset({'관련', '때문'}), confidence=0.9, lift=1.9285714285714286), OrderedStatistic(items_base=frozenset({'관련', '때문', '사진'}), items_add=frozenset({'중요'}), confidence=0.7499999999999999, lift=1.8749999999999996), OrderedStatistic(items_base=frozenset({'관련', '중요', '때문'}), items_add=frozenset({'사진'}), confidence=0.9, lift=1.6875), OrderedStatistic(items_base=frozenset({'관련', '중요', '사진'}), items_add=frozenset({'때문'}), confidence=1.0, lift=1.7647058823529411), OrderedStatistic(items_base=frozenset({'중요', '때문', '사진'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.35)])

# %%
result[3]
# Out:
# RelationRecord(items=frozenset({'1일'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'1일'}), confidence=0.3, lift=1.0)])

# %%
# 위의 결과를 데이터프레임으로 
import pandas as pd 
result_df = pd.DataFrame(None, 
                         columns=['lhs', 'rhs', 
                                  'support', 'confidence', 'lift'])
index = 0
for row in result:
    support = row[1]
    ordered_st = row[2]
    
    for item in ordered_st:
        lhs = ','.join(x for x in item[0])
        rhs = ','.join(x.strip() for x in item[1])
        confidence = item[2]
        lift = item[3]
        
        if lift != 1:
            result_df.loc[index] = [lhs, rhs, support, confidence, lift]
            index += 1
result_df.head(10)
# Out:
#    lhs  rhs   support  confidence      lift
# 0   10   관련  0.333333    0.833333  1.250000
# 1   관련   10  0.333333    0.500000  1.250000
# 2   10   기사  0.300000    0.750000  1.500000
# 3   기사   10  0.300000    0.600000  1.500000
# 4   10   기자  0.300000    0.750000  1.022727
# 5   기자   10  0.300000    0.409091  1.022727
# 6   10   사진  0.300000    0.750000  1.406250
# 7   사진   10  0.300000    0.562500  1.406250
# 8   10  지난해  0.300000    0.750000  1.406250
# 9  지난해   10  0.300000    0.562500  1.406250

# %%
pd.options.display.max_rows = 530
result_df
# Out:
#                lhs            rhs   support  confidence      lift
# 0               10             관련  0.333333    0.833333  1.250000
# 1               관련             10  0.333333    0.500000  1.250000
# 2               10             기사  0.300000    0.750000  1.500000
# 3               기사             10  0.300000    0.600000  1.500000
# 4               10             기자  0.300000    0.750000  1.022727
# 5               기자             10  0.300000    0.409091  1.022727
# 6               10             사진  0.300000    0.750000  1.406250
# 7               사진             10  0.300000    0.562500  1.406250
# 8               10            지난해  0.300000    0.750000  1.406250
# 9              지난해             10  0.300000    0.562500  1.406250
# 10            1000             관련  0.300000    0.900000  1.350000
# 11              관련           1000  0.300000    0.450000  1.350000
# 12            1000             기자  0.300000    0.900000  1.227273
# 13              기자           1000  0.300000    0.409091  1.227273
# 14            1000             올해  0.300000    0.900000  1.928571
# 15              올해           1000  0.300000    0.642857  1.928571
# 16              19             기자  0.333333    0.909091  1.239669
# 17              기자             19  0.333333    0.454545  1.239669
# 18              19            지난해  0.333333    0.909091  1.704545
# 19             지난해             19  0.333333    0.625000  1.704545
# 20              19            코로나  0.333333    0.909091  2.097902
# 21             코로나             19  0.333333    0.769231  2.097902
# 22              19          코로나19  0.333333    0.909091  2.727273
# 23           코로나19             19  0.333333    1.000000  2.727273
# 24            2019          2019년  0.333333    1.000000  3.000000
# 25           2019년           2019  0.333333    1.000000  3.000000
# 26            2019             관련  0.300000    0.900000  1.350000
# 27              관련           2019  0.300000    0.450000  1.350000
# 28            2019             기자  0.300000    0.900000  1.227273
# 29              기자           2019  0.300000    0.409091  1.227273
# 30            2019             사진  0.300000    0.900000  1.687500
# 31              사진           2019  0.300000    0.562500  1.687500
# 32           2019년             관련  0.300000    0.900000  1.350000
# 33              관련          2019년  0.300000    0.450000  1.350000
# 34           2019년             기자  0.300000    0.900000  1.227273
# 35              기자          2019년  0.300000    0.409091  1.227273
# 36           2019년             사진  0.300000    0.900000  1.687500
# 37              사진          2019년  0.300000    0.562500  1.687500
# 38              2일             기자  0.333333    0.909091  1.239669
# 39              기자             2일  0.333333    0.454545  1.239669
# 40              가격             기자  0.366667    1.000000  1.363636
# 41              기자             가격  0.366667    0.500000  1.363636
# 42              가치             관련  0.300000    0.750000  1.125000
# 43              관련             가치  0.300000    0.450000  1.125000
# 44              가치             기자  0.300000    0.750000  1.022727
# 45              기자             가치  0.300000    0.409091  1.022727
# 46              경우             때문  0.300000    0.900000  1.588235
# 47              때문             경우  0.300000    0.529412  1.588235
# 48              경우             사진  0.300000    0.900000  1.687500
# 49              사진             경우  0.300000    0.562500  1.687500
# 50              계획             올해  0.300000    0.900000  1.928571
# 51              올해             계획  0.300000    0.642857  1.928571
# 52             관계자             기자  0.300000    1.000000  1.363636
# 53              기자            관계자  0.300000    0.409091  1.363636
# 54              관련             기사  0.466667    0.700000  1.400000
# 55              기사             관련  0.466667    0.933333  1.400000
# 56              관련             기업  0.300000    0.450000  1.038462
# 57              기업             관련  0.300000    0.692308  1.038462
# 58              관련             기자  0.500000    0.750000  1.022727
# 59              기자             관련  0.500000    0.681818  1.022727
# 60              관련             뉴스  0.300000    0.450000  1.125000
# 61              뉴스             관련  0.300000    0.750000  1.125000
# 62              관련             때문  0.466667    0.700000  1.235294
# 63              때문             관련  0.466667    0.823529  1.235294
# 64              관련             만큼  0.300000    0.450000  1.350000
# 65              만큼             관련  0.300000    0.900000  1.350000
# 66              관련             사진  0.466667    0.700000  1.312500
# 67              사진             관련  0.466667    0.875000  1.312500
# 68              관련             시장  0.333333    0.500000  1.153846
# 69              시장             관련  0.333333    0.769231  1.153846
# 70              관련             올해  0.366667    0.550000  1.178571
# 71              올해             관련  0.366667    0.785714  1.178571
# 72              관련             이번  0.300000    0.450000  1.227273
# 73              이번             관련  0.300000    0.818182  1.227273
# 74              관련             이상  0.400000    0.600000  1.200000
# 75              이상             관련  0.400000    0.800000  1.200000
# 76              관련             이후  0.333333    0.500000  1.500000
# 77              이후             관련  0.333333    1.000000  1.500000
# 78              관련             중요  0.366667    0.550000  1.375000
# 79              중요             관련  0.366667    0.916667  1.375000
# 80              관련            지난해  0.366667    0.550000  1.031250
# 81             지난해             관련  0.366667    0.687500  1.031250
# 82              관련             필요  0.300000    0.450000  1.350000
# 83              필요             관련  0.300000    0.900000  1.350000
# 84              관련             한국  0.300000    0.450000  1.125000
# 85              한국             관련  0.300000    0.750000  1.125000
# 86              기사             때문  0.366667    0.733333  1.294118
# 87              때문             기사  0.366667    0.647059  1.294118
# 88              기사             사진  0.366667    0.733333  1.375000
# 89              사진             기사  0.366667    0.687500  1.375000
# 90              기사             이상  0.333333    0.666667  1.333333
# 91              이상             기사  0.333333    0.666667  1.333333
# 92              기사             이후  0.300000    0.600000  1.800000
# 93              이후             기사  0.300000    0.900000  1.800000
# 94              기사             필요  0.300000    0.600000  1.800000
# 95              필요             기사  0.300000    0.900000  1.800000
# 96              기자             뉴스  0.366667    0.500000  1.250000
# 97              뉴스             기자  0.366667    0.916667  1.250000
# 98              기자             때문  0.466667    0.636364  1.122995
# 99              때문             기자  0.466667    0.823529  1.122995
# 100             기자             미국  0.366667    0.500000  1.363636
# 101             미국             기자  0.366667    1.000000  1.363636
# 102             기자             사진  0.400000    0.545455  1.022727
# 103             사진             기자  0.400000    0.750000  1.022727
# 104             기자             수요  0.300000    0.409091  1.363636
# 105             수요             기자  0.300000    1.000000  1.363636
# 106             기자             시간  0.300000    0.409091  1.227273
# 107             시간             기자  0.300000    0.900000  1.227273
# 108             기자             시장  0.366667    0.500000  1.153846
# 109             시장             기자  0.366667    0.846154  1.153846
# 110             기자             업계  0.333333    0.454545  1.363636
# 111             업계             기자  0.333333    1.000000  1.363636
# 112             기자             업체  0.333333    0.454545  1.363636
# 113             업체             기자  0.333333    1.000000  1.363636
# 114             기자             올해  0.366667    0.500000  1.071429
# 115             올해             기자  0.366667    0.785714  1.071429
# 116             기자             이상  0.400000    0.545455  1.090909
# 117             이상             기자  0.400000    0.800000  1.090909
# 118             기자             이후  0.300000    0.409091  1.227273
# 119             이후             기자  0.300000    0.900000  1.227273
# 120             기자             중요  0.300000    0.409091  1.022727
# 121             중요             기자  0.300000    0.750000  1.022727
# 122             기자            지난달  0.300000    0.409091  1.363636
# 123            지난달             기자  0.300000    1.000000  1.363636
# 124             기자            지난해  0.433333    0.590909  1.107955
# 125            지난해             기자  0.433333    0.812500  1.107955
# 126             기자             최근  0.400000    0.545455  1.363636
# 127             최근             기자  0.400000    1.000000  1.363636
# 128             기자             최대  0.333333    0.454545  1.239669
# 129             최대             기자  0.333333    0.909091  1.239669
# 130             기자            코로나  0.366667    0.500000  1.153846
# 131            코로나             기자  0.366667    0.846154  1.153846
# 132             기자          코로나19  0.300000    0.409091  1.227273
# 133          코로나19             기자  0.300000    0.900000  1.227273
# 134             기자             한국  0.333333    0.454545  1.136364
# 135             한국             기자  0.333333    0.833333  1.136364
# 136             때문             사진  0.466667    0.823529  1.544118
# 137             사진             때문  0.466667    0.875000  1.544118
# 138             때문             시장  0.333333    0.588235  1.357466
# 139             시장             때문  0.333333    0.769231  1.357466
# 140             때문             이상  0.400000    0.705882  1.411765
# 141             이상             때문  0.400000    0.800000  1.411765
# 142             때문             이유  0.300000    0.529412  1.588235
# 143             이유             때문  0.300000    0.900000  1.588235
# 144             때문             중요  0.366667    0.647059  1.617647
# 145             중요             때문  0.366667    0.916667  1.617647
# 146             때문            코로나  0.333333    0.588235  1.357466
# 147            코로나             때문  0.333333    0.769231  1.357466
# 148             때문             필요  0.300000    0.529412  1.588235
# 149             필요             때문  0.300000    0.900000  1.588235
# 150             때문             한국  0.300000    0.529412  1.323529
# 151             한국             때문  0.300000    0.750000  1.323529
# 152             사진             이상  0.333333    0.625000  1.250000
# 153             이상             사진  0.333333    0.666667  1.250000
# 154             사진             이유  0.333333    0.625000  1.875000
# 155             이유             사진  0.333333    1.000000  1.875000
# 156             사진             중요  0.333333    0.625000  1.562500
# 157             중요             사진  0.333333    0.833333  1.562500
# 158             사진            지난해  0.300000    0.562500  1.054688
# 159            지난해             사진  0.300000    0.562500  1.054688
# 160             사진            코로나  0.300000    0.562500  1.298077
# 161            코로나             사진  0.300000    0.692308  1.298077
# 162             사진             필요  0.300000    0.562500  1.687500
# 163             필요             사진  0.300000    0.900000  1.687500
# 164             시장             이상  0.333333    0.769231  1.538462
# 165             이상             시장  0.333333    0.666667  1.538462
# 166             시장             한국  0.300000    0.692308  1.730769
# 167             한국             시장  0.300000    0.750000  1.730769
# 168             올해             이상  0.300000    0.642857  1.285714
# 169             이상             올해  0.300000    0.600000  1.285714
# 170             올해            지난해  0.333333    0.714286  1.339286
# 171            지난해             올해  0.333333    0.625000  1.339286
# 172             이상             중요  0.300000    0.600000  1.500000
# 173             중요             이상  0.300000    0.750000  1.500000
# 174             이상            코로나  0.300000    0.600000  1.384615
# 175            코로나             이상  0.300000    0.692308  1.384615
# 176            지난해            코로나  0.333333    0.625000  1.442308
# 177            코로나            지난해  0.333333    0.769231  1.442308
# 178            지난해          코로나19  0.300000    0.562500  1.687500
# 179          코로나19            지난해  0.300000    0.900000  1.687500
# 180            코로나          코로나19  0.333333    0.769231  2.307692
# 181          코로나19            코로나  0.333333    1.000000  2.307692
# 182             19         기자,지난해  0.300000    0.818182  1.888112
# 183             기자         19,지난해  0.300000    0.409091  1.227273
# 184            지난해          기자,19  0.300000    0.562500  1.687500
# 185          기자,19            지난해  0.300000    0.900000  1.687500
# 186         19,지난해             기자  0.300000    0.900000  1.227273
# 187         기자,지난해             19  0.300000    0.692308  1.888112
# 188             19         기자,코로나  0.300000    0.818182  2.231405
# 189             기자         19,코로나  0.300000    0.409091  1.227273
# 190            코로나          기자,19  0.300000    0.692308  2.076923
# 191          기자,19            코로나  0.300000    0.900000  2.076923
# 192         19,코로나             기자  0.300000    0.900000  1.227273
# 193         기자,코로나             19  0.300000    0.818182  2.231405
# 194             19       기자,코로나19  0.300000    0.818182  2.727273
# 195             기자       코로나19,19  0.300000    0.409091  1.227273
# 196          코로나19          기자,19  0.300000    0.900000  2.700000
# 197          기자,19          코로나19  0.300000    0.900000  2.700000
# 198       코로나19,19             기자  0.300000    0.900000  1.227273
# 199       기자,코로나19             19  0.300000    1.000000  2.727273
# 200             19        지난해,코로나  0.300000    0.818182  2.454545
# 201            지난해         19,코로나  0.300000    0.562500  1.687500
# 202            코로나         19,지난해  0.300000    0.692308  2.076923
# 203         19,지난해            코로나  0.300000    0.900000  2.076923
# 204         19,코로나            지난해  0.300000    0.900000  1.687500
# 205        지난해,코로나             19  0.300000    0.900000  2.454545
# 206             19      코로나19,지난해  0.300000    0.818182  2.727273
# 207            지난해       코로나19,19  0.300000    0.562500  1.687500
# 208          코로나19         19,지난해  0.300000    0.900000  2.700000
# 209         19,지난해          코로나19  0.300000    0.900000  2.700000
# 210       코로나19,19            지난해  0.300000    0.900000  1.687500
# 211      코로나19,지난해             19  0.300000    1.000000  2.727273
# 212             19      코로나19,코로나  0.333333    0.909091  2.727273
# 213            코로나       코로나19,19  0.333333    0.769231  2.307692
# 214          코로나19         19,코로나  0.333333    1.000000  3.000000
# 215         19,코로나          코로나19  0.333333    1.000000  3.000000
# 216       코로나19,19            코로나  0.333333    1.000000  2.307692
# 217      코로나19,코로나             19  0.333333    1.000000  2.727273
# 218           2019       관련,2019년  0.300000    0.900000  3.000000
# 219          2019년        관련,2019  0.300000    0.900000  3.000000
# 220             관련     2019,2019년  0.300000    0.450000  1.350000
# 221     2019,2019년             관련  0.300000    0.900000  1.350000
# 222        관련,2019          2019년  0.300000    1.000000  3.000000
# 223       관련,2019년           2019  0.300000    1.000000  3.000000
# 224           2019       기자,2019년  0.300000    0.900000  3.000000
# 225          2019년        기자,2019  0.300000    0.900000  3.000000
# 226             기자     2019,2019년  0.300000    0.409091  1.227273
# 227     2019,2019년             기자  0.300000    0.900000  1.227273
# 228        기자,2019          2019년  0.300000    1.000000  3.000000
# 229       기자,2019년           2019  0.300000    1.000000  3.000000
# 230           2019       2019년,사진  0.300000    0.900000  3.000000
# 231          2019년        2019,사진  0.300000    0.900000  3.000000
# 232             사진     2019,2019년  0.300000    0.562500  1.687500
# 233     2019,2019년             사진  0.300000    0.900000  1.687500
# 234        2019,사진          2019년  0.300000    1.000000  3.000000
# 235       2019년,사진           2019  0.300000    1.000000  3.000000
# 236             경우          때문,사진  0.300000    0.900000  1.928571
# 237             때문          경우,사진  0.300000    0.529412  1.764706
# 238             사진          경우,때문  0.300000    0.562500  1.875000
# 239          경우,때문             사진  0.300000    1.000000  1.875000
# 240          경우,사진             때문  0.300000    1.000000  1.764706
# 241          때문,사진             경우  0.300000    0.642857  1.928571
# 242             관련          기자,기사  0.333333    0.500000  1.363636
# 243             기사          관련,기자  0.333333    0.666667  1.333333
# 244             기자          관련,기사  0.333333    0.454545  0.974026
# 245          관련,기사             기자  0.333333    0.714286  0.974026
# 246          관련,기자             기사  0.333333    0.666667  1.333333
# 247          기자,기사             관련  0.333333    0.909091  1.363636
# 248             관련          기사,때문  0.333333    0.500000  1.363636
# 249             기사          관련,때문  0.333333    0.666667  1.428571
# 250             때문          관련,기사  0.333333    0.588235  1.260504
# 251          관련,기사             때문  0.333333    0.714286  1.260504
# 252          관련,때문             기사  0.333333    0.714286  1.428571
# 253          기사,때문             관련  0.333333    0.909091  1.363636
# 254             관련          기사,사진  0.333333    0.500000  1.363636
# 255             기사          관련,사진  0.333333    0.666667  1.428571
# 256             사진          관련,기사  0.333333    0.625000  1.339286
# 257          관련,기사             사진  0.333333    0.714286  1.339286
# 258          관련,사진             기사  0.333333    0.714286  1.428571
# 259          기사,사진             관련  0.333333    0.909091  1.363636
# 260             관련          기사,이상  0.300000    0.450000  1.350000
# 261             기사          관련,이상  0.300000    0.600000  1.500000
# 262             이상          관련,기사  0.300000    0.600000  1.285714
# 263          관련,기사             이상  0.300000    0.642857  1.285714
# 264          관련,이상             기사  0.300000    0.750000  1.500000
# 265          이상,기사             관련  0.300000    0.900000  1.350000
# 266             관련          이후,기사  0.300000    0.450000  1.500000
# 267             기사          관련,이후  0.300000    0.600000  1.800000
# 268             이후          관련,기사  0.300000    0.900000  1.928571
# 269          관련,기사             이후  0.300000    0.642857  1.928571
# 270          관련,이후             기사  0.300000    0.900000  1.800000
# 271          이후,기사             관련  0.300000    1.000000  1.500000
# 272             관련          기자,때문  0.366667    0.550000  1.178571
# 273             기자          관련,때문  0.366667    0.500000  1.071429
# 274             때문          관련,기자  0.366667    0.647059  1.294118
# 275          관련,기자             때문  0.366667    0.733333  1.294118
# 276          관련,때문             기자  0.366667    0.785714  1.071429
# 277          기자,때문             관련  0.366667    0.785714  1.178571
# 278             관련          기자,사진  0.333333    0.500000  1.250000
# 279             기자          관련,사진  0.333333    0.454545  0.974026
# 280             사진          관련,기자  0.333333    0.625000  1.250000
# 281          관련,기자             사진  0.333333    0.666667  1.250000
# 282          관련,사진             기자  0.333333    0.714286  0.974026
# 283          기자,사진             관련  0.333333    0.833333  1.250000
# 284             관련          기자,시장  0.300000    0.450000  1.227273
# 285             기자          관련,시장  0.300000    0.409091  1.227273
# 286             시장          관련,기자  0.300000    0.692308  1.384615
# 287          관련,기자             시장  0.300000    0.600000  1.384615
# 288          관련,시장             기자  0.300000    0.900000  1.227273
# 289          기자,시장             관련  0.300000    0.818182  1.227273
# 290             관련          기자,올해  0.300000    0.450000  1.227273
# 291             기자          관련,올해  0.300000    0.409091  1.115702
# 292             올해          관련,기자  0.300000    0.642857  1.285714
# 293          관련,기자             올해  0.300000    0.600000  1.285714
# 294          관련,올해             기자  0.300000    0.818182  1.115702
# 295          기자,올해             관련  0.300000    0.818182  1.227273
# 296             관련          기자,이상  0.300000    0.450000  1.125000
# 297             기자          관련,이상  0.300000    0.409091  1.022727
# 298             이상          관련,기자  0.300000    0.600000  1.200000
# 299          관련,기자             이상  0.300000    0.600000  1.200000
# 300          관련,이상             기자  0.300000    0.750000  1.022727
# 301          기자,이상             관련  0.300000    0.750000  1.125000
# 302             관련          기자,이후  0.300000    0.450000  1.500000
# 303             기자          관련,이후  0.300000    0.409091  1.227273
# 304             이후          관련,기자  0.300000    0.900000  1.800000
# 305          관련,기자             이후  0.300000    0.600000  1.800000
# 306          관련,이후             기자  0.300000    0.900000  1.227273
# 307          기자,이후             관련  0.300000    1.000000  1.500000
# 308             관련         기자,지난해  0.300000    0.450000  1.038462
# 309             기자         관련,지난해  0.300000    0.409091  1.115702
# 310            지난해          관련,기자  0.300000    0.562500  1.125000
# 311          관련,기자            지난해  0.300000    0.600000  1.125000
# 312         관련,지난해             기자  0.300000    0.818182  1.115702
# 313         기자,지난해             관련  0.300000    0.692308  1.038462
# 314             관련          때문,사진  0.400000    0.600000  1.285714
# 315             때문          관련,사진  0.400000    0.705882  1.512605
# 316             사진          관련,때문  0.400000    0.750000  1.607143
# 317          관련,때문             사진  0.400000    0.857143  1.607143
# 318          관련,사진             때문  0.400000    0.857143  1.512605
# 319          때문,사진             관련  0.400000    0.857143  1.285714
# 320             관련          때문,시장  0.300000    0.450000  1.350000
# 321             때문          관련,시장  0.300000    0.529412  1.588235
# 322             시장          관련,때문  0.300000    0.692308  1.483516
# 323          관련,때문             시장  0.300000    0.642857  1.483516
# 324          관련,시장             때문  0.300000    0.900000  1.588235
# 325          때문,시장             관련  0.300000    0.900000  1.350000
# 326             관련          이상,때문  0.366667    0.550000  1.375000
# 327             때문          관련,이상  0.366667    0.647059  1.617647
# 328             이상          관련,때문  0.366667    0.733333  1.571429
# 329          관련,때문             이상  0.366667    0.785714  1.571429
# 330          관련,이상             때문  0.366667    0.916667  1.617647
# 331          이상,때문             관련  0.366667    0.916667  1.375000
# 332             관련          중요,때문  0.333333    0.500000  1.363636
# 333             때문          관련,중요  0.333333    0.588235  1.604278
# 334             중요          관련,때문  0.333333    0.833333  1.785714
# 335          관련,때문             중요  0.333333    0.714286  1.785714
# 336          관련,중요             때문  0.333333    0.909091  1.604278
# 337          중요,때문             관련  0.333333    0.909091  1.363636
# 338             관련          이상,사진  0.300000    0.450000  1.350000
# 339             사진          관련,이상  0.300000    0.562500  1.406250
# 340             이상          관련,사진  0.300000    0.600000  1.285714
# 341          관련,사진             이상  0.300000    0.642857  1.285714
# 342          관련,이상             사진  0.300000    0.750000  1.406250
# 343          이상,사진             관련  0.300000    0.900000  1.350000
# 344             관련          중요,사진  0.300000    0.450000  1.350000
# 345             사진          관련,중요  0.300000    0.562500  1.534091
# 346             중요          관련,사진  0.300000    0.750000  1.607143
# 347          관련,사진             중요  0.300000    0.642857  1.607143
# 348          관련,중요             사진  0.300000    0.818182  1.534091
# 349          중요,사진             관련  0.300000    0.900000  1.350000
# 350             관련          이상,시장  0.300000    0.450000  1.350000
# 351             시장          관련,이상  0.300000    0.692308  1.730769
# 352             이상          관련,시장  0.300000    0.600000  1.800000
# 353          관련,시장             이상  0.300000    0.900000  1.800000
# 354          관련,이상             시장  0.300000    0.750000  1.730769
# 355          이상,시장             관련  0.300000    0.900000  1.350000
# 356             기사          때문,사진  0.300000    0.600000  1.285714
# 357             때문          기사,사진  0.300000    0.529412  1.443850
# 358             사진          기사,때문  0.300000    0.562500  1.534091
# 359          기사,때문             사진  0.300000    0.818182  1.534091
# 360          기사,사진             때문  0.300000    0.818182  1.443850
# 361          때문,사진             기사  0.300000    0.642857  1.285714
# 362             기사          이상,때문  0.300000    0.600000  1.500000
# 363             때문          기사,이상  0.300000    0.529412  1.588235
# 364             이상          기사,때문  0.300000    0.600000  1.636364
# 365          기사,때문             이상  0.300000    0.818182  1.636364
# 366          이상,기사             때문  0.300000    0.900000  1.588235
# 367          이상,때문             기사  0.300000    0.750000  1.500000
# 368             기자          때문,사진  0.366667    0.500000  1.071429
# 369             때문          기자,사진  0.366667    0.647059  1.617647
# 370             사진          기자,때문  0.366667    0.687500  1.473214
# 371          기자,때문             사진  0.366667    0.785714  1.473214
# 372          기자,사진             때문  0.366667    0.916667  1.617647
# 373          때문,사진             기자  0.366667    0.785714  1.071429
# 374             기자          때문,시장  0.300000    0.409091  1.227273
# 375             때문          기자,시장  0.300000    0.529412  1.443850
# 376             시장          기자,때문  0.300000    0.692308  1.483516
# 377          기자,때문             시장  0.300000    0.642857  1.483516
# 378          기자,시장             때문  0.300000    0.818182  1.443850
# 379          때문,시장             기자  0.300000    0.900000  1.227273
# 380             기자          이상,때문  0.300000    0.409091  1.022727
# 381             때문          기자,이상  0.300000    0.529412  1.323529
# 382             이상          기자,때문  0.300000    0.600000  1.285714
# 383          기자,때문             이상  0.300000    0.642857  1.285714
# 384          기자,이상             때문  0.300000    0.750000  1.323529
# 385          이상,때문             기자  0.300000    0.750000  1.022727
# 386             기자          중요,때문  0.300000    0.409091  1.115702
# 387             때문          기자,중요  0.300000    0.529412  1.764706
# 388             중요          기자,때문  0.300000    0.750000  1.607143
# 389          기자,때문             중요  0.300000    0.642857  1.607143
# 390          기자,중요             때문  0.300000    1.000000  1.764706
# 391          중요,때문             기자  0.300000    0.818182  1.115702
# 392             기자         코로나,때문  0.300000    0.409091  1.227273
# 393             때문         기자,코로나  0.300000    0.529412  1.443850
# 394            코로나          기자,때문  0.300000    0.692308  1.483516
# 395          기자,때문            코로나  0.300000    0.642857  1.483516
# 396         기자,코로나             때문  0.300000    0.818182  1.443850
# 397         코로나,때문             기자  0.300000    0.900000  1.227273
# 398             기자          한국,때문  0.300000    0.409091  1.363636
# 399             때문          기자,한국  0.300000    0.529412  1.588235
# 400             한국          기자,때문  0.300000    0.750000  1.607143
# 401          기자,때문             한국  0.300000    0.642857  1.607143
# 402          기자,한국             때문  0.300000    0.900000  1.588235
# 403          한국,때문             기자  0.300000    1.000000  1.363636
# 404             기자          이상,시장  0.300000    0.409091  1.227273
# 405             시장          기자,이상  0.300000    0.692308  1.730769
# 406             이상          기자,시장  0.300000    0.600000  1.636364
# 407          기자,시장             이상  0.300000    0.818182  1.636364
# 408          기자,이상             시장  0.300000    0.750000  1.730769
# 409          이상,시장             기자  0.300000    0.900000  1.227273
# 410             기자        지난해,코로나  0.300000    0.409091  1.227273
# 411            지난해         기자,코로나  0.300000    0.562500  1.534091
# 412            코로나         기자,지난해  0.300000    0.692308  1.597633
# 413         기자,지난해            코로나  0.300000    0.692308  1.597633
# 414         기자,코로나            지난해  0.300000    0.818182  1.534091
# 415        지난해,코로나             기자  0.300000    0.900000  1.227273
# 416             기자      코로나19,코로나  0.300000    0.409091  1.227273
# 417            코로나       기자,코로나19  0.300000    0.692308  2.307692
# 418          코로나19         기자,코로나  0.300000    0.900000  2.454545
# 419         기자,코로나          코로나19  0.300000    0.818182  2.454545
# 420       기자,코로나19            코로나  0.300000    1.000000  2.307692
# 421      코로나19,코로나             기자  0.300000    0.900000  1.227273
# 422             때문          이상,사진  0.333333    0.588235  1.764706
# 423             사진          이상,때문  0.333333    0.625000  1.562500
# 424             이상          때문,사진  0.333333    0.666667  1.428571
# 425          때문,사진             이상  0.333333    0.714286  1.428571
# 426          이상,때문             사진  0.333333    0.833333  1.562500
# 427          이상,사진             때문  0.333333    1.000000  1.764706
# 428             때문          이유,사진  0.300000    0.529412  1.588235
# 429             사진          이유,때문  0.300000    0.562500  1.875000
# 430             이유          때문,사진  0.300000    0.900000  1.928571
# 431          때문,사진             이유  0.300000    0.642857  1.928571
# 432          이유,때문             사진  0.300000    1.000000  1.875000
# 433          이유,사진             때문  0.300000    0.900000  1.588235
# 434             때문          중요,사진  0.333333    0.588235  1.764706
# 435             사진          중요,때문  0.333333    0.625000  1.704545
# 436             중요          때문,사진  0.333333    0.833333  1.785714
# 437          때문,사진             중요  0.333333    0.714286  1.785714
# 438          중요,때문             사진  0.333333    0.909091  1.704545
# 439          중요,사진             때문  0.333333    1.000000  1.764706
# 440             때문         코로나,사진  0.300000    0.529412  1.764706
# 441             사진         코로나,때문  0.300000    0.562500  1.687500
# 442            코로나          때문,사진  0.300000    0.692308  1.483516
# 443          때문,사진            코로나  0.300000    0.642857  1.483516
# 444         코로나,때문             사진  0.300000    0.900000  1.687500
# 445         코로나,사진             때문  0.300000    1.000000  1.764706
# 446             때문          중요,이상  0.300000    0.529412  1.764706
# 447             이상          중요,때문  0.300000    0.600000  1.636364
# 448             중요          이상,때문  0.300000    0.750000  1.875000
# 449          이상,때문             중요  0.300000    0.750000  1.875000
# 450          중요,때문             이상  0.300000    0.818182  1.636364
# 451          중요,이상             때문  0.300000    1.000000  1.764706
# 452            지난해      코로나19,코로나  0.300000    0.562500  1.687500
# 453            코로나      코로나19,지난해  0.300000    0.692308  2.307692
# 454          코로나19        지난해,코로나  0.300000    0.900000  2.700000
# 455        지난해,코로나          코로나19  0.300000    0.900000  2.700000
# 456      코로나19,지난해            코로나  0.300000    1.000000  2.307692
# 457      코로나19,코로나            지난해  0.300000    0.900000  1.687500
# 458             19   기자,코로나19,코로나  0.300000    0.818182  2.727273
# 459             기자   코로나19,19,코로나  0.300000    0.409091  1.227273
# 460            코로나    기자,19,코로나19  0.300000    0.692308  2.307692
# 461          코로나19      기자,19,코로나  0.300000    0.900000  3.000000
# 462          기자,19      코로나19,코로나  0.300000    0.900000  2.700000
# 463         19,코로나       기자,코로나19  0.300000    0.900000  3.000000
# 464       코로나19,19         기자,코로나  0.300000    0.900000  2.454545
# 465         기자,코로나       코로나19,19  0.300000    0.818182  2.454545
# 466       기자,코로나19         19,코로나  0.300000    1.000000  3.000000
# 467      코로나19,코로나          기자,19  0.300000    0.900000  2.700000
# 468      기자,19,코로나          코로나19  0.300000    1.000000  3.000000
# 469    기자,19,코로나19            코로나  0.300000    1.000000  2.307692
# 470   코로나19,19,코로나             기자  0.300000    0.900000  1.227273
# 471   기자,코로나19,코로나             19  0.300000    1.000000  2.727273
# 472             19  코로나19,지난해,코로나  0.300000    0.818182  2.727273
# 473            지난해   코로나19,19,코로나  0.300000    0.562500  1.687500
# 474            코로나   코로나19,19,지난해  0.300000    0.692308  2.307692
# 475          코로나19     19,지난해,코로나  0.300000    0.900000  3.000000
# 476         19,지난해      코로나19,코로나  0.300000    0.900000  2.700000
# 477         19,코로나      코로나19,지난해  0.300000    0.900000  3.000000
# 478       코로나19,19        지난해,코로나  0.300000    0.900000  2.700000
# 479        지난해,코로나       코로나19,19  0.300000    0.900000  2.700000
# 480      코로나19,지난해         19,코로나  0.300000    1.000000  3.000000
# 481      코로나19,코로나         19,지난해  0.300000    0.900000  2.700000
# 482     19,지난해,코로나          코로나19  0.300000    1.000000  3.000000
# 483   코로나19,19,지난해            코로나  0.300000    1.000000  2.307692
# 484   코로나19,19,코로나            지난해  0.300000    0.900000  1.687500
# 485  코로나19,지난해,코로나             19  0.300000    1.000000  2.727273
# 486             관련       기자,때문,사진  0.300000    0.450000  1.227273
# 487             기자       관련,때문,사진  0.300000    0.409091  1.022727
# 488             때문       관련,기자,사진  0.300000    0.529412  1.588235
# 489             사진       관련,기자,때문  0.300000    0.562500  1.534091
# 490          관련,기자          때문,사진  0.300000    0.600000  1.285714
# 491          관련,때문          기자,사진  0.300000    0.642857  1.607143
# 492          관련,사진          기자,때문  0.300000    0.642857  1.377551
# 493          기자,때문          관련,사진  0.300000    0.642857  1.377551
# 494          기자,사진          관련,때문  0.300000    0.750000  1.607143
# 495          때문,사진          관련,기자  0.300000    0.642857  1.285714
# 496       관련,기자,때문             사진  0.300000    0.818182  1.534091
# 497       관련,기자,사진             때문  0.300000    0.900000  1.588235
# 498       관련,때문,사진             기자  0.300000    0.750000  1.022727
# 499       기자,때문,사진             관련  0.300000    0.818182  1.227273
# 500             관련       이상,때문,사진  0.300000    0.450000  1.350000
# 501             때문       관련,이상,사진  0.300000    0.529412  1.764706
# 502             사진       관련,이상,때문  0.300000    0.562500  1.534091
# 503             이상       관련,때문,사진  0.300000    0.600000  1.500000
# 504          관련,때문          이상,사진  0.300000    0.642857  1.928571
# 505          관련,사진          이상,때문  0.300000    0.642857  1.607143
# 506          관련,이상          때문,사진  0.300000    0.750000  1.607143
# 507          때문,사진          관련,이상  0.300000    0.642857  1.607143
# 508          이상,때문          관련,사진  0.300000    0.750000  1.607143
# 509          이상,사진          관련,때문  0.300000    0.900000  1.928571
# 510       관련,때문,사진             이상  0.300000    0.750000  1.500000
# 511       관련,이상,때문             사진  0.300000    0.818182  1.534091
# 512       관련,이상,사진             때문  0.300000    1.000000  1.764706
# 513       이상,때문,사진             관련  0.300000    0.900000  1.350000
# 514             관련       중요,때문,사진  0.300000    0.450000  1.350000
# 515             때문       관련,중요,사진  0.300000    0.529412  1.764706
# 516             사진       관련,중요,때문  0.300000    0.562500  1.687500
# 517             중요       관련,때문,사진  0.300000    0.750000  1.875000
# 518          관련,때문          중요,사진  0.300000    0.642857  1.928571
# 519          관련,사진          중요,때문  0.300000    0.642857  1.753247
# 520          관련,중요          때문,사진  0.300000    0.818182  1.753247
# 521          때문,사진          관련,중요  0.300000    0.642857  1.753247
# 522          중요,때문          관련,사진  0.300000    0.818182  1.753247
# 523          중요,사진          관련,때문  0.300000    0.900000  1.928571
# 524       관련,때문,사진             중요  0.300000    0.750000  1.875000
# 525       관련,중요,때문             사진  0.300000    0.900000  1.687500
# 526       관련,중요,사진             때문  0.300000    1.000000  1.764706
# 527       중요,때문,사진             관련  0.300000    0.900000  1.350000

# %%
result_df.loc[(result_df.lhs.str.contains('기자'))].sort_values(
    by=['lift'],
    ascending=False)
# Out:
#               lhs           rhs   support  confidence      lift
# 228       기자,2019         2019년  0.300000    1.000000  3.000000
# 229      기자,2019년          2019  0.300000    1.000000  3.000000
# 466      기자,코로나19        19,코로나  0.300000    1.000000  3.000000
# 468     기자,19,코로나         코로나19  0.300000    1.000000  3.000000
# 199      기자,코로나19            19  0.300000    1.000000  2.727273
# 471  기자,코로나19,코로나            19  0.300000    1.000000  2.727273
# 462         기자,19     코로나19,코로나  0.300000    0.900000  2.700000
# 197         기자,19         코로나19  0.300000    0.900000  2.700000
# 465        기자,코로나      코로나19,19  0.300000    0.818182  2.454545
# 419        기자,코로나         코로나19  0.300000    0.818182  2.454545
# 420      기자,코로나19           코로나  0.300000    1.000000  2.307692
# 469   기자,19,코로나19           코로나  0.300000    1.000000  2.307692
# 193        기자,코로나            19  0.300000    0.818182  2.231405
# 191         기자,19           코로나  0.300000    0.900000  2.076923
# 187        기자,지난해            19  0.300000    0.692308  1.888112
# 305         관련,기자            이후  0.300000    0.600000  1.800000
# 390         기자,중요            때문  0.300000    1.000000  1.764706
# 408         기자,이상            시장  0.300000    0.750000  1.730769
# 185         기자,19           지난해  0.300000    0.900000  1.687500
# 407         기자,시장            이상  0.300000    0.818182  1.636364
# 372         기자,사진            때문  0.366667    0.916667  1.617647
# 494         기자,사진         관련,때문  0.300000    0.750000  1.607143
# 401         기자,때문            한국  0.300000    0.642857  1.607143
# 389         기자,때문            중요  0.300000    0.642857  1.607143
# 413        기자,지난해           코로나  0.300000    0.692308  1.597633
# 497      관련,기자,사진            때문  0.300000    0.900000  1.588235
# 402         기자,한국            때문  0.300000    0.900000  1.588235
# 414        기자,코로나           지난해  0.300000    0.818182  1.534091
# 496      관련,기자,때문            사진  0.300000    0.818182  1.534091
# 307         기자,이후            관련  0.300000    1.000000  1.500000
# 377         기자,때문            시장  0.300000    0.642857  1.483516
# 395         기자,때문           코로나  0.300000    0.642857  1.483516
# 371         기자,때문            사진  0.366667    0.785714  1.473214
# 378         기자,시장            때문  0.300000    0.818182  1.443850
# 396        기자,코로나            때문  0.300000    0.818182  1.443850
# 287         관련,기자            시장  0.300000    0.600000  1.384615
# 493         기자,때문         관련,사진  0.300000    0.642857  1.377551
# 41             기자            가격  0.366667    0.500000  1.363636
# 398            기자         한국,때문  0.300000    0.409091  1.363636
# 247         기자,기사            관련  0.333333    0.909091  1.363636
# 126            기자            최근  0.400000    0.545455  1.363636
# 53             기자           관계자  0.300000    0.409091  1.363636
# 104            기자            수요  0.300000    0.409091  1.363636
# 122            기자           지난달  0.300000    0.409091  1.363636
# 100            기자            미국  0.366667    0.500000  1.363636
# 112            기자            업체  0.333333    0.454545  1.363636
# 110            기자            업계  0.333333    0.454545  1.363636
# 246         관련,기자            기사  0.333333    0.666667  1.333333
# 384         기자,이상            때문  0.300000    0.750000  1.323529
# 275         관련,기자            때문  0.366667    0.733333  1.294118
# 293         관련,기자            올해  0.300000    0.600000  1.285714
# 383         기자,때문            이상  0.300000    0.642857  1.285714
# 490         관련,기자         때문,사진  0.300000    0.600000  1.285714
# 281         관련,기자            사진  0.333333    0.666667  1.250000
# 96             기자            뉴스  0.366667    0.500000  1.250000
# 283         기자,사진            관련  0.333333    0.833333  1.250000
# 128            기자            최대  0.333333    0.454545  1.239669
# 39             기자            2일  0.333333    0.454545  1.239669
# 17             기자            19  0.333333    0.454545  1.239669
# 374            기자         때문,시장  0.300000    0.409091  1.227273
# 289         기자,시장            관련  0.300000    0.818182  1.227273
# 392            기자        코로나,때문  0.300000    0.409091  1.227273
# 404            기자         이상,시장  0.300000    0.409091  1.227273
# 416            기자     코로나19,코로나  0.300000    0.409091  1.227273
# 459            기자  코로나19,19,코로나  0.300000    0.409091  1.227273
# 410            기자       지난해,코로나  0.300000    0.409091  1.227273
# 499      기자,때문,사진            관련  0.300000    0.818182  1.227273
# 189            기자        19,코로나  0.300000    0.409091  1.227273
# 295         기자,올해            관련  0.300000    0.818182  1.227273
# 132            기자         코로나19  0.300000    0.409091  1.227273
# 183            기자        19,지난해  0.300000    0.409091  1.227273
# 195            기자      코로나19,19  0.300000    0.409091  1.227273
# 226            기자    2019,2019년  0.300000    0.409091  1.227273
# 106            기자            시간  0.300000    0.409091  1.227273
# 118            기자            이후  0.300000    0.409091  1.227273
# 13             기자          1000  0.300000    0.409091  1.227273
# 285            기자         관련,시장  0.300000    0.409091  1.227273
# 35             기자         2019년  0.300000    0.409091  1.227273
# 303            기자         관련,이후  0.300000    0.409091  1.227273
# 29             기자          2019  0.300000    0.409091  1.227273
# 299         관련,기자            이상  0.300000    0.600000  1.200000
# 277         기자,때문            관련  0.366667    0.785714  1.178571
# 108            기자            시장  0.366667    0.500000  1.153846
# 130            기자           코로나  0.366667    0.500000  1.153846
# 134            기자            한국  0.333333    0.454545  1.136364
# 301         기자,이상            관련  0.300000    0.750000  1.125000
# 311         관련,기자           지난해  0.300000    0.600000  1.125000
# 98             기자            때문  0.466667    0.636364  1.122995
# 291            기자         관련,올해  0.300000    0.409091  1.115702
# 386            기자         중요,때문  0.300000    0.409091  1.115702
# 309            기자        관련,지난해  0.300000    0.409091  1.115702
# 124            기자           지난해  0.433333    0.590909  1.107955
# 116            기자            이상  0.400000    0.545455  1.090909
# 114            기자            올해  0.366667    0.500000  1.071429
# 368            기자         때문,사진  0.366667    0.500000  1.071429
# 273            기자         관련,때문  0.366667    0.500000  1.071429
# 313        기자,지난해            관련  0.300000    0.692308  1.038462
# 102            기자            사진  0.400000    0.545455  1.022727
# 59             기자            관련  0.500000    0.681818  1.022727
# 120            기자            중요  0.300000    0.409091  1.022727
# 487            기자      관련,때문,사진  0.300000    0.409091  1.022727
# 45             기자            가치  0.300000    0.409091  1.022727
# 297            기자         관련,이상  0.300000    0.409091  1.022727
# 380            기자         이상,때문  0.300000    0.409091  1.022727
# 5              기자            10  0.300000    0.409091  1.022727
# 244            기자         관련,기사  0.333333    0.454545  0.974026
# 279            기자         관련,사진  0.333333    0.454545  0.974026

# %%
result_df.loc[(result_df.lhs.str.contains('기자')) &
              result_df.rhs.str.contains('한국')].sort_values(
by=['lift'], 
ascending=False)
# Out:
#        lhs    rhs   support  confidence      lift
# 401  기자,때문     한국  0.300000    0.642857  1.607143
# 398     기자  한국,때문  0.300000    0.409091  1.363636
# 134     기자     한국  0.333333    0.454545  1.136364

# %%
# 연습해보기 
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Kkma

kkma = Kkma()

test_url = 'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%BD%94%EB%A1%9C%EB%82%98'
test_response = requests.get(test_url)
test_soup = BeautifulSoup(test_response.content, 'html.parser')
text_content = test_soup.select('.f_eb')

news = []

for text in text_content:
    news.append(list(filter(
        lambda word : len(word)>1 and word != '기자',
        kkma.nouns(text.text))))

# %%
news_nouns = set()

for new in news:
    for n in new:
        news_nouns.add(n)
        
print('코로나 기사에 나오는 단어들: ', news_nouns)
print(len(news_nouns))
# Out:
# 코로나 기사에 나오는 단어들:  {'한번', '국외발생현황', '아픔', '가운데', '3월', '생계', '공개', '참조', '센터', '현황', '이달', '번호', '지역콜센터120', '스감염증-19', '29일', '38', '기체', '10', '400', '할리우드', '1년', '오늘', '사실', '자료', '제공', '고온', '증상완화', '길거리', '1339콜센터', '관할보건소', '실시간', '바이러스', '다음달', '38도', '진료', '코로나19', '부곰', '사람', '태양', '박창', '기네스', '대상', '반응', '전리', '용어', '국외', '2020년', '400명대', '단순', '방문자', '완치', '콜센터', '노출', '차례', '존스', '아빠', '성공', '2천', '발생', '자제', '나눔', '이후', '강도', '수칙', '영역', '남자', '청년', '수입', '신규', '의료기관', '검색어', '초고온', '유행성', '예방수칙', '사회적', '결과', '고공행진', '의식', '진자', '반품', '스트레스', '전세', '가능하다', '백신접종', '광고노출기준', '무엇', '이상', '2천7백', '쇼핑', '7377', '질병관리청', '영국', '공지사항', '동기', '성혜미', '건강보험', '눈길', '이동', '상담', '네덜란드', '생각', '유세', '병원', '관심', '상태', '2019년', '코로나바', '00시', '당일', '감염증', '이러스', '끝나도', '29', '2019', '1월', '토요일', '동반', '스감', '중국산', '남성', '상위', '증상', '지역국번', '12', '염증', '전계', '양성', '논란', '폐렴', '문제', '한국', '로이터', '가지', '고함', '한시', '60', '캠페인', '경과', '증강', '앵커', '6월', '닷새', '마스크', '건강', '지역', '가스', '연관성', '발표', '마음', '감기', '집계', '국가별', '대기', '참여', '2020', '존스홉킨스대학교', '관련', '11월', '고백', '불량', '중국방문자', '안내', '식이요법', '현장', '일본', '120', '방송', '입찰', '서울', '실시', '때문', '제품', '행동', '계속', '온오프', '식별', '운영', '정부', '접종', '돌체', '여러분', '선별', '요즘', '안녕', '감염자', '대표번호', '202102251320', '로이', '임계', '보건소', '사항', '1339', '동포', '스감염증', '접촉', '출마', '백신', '5월', '그림자', '대학교', '기침', '인도네시아', '시도별', '호흡기증상', '방문', '고개', '효과', '행진', '문서', '무증상', '나눔캠페인', '취재', '코로나', '무료', '고공', '가능', '기네스팰트', '회사', '전계강도', '안일', '11', '물질', '민주당', '공식', '플라스마', '홉킨스', '평가', '광고주의', '수가', '10시', '신종', '우선시한', '투표', '한국분', '한국인', '00000024', '공지', '팬데믹', '숫자', '동향', '식품', '터널', '이유', '세계', '경로', '관할', '보험', '판정', '뉴스', '지속', '육안', '전염성', '우리', '마지막', '시한', '완화', '상황', '청하', '예방', '가치', '치료', '형성', '바깥쪽', '11776', '주의', '선별진료소', '우리나라', '비누', '요령', '고열', '예산', '최근', '데이터', '연속', '초기', '의원', '인사', '통신', '요법', '진료소', '인후통', '파키스탄', '지도', '사업가', '전역', '차트', '김치', '변심', '코로나바이러스', '확인', '팰트', '기관', '12월', '2월', '중국', '서비스', '국번', '우한시', '기준', '행동요령', '식구', '음악', '총선', '교환', '시대', '의료', '주위', '호흡기', '경제', '어깨', '코로나때문', '9월', '미국', '차단', '이웋', '교민', '-19', '방전', '블루', '우선', '유산균', '일일', '관련뉴스', '발열', '표면', '나라', '가열', '도움', '4월', '배우', '8월', '대응', '선거', '식이', '7월', '시도', '정부대응발표', '데이터차트', '경제지원', '지면', '유의사항', '나도', '연속기획', '특징', '유의', '철탑', '아무것', '감염', '설탕', '기획', '대표', '방역', '대통령', '제품교환', '20210224', '60대', '나의', '모습', '하다', '00', '소속', '연합', '단순변심', '착용', '지원', '도체', '지역콜센터', '19', '우울감', '정보', '현지', '공기', '연합뉴스', '광고', '구성', '관리청', '거리', '무료반품', '이온화', '이동경로', '질환', '유럽', '언론', '구의원', '면역', '질병', '영화', '바깥', '인후', '목아픔', '발광', '10월', '특파원'}
# 393

# %%
rules = apriori(news, 
                min_support=0.2,
                min_confidence=0.2)
result = list(rules)
result
# Out:
# [RelationRecord(items=frozenset({'코로나'}), support=0.5263157894736842, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나'}), confidence=0.5263157894736842, lift=1.0)])]

# %%
from gensim.models import Word2Vec

model = Word2Vec(news, size=100, 
                 window=5, min_count=2, 
                 workers=-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a08237bfb17f> in <module>
#       1 from gensim.models import Word2Vec
#       2
# ----> 3 model = Word2Vec(news, size=100,
#       4                  window=5, min_count=2,
#       5                  workers=-1)
#
# TypeError: __init__() got an unexpected keyword argument 'size'

# %%
model.wv.most_similar('감염증')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-655f265a7713> in <module>
# ----> 1 model.wv.most_similar('감염증')
#
# NameError: name 'model' is not defined
