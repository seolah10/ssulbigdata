# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.CodeMirror {font-family:Consolas; font-size:10pt;}
div.output {font-size:10pt;}
div.input {font-family:Consolas; font-size:10pt;}
div.prompt {min-width:70px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.CodeMirror {font-family:Consolas; font-size:10pt;}
# div.output {font-size:10pt;}
# div.input {font-family:Consolas; font-size:10pt;}
# div.prompt {min-width:70px;}
# </style>

# %% [markdown]
# **<font color='darkred' size='6'>ch03. 연관분석(장바구니분석)</font>**

# %% [markdown]
# # 연관분석 개요

# %% [markdown]
# <pre>
# - 데이터들 사이에서 <b>'자주'</b> 발생하는 속성을 찾고 그 속성들 사이에 어느 정도 있는지를 분석하는 방법
# - 활용분야: 상품진열, 사기보험적발, 카탈로그디자인, 신상품 카테고리 구성
# - 연관성분석 관련 지표
#     - 지지도(support) = 조건결과 항목 수/ 전체 수
#     - 신뢰도(confidence) = 조건결과 항목 수 / 조건 항목 수
#     - 향상도(lift): 우연히 발생한 규칙인지 아닌지 여부를 확인
#                    = 조건 결과 지지도 / (조건지지도) * (결과지지도)
#                        => 1(상관관계 없음)
#                          >1(양의 상관관계)
#                          <1(음의 상관관계)
#
#     [조건] => [결과]  지지도   신뢰도    향상도  (cf_basket.csv)
#     [주스] => [콜라]   0.4       1      0.4 / (0.4) * (1) = 1
#     [소주] => [맥주]   0.2     0.333..  0.3 / (0.6) * (0.4) = 0.833...
# </pre>

# %%
import os
os.getcwd() # 가져올 데이터는 반드시 이 폴더 안에 있어야 한다.
# Out:
# 'D:\\BigData\\src\\09_자연어처리'

# %%
# 트랜잭션 데이터 가져오기 
import csv

transaction = []
with open('cf_basket.csv', 'r', encoding='utf-8') as cf:
    csvdata = csv.reader(cf)
    # transaction = list(csvdata) # 리스트로 형변환
    for row in csvdata:           # 혹은 for문 돌리기
        transaction.append(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-6c4bd2706388> in <module>
#       3
#       4 transaction = []
# ----> 5 with open('cf_basket.csv', 'r', encoding='utf-8') as cf:
#       6     csvdata = csv.reader(cf)
#       7     # transaction = list(csvdata) # 리스트로 형변환
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cf_basket.csv'

# %%
transaction
# Out:
# [['소주', '콜라', '와인'],
#  ['소주', '오렌지주스', '콜라'],
#  ['콜라', '맥주', '와인'],
#  ['소주', '콜라', '맥주'],
#  ['오렌지주스', '와인', '콜라']]

# %% [markdown]
# # 연관분석
# - pip install apyori

# %% [markdown]
# ## 연관 규칙 생성

# %%
from apyori import apriori # 연관성 규칙 생성 

rules = apriori(transaction, min_support=0.2, min_confidence=0.1) # 지지도가 0.2이상인 경우만 연관분석해라.. .. 
rules = list(rules)
len(rules)
# Out:
# 0

# %%
rules[15]
# Out:
# RelationRecord(items=frozenset({'콜라', '와인', '맥주'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'콜라', '맥주', '와인'}), confidence=0.2, lift=1.0), OrderedStatistic(items_base=frozenset({'맥주'}), items_add=frozenset({'콜라', '와인'}), confidence=0.5, lift=0.8333333333333334), OrderedStatistic(items_base=frozenset({'와인'}), items_add=frozenset({'콜라', '맥주'}), confidence=0.33333333333333337, lift=0.8333333333333334), OrderedStatistic(items_base=frozenset({'콜라'}), items_add=frozenset({'맥주', '와인'}), confidence=0.2, lift=1.0), OrderedStatistic(items_base=frozenset({'와인', '맥주'}), items_add=frozenset({'콜라'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'콜라', '맥주'}), items_add=frozenset({'와인'}), confidence=0.5, lift=0.8333333333333334), OrderedStatistic(items_base=frozenset({'콜라', '와인'}), items_add=frozenset({'맥주'}), confidence=0.33333333333333337, lift=0.8333333333333334)])

# %%
rules[1]
# Out:
# RelationRecord(items=frozenset({'소주'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'소주'}), confidence=0.6, lift=1.0)])

# %%
print('조건    ->     결과 \t 지지도 \t 신뢰도 \t 향상도')
for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        lhs = ', '.join(x for x in item[0])
        lhs = [x for x in item[0]] # 조건 (left hand side)
        rhs = ', '.join(x for x in item[1])
        rhs = [x for x in item[1]] # 결과 (right hand side)
        confidence = item[2]
        lift = item[3]
        if lift != 1:
            print(lhs, '=>', rhs, '\t{:5.3f}\t{:5.3f}\t{:5.3f}'.format(support, confidence, lift))
# Out:
# 조건    ->     결과 	 지지도 	 신뢰도 	 향상도
# ['맥주'] => ['소주'] 	0.200	0.500	0.833
# ['소주'] => ['맥주'] 	0.200	0.333	0.833
# ['맥주'] => ['와인'] 	0.200	0.500	0.833
# ['와인'] => ['맥주'] 	0.200	0.333	0.833
# ['소주'] => ['오렌지주스'] 	0.200	0.333	0.833
# ['오렌지주스'] => ['소주'] 	0.200	0.500	0.833
# ['소주'] => ['와인'] 	0.200	0.333	0.556
# ['와인'] => ['소주'] 	0.200	0.333	0.556
# ['오렌지주스'] => ['와인'] 	0.200	0.500	0.833
# ['와인'] => ['오렌지주스'] 	0.200	0.333	0.833
# ['맥주'] => ['소주', '콜라'] 	0.200	0.500	0.833
# ['소주'] => ['콜라', '맥주'] 	0.200	0.333	0.833
# ['콜라', '맥주'] => ['소주'] 	0.200	0.500	0.833
# ['소주', '콜라'] => ['맥주'] 	0.200	0.333	0.833
# ['맥주'] => ['콜라', '와인'] 	0.200	0.500	0.833
# ['와인'] => ['콜라', '맥주'] 	0.200	0.333	0.833
# ['콜라', '맥주'] => ['와인'] 	0.200	0.500	0.833
# ['콜라', '와인'] => ['맥주'] 	0.200	0.333	0.833
# ['소주'] => ['콜라', '오렌지주스'] 	0.200	0.333	0.833
# ['오렌지주스'] => ['소주', '콜라'] 	0.200	0.500	0.833
# ['소주', '콜라'] => ['오렌지주스'] 	0.200	0.333	0.833
# ['콜라', '오렌지주스'] => ['소주'] 	0.200	0.500	0.833
# ['소주'] => ['콜라', '와인'] 	0.200	0.333	0.556
# ['와인'] => ['소주', '콜라'] 	0.200	0.333	0.556
# ['소주', '콜라'] => ['와인'] 	0.200	0.333	0.556
# ['콜라', '와인'] => ['소주'] 	0.200	0.333	0.556
# ['오렌지주스'] => ['콜라', '와인'] 	0.200	0.500	0.833
# ['와인'] => ['콜라', '오렌지주스'] 	0.200	0.333	0.833
# ['콜라', '오렌지주스'] => ['와인'] 	0.200	0.500	0.833
# ['콜라', '와인'] => ['오렌지주스'] 	0.200	0.333	0.833

# %% [markdown]
# # 뉴스기사 연관 분석 실습

# %% [markdown]
# ## 뉴스 RSS을 이용해서 기사 검색 후 연관 분석

# %%
import requests 
from bs4 import BeautifulSoup 

rss_url = "https://rss.joins.com/joins_money_list.xml"
money_response = requests.get(rss_url)
money_soup = BeautifulSoup(money_response.content, 'xml')
link_list = money_soup.select('item > link')
link_list = [l.text for l in link_list]
len(link_list)
# Out:
# 30

# %%
from konlpy.tag import Kkma
kkma = Kkma()
news = []

for link in link_list:
    news_response =  requests.get(link) # (위의 리스트 컴프리헨션에서 .text를 포함하므로 여기서는 생략한다.)
    news_soup = BeautifulSoup(news_response.content, 'html.parser')
    news_content = news_soup.select_one('div#article_body').text # 기사 내용 
    nouns_list = list(filter(lambda word : len(word)>1, kkma.nouns(news_content))) # 1글자 넘을 때만 명사 추출해
    news.append(nouns_list)
news
# Out:
# [['마일리지',
#   '통합',
#   '결제',
#   '플랫폼',
#   '마일',
#   '마일벌스',
#   '벌스',
#   '대표',
#   '대표이사',
#   '이사',
#   '정진',
#   '정진형',
#   '26',
#   '26일',
#   '서비스',
#   '중인',
#   '디지털',
#   '디지털상품권',
#   '상품권',
#   '10',
#   '10여종',
#   '여종',
#   '구매',
#   '구매상품',
#   '상품',
#   '추가',
#   '업데이트',
#   '이번',
#   '상품추가',
#   '기존',
#   '판매',
#   '30',
#   '30여종',
#   '편의점',
#   '커피',
#   '치킨',
#   '베이커리',
#   '영화',
#   '뷰티',
#   '이외',
#   '게임',
#   '기프트카드',
#   '프트',
#   '카드',
#   '백화점',
#   '외식',
#   '가능',
#   '사용자',
#   '선택',
#   '의미',
#   '활성화',
#   '도움',
#   '예상',
#   '신규',
#   '유입',
#   '효과',
#   '전망',
#   '제한',
#   '사용처',
#   '사용',
#   '고객',
#   '다양',
#   '이용',
#   '가맹점',
#   '확장',
#   '마일벌',
#   '기업',
#   '포인트',
#   '교환',
#   '커피전문점',
#   '전문점',
#   '실생활',
#   '현금',
#   '중앙',
#   '중앙일보',
#   '일보',
#   '엠앤서비스',
#   '제휴',
#   '지원',
#   '구글플레이',
#   '플레이',
#   '앱스토어',
#   '다운로드',
#   '당일',
#   '당일기준',
#   '기준',
#   '출시',
#   '60',
#   '60일만',
#   '누적',
#   '30,000',
#   '달성',
#   '온라인'],
#  ['한국',
#   '한국과학기술정보',
#   '과학',
#   '기술',
#   '정보',
#   '연구원',
#   '원장',
#   '김재수',
#   '재수',
#   '이하',
#   '프린팅',
#   '산업',
#   '활성',
#   '활성방안',
#   '방안',
#   '연구',
#   '책자',
#   '3월',
#   '23',
#   '23일',
#   '발행',
#   '기계',
#   '금속',
#   '고분자',
#   '세라믹',
#   '관련',
#   '전문가',
#   '소재',
#   '총망라',
#   '발간',
#   '단편적',
#   '매체',
#   '소개',
#   '개념',
#   '단계',
#   '이번',
#   '기술별',
#   '체계적',
#   '정리',
#   '최근',
#   '동향',
#   '이해',
#   '권영일',
#   '영일',
#   '책임',
#   '책임연구원',
#   '강민철',
#   '프린팅연구조합',
#   '조합',
#   '상임',
#   '상임이사',
#   '이사',
#   '김윤철',
#   '성균관',
#   '성균관대',
#   '화학',
#   '화학공학고분자공학부',
#   '공학',
#   '공학부',
#   '교수',
#   '배창준',
#   '창준',
#   '한국재료연구원',
#   '재료',
#   '이슬비',
#   '부산',
#   '부산대학교',
#   '대학교',
#   '박사',
#   '공동',
#   '필집',
#   '도서',
#   '국내외',
#   '활성화',
#   '전문',
#   '부족',
#   '실정',
#   '원리',
#   '소프트',
#   '소프트웨어',
#   '웨어',
#   '응용',
#   '응용분야',
#   '분야',
#   '구성',
#   '주요',
#   '내용',
#   '4차',
#   '산업혁명',
#   '혁명',
#   '제조',
#   '제조시스템',
#   '시스템',
#   '디지털',
#   '기존',
#   '제조방식',
#   '방식',
#   '혁신',
#   '전통적',
#   '비즈니스',
#   '모델',
#   '변혁',
#   '가능성',
#   '때문',
#   '인터넷',
#   '플랫폼',
#   '소비자',
#   '요구',
#   '요구사항',
#   '사항',
#   '데이터',
#   '입력',
#   '주문',
#   '개인',
#   '제조업자',
#   '업자',
#   '중심',
#   '확장',
#   '사업',
#   '보완',
#   '관계',
#   '공존',
#   '전망',
#   '세계',
#   '시장',
#   '규모',
#   '성장',
#   '2022',
#   '2022년',
#   '262',
#   '262억',
#   '달러',
#   '29',
#   '29조원',
#   '현재',
#   '미국',
#   '일본',
#   '중국',
#   '유럽',
#   '다수',
#   '해외',
#   '기업',
#   '기술력',
#   '바탕',
#   '선도',
#   '공정',
#   '적용',
#   '제품',
#   '상용',
#   '국내',
#   '국내시장',
#   '경우',
#   '수년',
#   '수년간',
#   '교육',
#   '우주',
#   '우주항공',
#   '항공',
#   '자동차',
#   '부품',
#   '시제품',
#   '제작',
#   '등에',
#   '활용',
#   '의료',
#   '치과',
#   '생활',
#   '생활소비재',
#   '소비재',
#   '완제품',
#   '생산',
#   '확산',
#   '그간',
#   '성장률',
#   '부진',
#   '정부',
#   '시장규모',
#   '1조원',
#   '성공',
#   '사례',
#   '적극적',
#   '발굴',
#   '완성',
#   '완성차',
#   '업체',
#   '생산공정',
#   '개선',
#   '현장',
#   '도입',
#   '증가',
#   '세계선',
#   '점유율',
#   '스타트',
#   '스타트업',
#   '글로벌',
#   '제조기업',
#   '협업',
#   '확대',
#   '산업구조',
#   '구조',
#   '변화',
#   '우리',
#   '홈페이지',
#   '전자책',
#   '형태',
#   '게재',
#   '예정',
#   '온라인',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['26',
#   '26일',
#   '승진',
#   '대상',
#   '대상그룹',
#   '그룹',
#   '부회장',
#   '회장',
#   '사진',
#   '44',
#   '전무',
#   '지주',
#   '지주회사',
#   '회사',
#   '대상홀딩스와',
#   '홀딩',
#   '스와',
#   '임창',
#   '명예',
#   '명예회장',
#   '장녀',
#   '차녀',
#   '임상',
#   '임상민',
#   '41',
#   '자매',
#   '경영',
#   '체제',
#   '본격',
#   '궤도',
#   '해석',
#   '부회',
#   '대상홀딩스',
#   '딩스',
#   '전략',
#   '전략담당',
#   '담당',
#   '중역',
#   '기존',
#   '마케팅',
#   '마케팅담당',
#   '보직',
#   '동시',
#   '수행',
#   '관련',
#   '대상홀딩',
#   '이날',
#   '정기',
#   '주주',
#   '주주총회',
#   '총회',
#   '사내',
#   '사내이사',
#   '이사',
#   '신규',
#   '선임',
#   '안건',
#   '의결',
#   '연세대',
#   '경영학',
#   '공부',
#   '이후',
#   '미국',
#   '뉴욕',
#   '뉴욕대',
#   '심리학',
#   '전공',
#   '1998',
#   '1998년',
#   '이재',
#   '삼성',
#   '삼성전자',
#   '전자',
#   '결혼',
#   '2009',
#   '2009년',
#   '이혼',
#   '2012',
#   '2012년',
#   '크리',
#   '티브',
#   '디렉터',
#   '직책',
#   '합류',
#   '2014',
#   '2014년',
#   '청정원',
#   '정원',
#   '대규모',
#   '리뉴얼',
#   '주도',
#   '주도해',
#   '브랜드',
#   '이미지',
#   '강화',
#   '2016',
#   '2016년',
#   '안주야',
#   '주야',
#   '출시',
#   '국내',
#   '안주',
#   '가정',
#   '가정간편식',
#   '편식',
#   '시장',
#   '개척',
#   '설명',
#   '관계자',
#   '변화',
#   '정확',
#   '정보',
#   '습득',
#   '실행',
#   '차원',
#   '중장기',
#   '방향',
#   '일관',
#   '추진',
#   '적임자',
#   '판단',
#   '업계',
#   '지주사인',
#   '사인',
#   '대상홀딩스에',
#   '언니',
#   '주력',
#   '사업회',
#   '사업회사인',
#   '동생',
#   '본격화',
#   '전체',
#   '투자',
#   '부문',
#   '실질적',
#   '식품',
#   '식자재',
#   '자재',
#   '유통',
#   '사업',
#   '지난해',
#   '상민',
#   '일각',
#   '후계',
#   '후계구도',
#   '구도',
#   '관측',
#   '당초',
#   '지분',
#   '승계',
#   '중심',
#   '가업',
#   '전망',
#   '37',
#   '보유',
#   '최대',
#   '최대주주',
#   '20',
#   '격차',
#   '부인',
#   '박현주',
#   '현주',
#   '정도',
#   '39',
#   '책임',
#   '일환',
#   '지주사',
#   '역할',
#   '등기',
#   '임원',
#   '이름',
#   '백민',
#   '백민정',
#   '기자',
#   '관련기사대상',
#   '기사',
#   '식품사업총괄',
#   '총괄',
#   '상무',
#   '임명',
#   '임명대상그룹',
#   '참여'],
#  ['삼성',
#   '삼성중공업',
#   '중공업',
#   '건조',
#   '1만3000',
#   '3000',
#   '컨테이너',
#   '컨테이너선',
#   '사진',
#   '초대형',
#   '20',
#   '20척',
#   '한번',
#   '수주',
#   '단일',
#   '선박',
#   '선박건조',
#   '계약',
#   '세계',
#   '조선업',
#   '역대',
#   '최대',
#   '규모',
#   '파나마',
#   '지역',
#   '선주가',
#   '주가',
#   '2조8000억',
#   '8000',
#   '26',
#   '26일',
#   '선주',
#   '1만5000',
#   '5000',
#   '공시',
#   '길이',
#   '이번',
#   '중국',
#   '후동중화조선',
#   '중화',
#   '조선',
#   '일본',
#   '이마',
#   '이마바리조선',
#   '바리',
#   '경합',
#   '연료',
#   '절감',
#   '절감기술',
#   '기술',
#   '자사',
#   '차세대',
#   '스마트',
#   '스마트십',
#   '솔루션',
#   '에스',
#   '베슬',
#   '탑재',
#   '경남',
#   '거제',
#   '거제조선소',
#   '조선소',
#   '2025',
#   '2025년',
#   '6월',
#   '순차적',
#   '인도',
#   '예정',
#   '관계자',
#   '올해',
#   '해상',
#   '물동량',
#   '회복',
#   '운임',
#   '인상',
#   '글로벌',
#   '발주',
#   '환경',
#   '호전',
#   '컨테이너선과',
#   '선과',
#   '원유',
#   '원유운반선',
#   '운반선',
#   '중심',
#   '시장',
#   '지배력',
#   '바탕',
#   '목표',
#   '달성',
#   '최선',
#   '42',
#   '42척',
#   '금액',
#   '기준',
#   '51',
#   '51억',
#   '달러',
#   '5조7000억',
#   '7000',
#   '회사',
#   '78',
#   '78억',
#   '가운데',
#   '3분',
#   '1분기',
#   '분기',
#   '시황',
#   '시황분석업체',
#   '분석',
#   '업체',
#   '리서치',
#   '서치',
#   '1만2000',
#   '2000',
#   '이상',
#   '네오',
#   '네오파',
#   '막스',
#   '막스급',
#   '대형',
#   '66',
#   '66척',
#   '절반',
#   '34',
#   '34척',
#   '이날',
#   '전일',
#   '대비',
#   '상승',
#   '7240',
#   '7240원',
#   '거래',
#   '실적',
#   '호조',
#   '기대감',
#   '반영',
#   '결과',
#   '김영민',
#   '기자',
#   '관련',
#   '관련기사',
#   '기사',
#   '월드',
#   '한국',
#   '2년',
#   '1위',
#   '부활',
#   '신호탄',
#   '빅3',
#   '4분기',
#   '15',
#   '15조',
#   '잭팟'],
#  ['금융',
#   '금융그룹',
#   '그룹',
#   '윤종규',
#   '종규',
#   '회장',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '중간',
#   '중간배당',
#   '배당',
#   '가능성',
#   '시사',
#   '현재',
#   '금융당국',
#   '당국',
#   '배당제한',
#   '제한',
#   '권고',
#   '20',
#   '향이',
#   '30',
#   '입장',
#   '때문',
#   '26',
#   '26일',
#   '서울',
#   '여의도',
#   '여의도동',
#   '본점',
#   '주주',
#   '주주총회',
#   '총회',
#   '정도',
#   '생각',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '상황',
#   '배당성향',
#   '성향',
#   '지난해',
#   '3조4552억',
#   '4552',
#   '순이익',
#   '이익',
#   '신한',
#   '신한금융',
#   '3조4146억',
#   '4146',
#   '리딩',
#   '리딩그룹',
#   '사상',
#   '최대',
#   '실적',
#   '전년',
#   '포인트',
#   '6월',
#   '장기화',
#   '대비',
#   '한시적',
#   '이하',
#   '정부',
#   '이후',
#   '주주환원',
#   '환원',
#   '정책',
#   '적극적',
#   '기본',
#   '충실',
#   '영업',
#   '영업방침',
#   '방침',
#   '가면',
#   '극복',
#   '기대',
#   '주주가치',
#   '가치',
#   '제고',
#   '방법',
#   '중간ㆍ분기',
#   '분기',
#   '정관',
#   '허용',
#   '금융주',
#   '배당주',
#   '중간ㆍ분기배당',
#   '공급',
#   '필요성',
#   '검토',
#   '하반기',
#   '의미',
#   '풀이',
#   '한편',
#   '이날',
#   '주총',
#   '스튜',
#   '스튜어트',
#   '어트',
#   '솔로몬',
#   '선우',
#   '석호',
#   '석호ㆍ',
#   '명희ㆍ정구',
#   '희ㆍ',
#   '정구',
#   '환ㆍ김경호',
#   '김경호',
#   '사외',
#   '사외이사',
#   '이사',
#   '선임',
#   '사진',
#   '9명',
#   '연간',
#   '보수',
#   '한도',
#   '30억원',
#   '안건',
#   '통과',
#   '염지',
#   '염지현',
#   '기자'],
#  ['작용기',
#   '작용기전',
#   '설명',
#   '도표',
#   '사진',
#   '큐라',
#   '바이오',
#   '벤처',
#   '벤처기업',
#   '기업',
#   '당뇨병',
#   '신증',
#   '치료제',
#   '효과',
#   '임상',
#   '2상',
#   '확인',
#   '26',
#   '26일',
#   '유효성',
#   '안전성',
#   '발표',
#   '영남',
#   '영남대병원',
#   '병원',
#   '5개',
#   '실시',
#   '이번',
#   '임상시험',
#   '시험',
#   '알부민',
#   '알부민뇨가',
#   '뇨가',
#   '2형',
#   '환자',
#   '42',
#   '42명',
#   '모집',
#   '위약',
#   '위약군',
#   '시험군',
#   '12',
#   '12주간',
#   '주간',
#   '하루',
#   '2회',
#   '투여',
#   '결과',
#   '대비',
#   '사구체',
#   '여과',
#   '증가',
#   '현상',
#   '관찰',
#   '책임자',
#   '원규장',
#   '규장',
#   '내분비',
#   '내분비대사내과',
#   '대사',
#   '내과',
#   '교수',
#   '향후',
#   '약제',
#   '치료',
#   '수단',
#   '하나',
#   '이상',
#   '반응',
#   '홍조',
#   '18.18',
#   '오심',
#   '13.64',
#   '중대',
#   '약물',
#   '연구',
#   '바탕',
#   '후기',
#   '준비',
#   '계획',
#   '문희철',
#   '희철',
#   '기자'],
#  ['정진',
#   '셀트리온그룹',
#   '트리',
#   '그룹',
#   '회장',
#   '인천시',
#   '연수',
#   '연수구',
#   '셀트리',
#   '2공장',
#   '공장',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '항체',
#   '항체치료제',
#   '치료제',
#   '생산',
#   '현장',
#   '점검',
#   '참석',
#   '뉴스',
#   '뉴스1',
#   '개발',
#   '렉키',
#   '해외',
#   '수출',
#   '방안',
#   '논의',
#   '명예',
#   '명예회장',
#   '서정진',
#   '셀트리온',
#   '26',
#   '26일',
#   '인천',
#   '인천광역시',
#   '광역',
#   '30',
#   '30기',
#   '주주',
#   '주주총회',
#   '총회',
#   '7개국',
#   '개국',
#   '이야기',
#   '언급',
#   '가격',
#   '미국',
#   '바이오',
#   '바이오기업인',
#   '기업인',
#   '85',
#   '수준',
#   '승인',
#   '현황',
#   '유럽',
#   '유럽의약품청',
#   '의약품',
#   '사용',
#   '사용승인',
#   '권고',
#   '결정',
#   '한국',
#   '시간',
#   '오늘',
#   '내일',
#   '27',
#   '27일',
#   '새벽',
#   '공지',
#   '산하',
#   '약물',
#   '약물사용자문위원회',
#   '사용자',
#   '위원회',
#   '주의',
#   '품목',
#   '품목허가',
#   '허가',
#   '사용권고',
#   '여부',
#   '심사',
#   '중이',
#   '주가',
#   '다음',
#   '수순',
#   '유럽연합',
#   '연합',
#   '각국',
#   '처방',
#   '자체',
#   '의견',
#   '생각',
#   '절차',
#   '식품',
#   '약국',
#   '2세',
#   '경영',
#   '본격화',
#   '차남',
#   '전면',
#   '임상',
#   '3상',
#   '진행',
#   '상황',
#   '남아프리카공화국',
#   '아프리카',
#   '공화국',
#   '변이',
#   '효과',
#   '동물',
#   '단독',
#   '1상',
#   '2상',
#   '추진',
#   '추가',
#   '설명',
#   '아가',
#   '3분기',
#   '분기',
#   '4분기',
#   '초쯤',
#   '예상',
#   '국내',
#   '2월',
#   '식품의약품안전처',
#   '안전',
#   '임상2상',
#   '결과',
#   '토대',
#   '조건부',
#   '중앙',
#   '중앙방역대책본부',
#   '방역',
#   '대책',
#   '본부',
#   '25',
#   '25일',
#   '기준',
#   '48',
#   '48개',
#   '병원',
#   '681',
#   '681명의',
#   '명의',
#   '환자',
#   '투여',
#   '한편',
#   '이날',
#   '열린',
#   '기점',
#   '셀트리온헬스',
#   '헬스',
#   '케어',
#   '이사회',
#   '사내',
#   '사내이사',
#   '이사',
#   '대신',
#   '장남',
#   '진석',
#   '수석',
#   '수석부사장',
#   '부사장',
#   '제약',
#   '등기',
#   '등기임원',
#   '임원',
#   '선임',
#   '서준석',
#   '준석',
#   '자격',
#   '정식',
#   '합류',
#   '본격적',
#   '돌입',
#   '전망',
#   '문희철',
#   '희철',
#   '기자',
#   '관련',
#   '관련기사제약바이오',
#   '기사',
#   '이름',
#   '기업',
#   '경제',
#   '브리핑',
#   '사상',
#   '최대',
#   '실적'],
#  ['서울',
#   '서초',
#   '서초구',
#   '삼성',
#   '삼성전자',
#   '전자',
#   '서초',
#   '서초사옥',
#   '사옥',
#   '뉴스',
#   '뉴스1',
#   '노사',
#   '올해',
#   '임금',
#   '임금협상',
#   '협상',
#   '직원',
#   '연봉',
#   '평균',
#   '4.5',
#   '기본',
#   '기본급',
#   '기준',
#   '인상',
#   '합의',
#   '대졸',
#   '초임',
#   '지난해',
#   '4450',
#   '4450만원',
#   '4800',
#   '4800만원',
#   '26',
#   '26일',
#   '사내',
#   '게시판',
#   '타결',
#   '타결안',
#   '발표',
#   '인상률',
#   '전년',
#   '대비',
#   '성과',
#   '특별',
#   '인상분',
#   '전체',
#   '7.5',
#   '상승',
#   '보너스',
#   '초과',
#   '초과이익',
#   '이익',
#   '성과급',
#   '목표',
#   '목표달성',
#   '달성',
#   '장려금',
#   '이번',
#   '별도',
#   '직급',
#   '커리어',
#   '레벨',
#   '고과',
#   '차등',
#   '지급',
#   '고졸',
#   '사원',
#   '11',
#   '전용',
#   '사용',
#   '복지',
#   '포인트',
#   '베네',
#   '베네포유',
#   '포유',
#   '기존',
#   '70',
#   '70만',
#   '100',
#   '100만',
#   '통상',
#   '임협',
#   '3월',
#   '중순',
#   '마무리',
#   '조정',
#   '급여',
#   '임금조정',
#   '협의',
#   '사측',
#   '안팎',
#   '6.36',
#   '주장',
#   '양쪽',
#   '절충',
#   '인상안',
#   '내부',
#   '불만',
#   '목소리',
#   '최근',
#   '게임',
#   '업체',
#   '정보',
#   '정보기술',
#   '기술',
#   '업계',
#   '전반',
#   '일례',
#   '네이버',
#   '근속',
#   '근속연수',
#   '연수',
#   '5.78',
#   '5.78년',
#   '1억248만',
#   '248',
#   '12.4',
#   '12.4년',
#   '1억2700만',
#   '2700',
#   '그래픽',
#   '기자',
#   '직장인',
#   '익명',
#   '커뮤니티',
#   '블라인드',
#   '대표',
#   '월급',
#   '2.4',
#   '2.4배',
#   '낮으',
#   '사기',
#   '관련',
#   '관련기사',
#   '기사',
#   '단독',
#   '난항',
#   '월급날',
#   '하루',
#   '소급',
#   '소급분',
#   '공지',
#   '박형수',
#   '형수',
#   '97'],
#  ['26',
#   '26일',
#   '서울',
#   '송파',
#   '송파구',
#   '롯데',
#   '롯데월드타워',
#   '월드',
#   '타워',
#   '롯데지주',
#   '지주',
#   '주주',
#   '주주총회',
#   '총회',
#   '현장',
#   '사진',
#   '이동',
#   '이동우',
#   '대표',
#   '2021',
#   '2021년',
#   '그룹',
#   '역량',
#   '결집',
#   '도약',
#   '터닝',
#   '터닝포인트',
#   '포인트',
#   '정기',
#   '올해',
#   '사업',
#   '성과',
#   '지난해',
#   '전반적',
#   '개선',
#   '기대',
#   '전략적',
#   '의의',
#   '시너지',
#   '창출',
#   '여부',
#   '점검',
#   '지속',
#   '지속성장',
#   '성장',
#   '가능',
#   '비즈니스',
#   '포트폴리오',
#   '계열사',
#   '턴어라운드',
#   '라운드',
#   '전환',
#   '전략',
#   '추가',
#   '기회',
#   '모색',
#   '설명',
#   '부진',
#   '공석',
#   '롯데온',
#   '영호',
#   '이베이코리아',
#   '베이',
#   '코리아',
#   '전략기획본부장',
#   '기획',
#   '본부장',
#   '내정',
#   '내부적',
#   '시나리오',
#   '준비',
#   '지금',
#   '운영',
#   '차세대',
#   '주력',
#   '주력사업',
#   '발굴',
#   '부문',
#   '차원',
#   '신속',
#   '적극적',
#   '실행',
#   '지원',
#   '바이오',
#   '진출',
#   '스마트',
#   '모빌리티',
#   '빌리티',
#   '전기',
#   '전기차',
#   '배터리',
#   '신규',
#   '모델',
#   '연구',
#   '롯데정밀화학',
#   '정밀',
#   '화학',
#   '기차',
#   '소재',
#   '산솔루스',
#   '루스',
#   '투자',
#   '롯데케미칼',
#   '케미칼',
#   '친환경',
#   '환경',
#   '시설',
#   '증설',
#   '롯데칠성음료',
#   '칠성',
#   '음료',
#   '스마트팩토리',
#   '팩토리',
#   '롯데글로벌',
#   '글로벌',
#   '지스',
#   '메가',
#   '메가허브',
#   '허브',
#   '터미널',
#   '구축',
#   '생산',
#   '물류',
#   '한창',
#   '이날',
#   '주총',
#   '추광',
#   '재무',
#   '재무혁신실장',
#   '혁신',
#   '실장',
#   '사내',
#   '사내이사',
#   '이사',
#   '김창수',
#   '중앙대',
#   '경영학',
#   '경영학부',
#   '교수',
#   '사외',
#   '사외이사',
#   '감사',
#   '감사위원',
#   '위원',
#   '선임',
#   '이병',
#   '기자',
#   '관련',
#   '관련기사강희태',
#   '기사',
#   '희태',
#   '롯데쇼핑',
#   '쇼핑',
#   '인수',
#   '관심',
#   '단독',
#   '중고',
#   '중고나라',
#   '나라',
#   '참여',
#   '중고거래',
#   '거래',
#   '시장'],
#  ['금호',
#   '금호석유화학',
#   '석유',
#   '화학',
#   '26',
#   '26일',
#   '서울',
#   '중구',
#   '타워',
#   '정기',
#   '주주',
#   '주주총회',
#   '총회',
#   '개최',
#   '사진',
#   '삼촌',
#   '조카',
#   '대결',
#   '관심',
#   '박찬',
#   '박찬구',
#   '회장',
#   '승리',
#   '일단락',
#   '박철완',
#   '철완',
#   '상무',
#   '사내',
#   '사내이사',
#   '이사',
#   '선임',
#   '무산',
#   '이사회',
#   '진출',
#   '실패',
#   '경영권',
#   '분쟁',
#   '금호석',
#   '호석',
#   '주총',
#   '재무제표',
#   '이익',
#   '이익배당',
#   '배당',
#   '승인',
#   '정관',
#   '일부',
#   '변경',
#   '22',
#   '22개',
#   '안건',
#   '처리',
#   '이날',
#   '대리인',
#   '위임',
#   '포함',
#   '의결권',
#   '주식',
#   '총수',
#   '2487',
#   '2487만주',
#   '만주',
#   '80',
#   '2056',
#   '2056명',
#   '1995',
#   '1995만주',
#   '참여',
#   '이사선임',
#   '배당안',
#   '삼촌',
#   '지분',
#   '구조',
#   '그래픽',
#   '김경진',
#   '경진',
#   '기자',
#   '찬성',
#   '53',
#   '보통',
#   '결의',
#   '요건',
#   '충족',
#   '사측',
#   '득표',
#   '부결',
#   '측이',
#   '추천',
#   '백종',
#   '백종훈',
#   '금호석유',
#   '영업',
#   '영업본부장',
#   '본부장',
#   '64',
#   '찬성률',
#   '성률',
#   '관심사',
#   '제안',
#   '통과',
#   '보통주',
#   '경우',
#   '주당',
#   '4200',
#   '4200원',
#   '우선주',
#   '4250',
#   '4250원',
#   '예정',
#   '1만1000원',
#   '1000',
#   '1만1050원',
#   '1050',
#   '36',
#   '최대',
#   '제한',
#   '감사',
#   '감사위원',
#   '위원',
#   '감사위원회',
#   '위원회',
#   '사외',
#   '사외이사',
#   '1명',
#   '교수',
#   '69',
#   '가결',
#   '보스턴',
#   '보스턴컨설팅그룹',
#   '컨설팅',
#   '그룹',
#   '한국',
#   '한국지사',
#   '지사',
#   '대표',
#   '31',
#   '박순애',
#   '순애',
#   '서울대',
#   '행정',
#   '행정대학원',
#   '대학원',
#   '이정',
#   '이정미',
#   '헌법',
#   '헌법재판소장',
#   '재판',
#   '소장',
#   '권한',
#   '권한대행',
#   '대행',
#   '최도성',
#   '도성',
#   '천대',
#   '석좌교수',
#   '대표이사',
#   '의장',
#   '분리',
#   '개정',
#   '특별',
#   '사항',
#   '3분',
#   '이상',
#   '모두',
#   '내부',
#   '내부거래위원회',
#   '거래',
#   '설치',
#   '오전',
#   '9시',
#   '시작',
#   '양측',
#   '유효',
#   '검표',
#   '작업',
#   '지체',
#   '2시간',
#   '시간',
#   '40',
#   '40여분이',
#   '여분이',
#   '개회',
#   '10',
#   '10여분',
#   '정족수',
#   '재확인',
#   '정회',
#   '진행',
#   '차질',
#   '이대',
#   '종결',
#   '당초',
#   '이번',
#   '전망',
#   '우세',
#   '가운데',
#   '여부',
#   '2대',
#   '국민',
#   '국민연금',
#   '연금',
#   '세계',
#   '자문',
#   '자문사',
#   '전체',
#   '의사',
#   '공표',
#   '때문',
#   '주주제',
#   '주주제안',
#   '나머지',
#   '입성',
#   '우호',
#   '우호세력',
#   '세력',
#   '확대',
#   '향후',
#   '행보',
#   '불투명',
#   '불투명해진',
#   '해진',
#   '상태',
#   '입장',
#   '입장문',
#   '하다',
#   '다음',
#   '결과',
#   '도전',
#   '여지',
#   '회사',
#   '일정',
#   '부분',
#   '기여',
#   '주주권',
#   '행사',
#   '동료',
#   '이해',
#   '이해관계자',
#   '관계자',
#   '소통',
#   '고민',
#   '승기',
#   '성원',
#   '겸손',
#   '마음',
#   '기업',
#   '기업가치',
#   '가치',
#   '제고',
#   '강화',
#   '주주가치',
#   '향상',
#   '매진',
#   '관련',
#   '관련기사국민연금',
#   '기사',
#   '선택',
#   '지지',
#   '한진',
#   '조원',
#   '조원태',
#   '반대',
#   '반대삼촌',
#   '전쟁',
#   '홍삼',
#   '진실',
#   '진실게임',
#   '게임'],
#  ['강인',
#   '영풍',
#   '사장',
#   '오른쪽',
#   '이강',
#   '이강명',
#   '성일',
#   '성일하이텍',
#   '하이텍',
#   '대표',
#   '가운데',
#   '김복철',
#   '복철',
#   '지질',
#   '지질자원연구원장',
#   '자원',
#   '연구원장',
#   '왼쪽',
#   '협약',
#   '협약후',
#   '사진',
#   '촬영',
#   '제공',
#   '국책',
#   '국책연구기관',
#   '연구',
#   '기관',
#   '기반',
#   '기반기술',
#   '기술',
#   '중소기업',
#   '사업',
#   '노하우',
#   '대기업',
#   '신기술',
#   '결합',
#   '글로벌',
#   '2차',
#   '전지',
#   '재활용',
#   '시장',
#   '도전장',
#   '한국',
#   '한국지질자원연구원',
#   '연구원',
#   '26',
#   '26일',
#   '대전',
#   '지자',
#   '지자연',
#   '양해',
#   '양해각서',
#   '각서',
#   '체결',
#   '전기',
#   '전기차',
#   '사용',
#   '배터리',
#   '연구개발',
#   '개발',
#   '사업기반조성',
#   '조성',
#   '상호',
#   '협력',
#   '지자연과',
#   '연과',
#   '이번',
#   '2차전지',
#   '국가',
#   '발굴',
#   '전기차용',
#   '차용',
#   '건식',
#   '습식',
#   '회수',
#   '인적',
#   '인적자원',
#   '교류',
#   '학술',
#   '정보',
#   '공유',
#   '연구시설',
#   '시설',
#   '활용',
#   '지원',
#   '향후',
#   '공동',
#   '대응',
#   '20',
#   '20여년간',
#   '역량',
#   '축적',
#   '2000',
#   '2000년',
#   '설립',
#   '리튬',
#   '리튬이온전지',
#   '이온',
#   '특화',
#   '발전',
#   '세계',
#   '최고',
#   '수준',
#   '습식처리공정',
#   '처리',
#   '공정',
#   '보유',
#   '포제련소',
#   '제련소',
#   '운영',
#   '독자적',
#   '건식용융',
#   '용융',
#   '제련',
#   '제련기술',
#   '바탕',
#   '건식용융공정기술',
#   '2022',
#   '2022년',
#   '상용화',
#   '용화',
#   '2천톤급',
#   '실험',
#   '실험설비',
#   '설비',
#   '아연',
#   '잔재',
#   '설치',
#   '계획',
#   '3자',
#   '대형',
#   '폐배터리',
#   '간소화',
#   '도입',
#   '변화',
#   '지금',
#   '해체',
#   '분쇄',
#   '분말',
#   '블랙',
#   '블랙파우더',
#   '파우더',
#   '전처리',
#   '황산',
#   '황산용액',
#   '용액',
#   '유가',
#   '유가금속',
#   '금속',
#   '추출',
#   '스마트',
#   '스마트폰',
#   '중소형',
#   '위주',
#   '형성',
#   '건식용융기술',
#   '과정',
#   '배터리팩',
#   '모듈',
#   '모듈단위',
#   '단위',
#   '단순',
#   '1,500',
#   '1,500도',
#   '용융로',
#   '융로',
#   '투입',
#   '금속분말',
#   '니켈',
#   '코발트',
#   '구리',
#   '400',
#   '내외',
#   '기차',
#   '적합',
#   '처리기술',
#   '이강인',
#   '전세계',
#   '산업',
#   '지각',
#   '지각변동',
#   '변동',
#   '유발',
#   '대표적',
#   '성장',
#   '도약',
#   '도시',
#   '도시광산',
#   '광산',
#   '경험',
#   '깊이',
#   '절호',
#   '기회',
#   '친환경',
#   '환경',
#   '재활용사업',
#   '진출',
#   '중요',
#   '기존',
#   '환경논란',
#   '논란',
#   '극복',
#   '미래',
#   '혁신',
#   '적극적',
#   '개척',
#   '계기',
#   '원장',
#   '적극',
#   '고도화',
#   '4차산업혁명',
#   '혁명',
#   '시대',
#   '국가전략',
#   '전략',
#   '광물',
#   '확보',
#   '기여',
#   '최근',
#   '지구',
#   '기후',
#   '기후변화',
#   '대비',
#   '운송',
#   '운송수단',
#   '수단',
#   '인식',
#   '보급',
#   '급속',
#   '확대',
#   '경우',
#   '2020',
#   '2020년',
#   '82',
#   '2030',
#   '2030년',
#   '785',
#   '785만대',
#   '만대',
#   '10',
#   '10배',
#   '예상',
#   '400만대',
#   '2025',
#   '2025년',
#   '2,800',
#   '2,800만대',
#   '팽창',
#   '자동차',
#   '생산',
#   '50',
#   '이상',
#   '점유',
#   '전망',
#   '10년',
#   '후속',
#   '급팽창',
#   '시장규모',
#   '규모',
#   '20억',
#   '달러',
#   '300',
#   '300억',
#   '활성화',
#   '중국',
#   '유럽',
#   '북미',
#   '중대형',
#   '경쟁',
#   '격화',
#   '온라인',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['사진',
#   '사진제공',
#   '제공',
#   '세양',
#   '코퍼',
#   '코퍼레이션',
#   '레이션',
#   '주식',
#   '주식회사',
#   '회사',
#   '세양코퍼레이션',
#   '대표',
#   '정재',
#   '정재훈',
#   '홍익',
#   '홍익대학교',
#   '대학교',
#   '경영',
#   '경영대학',
#   '대학',
#   '김승',
#   '교수',
#   '연구',
#   '연구팀',
#   '중소',
#   '중소상공인',
#   '상공인',
#   '상권',
#   '활성화',
#   '블록',
#   '블록체인기반',
#   '체인',
#   '기반',
#   '스마트',
#   '트랙',
#   '협약',
#   '체결',
#   '해당',
#   '주변',
#   '분석',
#   '가치',
#   '데이터',
#   '성과',
#   '부산',
#   '도입',
#   '직접',
#   '거래',
#   '디지털',
#   '디지털화',
#   '안전',
#   '효율적',
#   '향후',
#   '안전성',
#   '신개념',
#   '개념',
#   '금융',
#   '플랫폼',
#   '혁신',
#   '코로나',
#   '시국',
#   '투명',
#   '상품',
#   '구상',
#   '온라인',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['무원',
#   '무원식품',
#   '식품',
#   '찬속',
#   '만두',
#   '3종',
#   '왼쪽',
#   '고기',
#   '고기만두',
#   '김치',
#   '김치만두',
#   '땡초',
#   '땡초만두',
#   '사진',
#   '국내',
#   '냉동',
#   '냉동만두',
#   '시장',
#   '규모',
#   '지난해',
#   '5400',
#   '5400억원',
#   '돌파',
#   '가운데',
#   '업계',
#   '2위',
#   '풀무',
#   '성장세',
#   '1위',
#   '제일',
#   '제일제당',
#   '제당',
#   '자리',
#   '풀무원식품',
#   '26',
#   '26일',
#   '매출',
#   '1370',
#   '1370억원',
#   '얄피만두',
#   '출시',
#   '2018',
#   '2018년',
#   '이상',
#   '115',
#   '이름',
#   '0.7',
#   '만두피',
#   '제품',
#   '투명',
#   '특징',
#   '군만두',
#   '일색',
#   '호응',
#   '1년',
#   '누적',
#   '판매량',
#   '2000',
#   '봉지',
#   '얄피',
#   '교자만두',
#   '자만두',
#   '2종',
#   '5455',
#   '5455억원',
#   '점유율',
#   '비고',
#   '46',
#   '20',
#   '내외',
#   '국내외',
#   '이미지',
#   '2013',
#   '2013년',
#   '왕교자',
#   '교자',
#   '강자',
#   '군림',
#   '1조원',
#   '3600',
#   '3600억원',
#   '2016',
#   '2016년',
#   '미국',
#   '인기',
#   '수제',
#   '둣집',
#   '1월',
#   '사골',
#   '컵만둣국',
#   '만둣국',
#   '전자',
#   '전자레인지',
#   '레인지',
#   '트레이',
#   '트레이형',
#   '편의성',
#   '계속',
#   '선보',
#   '예정',
#   '2030',
#   '세대',
#   '석권',
#   '계획',
#   '온라인',
#   '비중',
#   '22',
#   '캐릭터',
#   '웹드라마',
#   '드라마',
#   '시도',
#   '홍세희',
#   '세희',
#   '만두제품',
#   '매니저',
#   '5000',
#   '5000억',
#   '라면',
#   '대표적',
#   '가정',
#   '가정간편식이',
#   '간편',
#   '식이',
#   '소통',
#   '충성',
#   '고객',
#   '확대',
#   '이병',
#   '기자',
#   '관련',
#   '관련기사',
#   '기사',
#   '원조',
#   '실크로드',
#   '입구',
#   '우루',
#   '수출',
#   '파오',
#   '파오차이',
#   '차이',
#   '표기',
#   '사정',
#   '덤플링',
#   '대신',
#   '세계',
#   '입맛',
#   '비결'],
#  ['박혜은',
#   '95',
#   '얼마',
#   '앙리',
#   '마티스',
#   '특별전',
#   '전시',
#   '코로나',
#   '상황',
#   '하다',
#   '기한',
#   '평일',
#   '오후',
#   '전시장',
#   '시간대',
#   '도슨트',
#   '설명',
#   '그림',
#   '관람',
#   '아내',
#   '얼굴',
#   '동감',
#   '웃음',
#   '100',
#   '100년',
#   '화가',
#   '모델',
#   '일반인',
#   '캔버스',
#   '포즈',
#   '인체',
#   '변형',
#   '색채',
#   '구사',
#   '여성',
#   '이유',
#   '대부분',
#   '야수파',
#   '하면',
#   '대표',
#   '대표주자',
#   '주자',
#   '파레르',
#   '조형',
#   '세계',
#   '존재',
#   '작품',
#   '그녀',
#   '모자',
#   '여인',
#   '사진',
#   '주인공',
#   '부부',
#   '부부싸움',
#   '싸움',
#   '감정',
#   '표현',
#   '1905',
#   '1905년',
#   '가을',
#   '살롱',
#   '살롱전',
#   '출품',
#   '화제',
#   '오른손',
#   '부채',
#   '의자',
#   '모습',
#   '파격적',
#   '피부색',
#   '파랑',
#   '초록',
#   '생소',
#   '부자연',
#   '색상',
#   '이야기',
#   '규칙',
#   '자유',
#   '사용',
#   '주관적',
#   '해석',
#   '당시',
#   '사람',
#   '자유분방',
#   '야생',
#   '동물',
#   '연상',
#   '시작',
#   '정돈',
#   '마음',
#   '느낌',
#   '모양',
#   '이해',
#   '감사',
#   '생각',
#   '한마디',
#   '실제',
#   '기분',
#   '샤방샤뱡',
#   '상대',
#   '마찬가지',
#   '시선',
#   '상대방',
#   '나름',
#   '요즘',
#   '남편',
#   '순간',
#   '샤방샤',
#   '샤방샤방',
#   '언제',
#   '나의',
#   '식물',
#   '아침',
#   '일어',
#   '출근',
#   '준비',
#   '화초',
#   '며칠',
#   '화분',
#   '오늘',
#   '시간',
#   '왜냐',
#   '꽃향기',
#   '기억',
#   '순간의',
#   '간의',
#   '지속',
#   '방향',
#   '단체',
#   '누군가',
#   '가정',
#   '정원',
#   '정글',
#   '굿커뮤니케이션',
#   '커뮤니케이션',
#   '관련',
#   '관련기사',
#   '기사',
#   '가족',
#   '불편',
#   '감정의',
#   '정의',
#   '쓰레기',
#   '쓰레기통',
#   '우리',
#   '직선',
#   '대화'],
#  ['법무',
#   '법무법인',
#   '법인',
#   '태평양',
#   '이하',
#   '대표',
#   '대표변호사',
#   '변호사',
#   '동우',
#   '하영',
#   '글로벌',
#   '금융',
#   '금융전문지',
#   '전문지',
#   '유로',
#   '유로머니',
#   '머니',
#   '산하',
#   '주최',
#   '2021',
#   '태지역',
#   '지역',
#   '워즈',
#   '올해',
#   '라이징',
#   '스타',
#   '한국',
#   '최초',
#   '수상',
#   '6명의',
#   '명의',
#   '후보',
#   '국내',
#   '유일',
#   '이름',
#   '금융법',
#   '시상식',
#   '국가',
#   '기업',
#   '기업구조조정',
#   '구조',
#   '조정',
#   '분야',
#   '창의',
#   '진취적',
#   '역량',
#   '발휘',
#   '우수',
#   '로펌',
#   '심사',
#   '발표',
#   '코로나',
#   '코로나19',
#   '19',
#   '사태',
#   '온라인',
#   '진행',
#   '자본',
#   '자본시장',
#   '시장',
#   '증권',
#   '증권금융',
#   '경험',
#   '전문',
#   '기반',
#   '성장',
#   '평가',
#   '실제',
#   '카카오',
#   '한화',
#   '한화케미칼',
#   '케미칼',
#   '발행',
#   '포르',
#   '증권거래소',
#   '거래소',
#   '상장',
#   '자문',
#   '삼성',
#   '삼성바이오',
#   '바이오',
#   '직스',
#   '산밥캣',
#   '카카오게임즈',
#   '게임',
#   '국내외',
#   '한국',
#   '한국거래소',
#   '대한',
#   '대한민국',
#   '민국',
#   '정부',
#   '외평채',
#   '성공적',
#   '수행',
#   '차세대',
#   '주자',
#   '활약',
#   '한국과학기술원',
#   '과학',
#   '기술원',
#   '고려대',
#   '고려대학교',
#   '학교',
#   '법학',
#   '법학전문대학원',
#   '전문대',
#   '학원',
#   '최우등',
#   '졸업',
#   '2019',
#   '2019년',
#   '하버드',
#   '로스쿨',
#   '스쿨',
#   '취득',
#   '1회',
#   '시험',
#   '합격',
#   '2012',
#   '2012년',
#   '증권금융분야',
#   '활동',
#   '혼자',
#   '모든',
#   '구성원',
#   '노력',
#   '반영',
#   '결과',
#   '저희',
#   '업무',
#   '주신',
#   '고객',
#   '니즈',
#   '부응',
#   '소통',
#   '보답',
#   '소감',
#   '강자',
#   '강자라',
#   '증권금융팀',
#   '대규모',
#   '기업공개',
#   '공개',
#   '외국',
#   '해외',
#   '해외상장',
#   '주식',
#   '주식예탁증서',
#   '예탁',
#   '증서',
#   '주목',
#   '다수',
#   '거래',
#   '신희',
#   '신희강',
#   '주축',
#   '구성',
#   '전문가',
#   '기간',
#   '법률',
#   '바탕',
#   '법규',
#   '감독',
#   '당국',
#   '실무',
#   '입각',
#   '최적',
#   '솔루션',
#   '제공',
#   '중앙',
#   '중앙일보',
#   '일보'],
#  ['26',
#   '26일',
#   '오전',
#   '주주',
#   '주주총회',
#   '총회',
#   '서울',
#   '여의도',
#   '트윈',
#   '트윈타워',
#   '타워',
#   '모습',
#   '이번',
#   '주총',
#   '사내',
#   '사내이사',
#   '이사',
#   '구광',
#   '그룹',
#   '회장',
#   '사외',
#   '사외이사',
#   '김상헌',
#   '국립',
#   '국립극단',
#   '극단',
#   '이사장',
#   '선임',
#   '계열',
#   '계열분리',
#   '분리',
#   '안건',
#   '의결',
#   '뉴스',
#   '뉴스1',
#   '고문',
#   '신설',
#   '지주',
#   '지주회사',
#   '회사',
#   '5월',
#   '공식',
#   '출범',
#   '정기',
#   '홀딩',
#   '설립',
#   '분할',
#   '계획',
#   '통과',
#   '이날',
#   '참석',
#   '89.2',
#   '찬성',
#   '76.6',
#   '최종',
#   '승인',
#   '광모',
#   '대표',
#   '존속',
#   '2개',
#   '재편',
#   '지주사',
#   '상사',
#   '하우',
#   '하우시스',
#   '시스',
#   '실리콘',
#   '실리콘웍스',
#   '웍스',
#   '4개',
#   '자회사',
#   '산하',
#   '판토스',
#   '토스',
#   '손자',
#   '손자회사',
#   '구조',
#   '대표이사',
#   '최고',
#   '최고경영자',
#   '경영자',
#   '역임',
#   '송치',
#   '송치호',
#   '자산',
#   '규모',
#   '7조원',
#   '안팎',
#   '기일',
#   '1일',
#   '독립',
#   '독립경영',
#   '경영',
#   '책임',
#   '책임경영',
#   '체제',
#   '구축',
#   '방침',
#   '사업',
#   '사업관리',
#   '관리',
#   '영역',
#   '전문화',
#   '기업',
#   '기업가치',
#   '가치',
#   '집중',
#   '신설지주',
#   '포함',
#   '5개',
#   '계열사',
#   '그래픽',
#   '김주원',
#   '주원',
#   '기자',
#   '구광모의',
#   '모의',
#   '전자',
#   '화학',
#   '통신',
#   '통신서비스',
#   '서비스',
#   '역량',
#   '자원',
#   '배터리',
#   '대형',
#   '자동차',
#   '전장',
#   '성장',
#   '성장동력',
#   '동력',
#   '강화',
#   '본준의',
#   '준의',
#   '잠재력',
#   '주력',
#   '육성',
#   '극대화',
#   '이번',
#   '2020',
#   '2020년도',
#   '년도',
#   '재무제표',
#   '정관',
#   '변경',
#   '의안',
#   '수영',
#   '에코',
#   '매니지먼트',
#   '코리아',
#   '코리아홀딩스',
#   '딩스',
#   '집행',
#   '임원',
#   '신규',
#   '영업',
#   '영업보고서',
#   '보고서',
#   '인사말',
#   '지난해',
#   '선택',
#   '전략',
#   '핵심',
#   '정비',
#   '경쟁력',
#   '방향',
#   '포트폴리오',
#   '연결',
#   '연결기준',
#   '기준',
#   '매출',
#   '6조6321억',
#   '6321',
#   '영업이익',
#   '이익',
#   '1조7022억',
#   '7022',
#   '성과',
#   '달성',
#   '올해',
#   '변화',
#   '대응',
#   '리스크',
#   '고객',
#   '중심',
#   '도전',
#   '관련',
#   '관련기사분리경영',
#   '기사',
#   '전통',
#   '사명',
#   '유력',
#   '확정',
#   '박형수',
#   '형수',
#   '97'],
#  ['포드',
#   '지난해',
#   '6월',
#   '공개',
#   '신형',
#   '픽업',
#   '픽업트럭',
#   '트럭',
#   '사진',
#   '차량',
#   '반도체',
#   '부족',
#   '사태',
#   '미국',
#   '대표',
#   '자동차',
#   '메이커',
#   '제너럴',
#   '제너럴모터스',
#   '모터스',
#   '생산',
#   '중단',
#   '결정',
#   '일반',
#   '승용차',
#   '뒷부분',
#   '부분',
#   '적재함',
#   '형태',
#   '때문',
#   '인기',
#   '고수익',
#   '차종',
#   '차질',
#   '발생',
#   '상반기',
#   '수익성',
#   '영향',
#   '전망',
#   '최다',
#   '판매',
#   '결국',
#   '생산중단',
#   '26',
#   '26일',
#   '전문',
#   '전문매체',
#   '매체',
#   '오토',
#   '오토모티브뉴스',
#   '모티브',
#   '뉴스',
#   '로이',
#   '로이터',
#   '통신',
#   '25',
#   '25일',
#   '미시간',
#   '디어본',
#   '공장',
#   '일시',
#   '28',
#   '28일',
#   '라인',
#   '가동',
#   '이후',
#   '상황',
#   '조업',
#   '재개',
#   '방침',
#   '시리즈',
#   '북미',
#   '지역',
#   '대표적',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '19',
#   '78',
#   '78만7422대',
#   '7422',
#   '단일',
#   '판매량',
#   '지난달',
#   '기존',
#   '3교대',
#   '교대',
#   '생산라인',
#   '8시간',
#   '시간',
#   '2개',
#   '조로',
#   '방식',
#   '대응',
#   '탑재',
#   '상태',
#   '조립',
#   '다음',
#   '계속',
#   '일손',
#   '출시',
#   '유리',
#   '와이퍼',
#   '모터',
#   '인포',
#   '인포테',
#   '먼트',
#   '시스템',
#   '고가',
#   '사양인',
#   '메모리',
#   '대신',
#   '미주리',
#   '29',
#   '29일',
#   '12',
#   '12일',
#   '산하',
#   '브랜드',
#   '캐니언',
#   '쉐보',
#   '쉐보레',
#   '라도',
#   '캔자스',
#   '중순',
#   '한국',
#   '경우',
#   '4월',
#   '평2공장',
#   '절반',
#   '수준',
#   '현대',
#   '현대차도',
#   '차도',
#   '상당수',
#   '주말',
#   '특근',
#   '시작',
#   '최근',
#   '일본',
#   '업체',
#   '사스',
#   '화재',
#   '현대자차',
#   '자차',
#   '아반',
#   '아반떼',
#   '쏘나타',
#   '일부',
#   '물량',
#   '조절',
#   '문제',
#   '최대한',
#   '설계',
#   '한시적',
#   '변경',
#   '실버',
#   '실버라도',
#   '연료',
#   '관리',
#   '관리모듈',
#   '모듈',
#   '김영민',
#   '기자',
#   '관련',
#   '관련기사',
#   '기사',
#   '단독',
#   '정부',
#   '가뭄',
#   '아이오',
#   '아이오닉5'],
#  ['홍남기',
#   '남기',
#   '부총리',
#   '기획',
#   '정부',
#   '장관',
#   '오른쪽',
#   '26',
#   '26일',
#   '정부서울청사',
#   '서울',
#   '청사',
#   '18',
#   '18차',
#   '부동산',
#   '부동산시장',
#   '시장',
#   '점검',
#   '관계',
#   '관계장관회의',
#   '회의',
#   '모두',
#   '모두발언',
#   '발언',
#   '한국',
#   '한국토지주택공사',
#   '토지',
#   '주택',
#   '공사',
#   '사태',
#   '관련',
#   '다음',
#   '강도',
#   '투기',
#   '투기근절',
#   '근절',
#   '재발',
#   '방지',
#   '대책',
#   '경제',
#   '경제부총리',
#   '장관회의',
#   '방지대책',
#   '마지막',
#   '협의',
#   '당정',
#   '초반',
#   '3월',
#   '발표',
#   '예정',
#   '공무원',
#   '공공',
#   '공공기관',
#   '기관',
#   '관계자',
#   '취득',
#   '기준',
#   '이전',
#   '강화',
#   '내용',
#   '포함',
#   '전망',
#   '예고',
#   '임직원',
#   '등록제',
#   '신고제',
#   '가능성',
#   '처벌',
#   '수단',
#   '비판',
#   '고려',
#   '환수',
#   '징계',
#   '기존',
#   '처벌방안',
#   '방안',
#   '솔선',
#   '공직자',
#   '엄한',
#   '책임',
#   '부과',
#   '이번',
#   '전형적',
#   '불법',
#   '편법',
#   '불공정',
#   '뿌리',
#   '각오',
#   '근본',
#   '마련',
#   '공급',
#   '공급대책',
#   '후속',
#   '조치',
#   '속도',
#   '2차',
#   '공공재',
#   '공공재개발',
#   '개발',
#   '후보지',
#   '선정',
#   '선정결과',
#   '결과',
#   '4대책',
#   '지방',
#   '지방자치단체',
#   '자치',
#   '단체',
#   '제안',
#   '부지',
#   '대상',
#   '1차',
#   '도심',
#   '사업',
#   '계획',
#   '공급일정',
#   '일정',
#   '차질',
#   '추진',
#   '메시지',
#   '취지',
#   '이날',
#   '최근',
#   '아파트',
#   '매도',
#   '매물',
#   '증가',
#   '상황',
#   '강남',
#   '일부',
#   '인기',
#   '지역',
#   '전셋값',
#   '하락',
#   '언론',
#   '언론보도',
#   '보도',
#   '언급',
#   '부정적',
#   '영향',
#   '예상',
#   '불확실',
#   '확대',
#   '다행',
#   '생각',
#   '지금',
#   '정책',
#   '불안정',
#   '우리',
#   '피해',
#   '미래',
#   '입직',
#   '세대',
#   '동향',
#   '좌고',
#   '좌고우',
#   '일관성',
#   '세종',
#   '김남',
#   '기자'],
#  ['우리',
#   '테슬라',
#   '가자',
#   '최근',
#   '수에즈',
#   '운하',
#   '사고',
#   '국내',
#   '해운',
#   '해운사',
#   '현대상선',
#   '대상',
#   '몸값',
#   '주가',
#   '장중',
#   '3만원',
#   '연중',
#   '최고가',
#   '주주',
#   '환호성',
#   '26',
#   '26일',
#   '오전',
#   '10',
#   '10시',
#   '30',
#   '30분',
#   '기준',
#   '코스',
#   '코스피',
#   '시장',
#   '전날',
#   '5150',
#   '5150원',
#   '17.49',
#   '3만4600원',
#   '4600',
#   '거래',
#   '9거래일',
#   '거래일',
#   '연속',
#   '상승세',
#   '기간',
#   '상승률',
#   '61.3',
#   '148',
#   '급등',
#   '초대형',
#   '컨테이너',
#   '컨테이너선',
#   '이치',
#   '이치엠엠',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '세계',
#   '경기',
#   '회복',
#   '기대감',
#   '물씬',
#   '이날',
#   '거래량',
#   '폭발',
#   '시각',
#   '현재',
#   '2400',
#   '거래대금',
#   '대금',
#   '8000',
#   '8000억원',
#   '코스닥',
#   '전체',
#   '1위',
#   '시가',
#   '시가총액',
#   '총액',
#   '11',
#   '11조265억',
#   '265',
#   '순위',
#   '30위',
#   '우선주',
#   '제외',
#   '강세',
#   '분석',
#   '벌크',
#   '건화물',
#   '화물',
#   '종합',
#   '시황',
#   '발틱',
#   '발틱운임지수',
#   '운임',
#   '지수',
#   '19',
#   '19일',
#   '2281',
#   '지난해',
#   '대비',
#   '70',
#   '상승',
#   '5월',
#   '신종',
#   '코로나',
#   '코로나바이러스',
#   '이러스',
#   '감염증',
#   '코로나19',
#   '여파',
#   '393',
#   '하락',
#   '비교',
#   '10개월',
#   '개월',
#   '6배',
#   '수준',
#   '철광석',
#   '석탄',
#   '원자재',
#   '물동량',
#   '양지환',
#   '지환',
#   '대신',
#   '대신증권',
#   '증권',
#   '연구원',
#   '업황',
#   '턴어라운드',
#   '라운드',
#   '반등',
#   '올해',
#   '건화물',
#   '사이클',
#   '진입',
#   '흐름',
#   '내년',
#   '지속',
#   '전망',
#   '해운사의',
#   '사의',
#   '실적',
#   '직결',
#   '금융',
#   '금융정보업체',
#   '정보',
#   '업체',
#   '에프',
#   '에프앤가이드',
#   '가이드',
#   '예상',
#   '영업',
#   '영업이익',
#   '이익',
#   '2조4783억',
#   '4783',
#   '추정',
#   '사상',
#   '최대',
#   '9808',
#   '9808억원',
#   '152.7',
#   '급증',
#   '수치',
#   '23',
#   '23일',
#   '현지',
#   '현지시간',
#   '시간',
#   '이집트',
#   '화물선',
#   '정체',
#   '아시아',
#   '유럽',
#   '해상',
#   '교역',
#   '핵심',
#   '통로',
#   '신영',
#   '신영증권',
#   '사태',
#   '초대형선',
#   '이용',
#   '남아프리카',
#   '아프리카',
#   '희망봉',
#   '경유',
#   '노선',
#   '활용',
#   '유럽노선',
#   '황의',
#   '황의영',
#   '기자'],
#  ['조원',
#   '조원태',
#   '한진',
#   '한진그룹',
#   '그룹',
#   '회장',
#   '26',
#   '26일',
#   '대한',
#   '대한항공',
#   '항공',
#   '주주',
#   '주주총회',
#   '총회',
#   '사내',
#   '사내이사',
#   '이사',
#   '선임',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '46',
#   '2대',
#   '국민',
#   '국민연금',
#   '연금',
#   '반대표',
#   '통과',
#   '주총',
#   '안건',
#   '83',
#   '찬성',
#   '가결',
#   '임채민',
#   '사외',
#   '사외이사',
#   '반대',
#   '의결권',
#   '행사',
#   '수탁자',
#   '수탁자책임전문위원회',
#   '책임',
#   '전문',
#   '위원회',
#   '아시아',
#   '인수',
#   '계약',
#   '체결',
#   '과정',
#   '실사',
#   '미실시',
#   '실시',
#   '계약상',
#   '불리',
#   '내용',
#   '회사',
#   '주주권익',
#   '권익',
#   '침해',
#   '이사회의',
#   '회의',
#   '감시',
#   '소홀',
#   '주장',
#   '결권',
#   '기준',
#   '지분',
#   '8.5',
#   '하다',
#   '최대',
#   '한진칼',
#   '29',
#   '특수',
#   '특수관계인',
#   '관계인',
#   '우리',
#   '사주',
#   '우호',
#   '40',
#   '김세진',
#   '세진',
#   '한국',
#   '한국펀드평가',
#   '펀드',
#   '평가',
#   '대표',
#   '장용성',
#   '용성',
#   '특임',
#   '특임교수',
#   '교수',
#   '이재민',
#   '서울대',
#   '원안',
#   '의결',
#   '이날',
#   '참석',
#   '대신',
#   '우기',
#   '우기홍',
#   '사장',
#   '대독',
#   '인사말',
#   '우리',
#   '우리나라',
#   '나라',
#   '항공산업',
#   '산업',
#   '위기',
#   '극복',
#   '장기적',
#   '성장',
#   '기반',
#   '확보',
#   '결정',
#   '일련',
#   '작업',
#   '순조',
#   '진행',
#   '올해',
#   '세계',
#   '전망',
#   '여객',
#   '수요',
#   '코로나',
#   '이전',
#   '회복',
#   '2024',
#   '2024년',
#   '현재',
#   '슬기',
#   '동시',
#   '포스트',
#   '시대',
#   '대비',
#   '역량',
#   '강화',
#   '최선',
#   '글로벌',
#   '항공사',
#   '대부분',
#   '천문학',
#   '적자',
#   '실정',
#   '화물',
#   '수익',
#   '창출',
#   '감소분',
#   '최대한',
#   '방어',
#   '영업',
#   '영업흑자',
#   '흑자',
#   '달성',
#   '백민',
#   '백민정',
#   '기자',
#   '관련',
#   '관련기사국민연금',
#   '기사',
#   '선택',
#   '금호석',
#   '호석',
#   '박찬',
#   '박찬구',
#   '지지',
#   '반대전경련',
#   '전경련',
#   '회장단',
#   '40대',
#   '합류',
#   '젊음',
#   '젊음피',
#   '수혈'],
#  ['뉴욕',
#   '뉴욕증권거래소',
#   '증권',
#   '거래소',
#   '상장',
#   '몸값',
#   '85',
#   '85조원',
#   '쿠팡',
#   '1년',
#   '2020',
#   '2020년',
#   '3월',
#   '1000',
#   '1000억엔',
#   '1조원',
#   '이상',
#   '적자',
#   '주주',
#   '소프트',
#   '소프트뱅크',
#   '뱅크',
#   '보전',
#   '기업',
#   '경쟁',
#   '생각',
#   '저격',
#   '사람',
#   '롯데',
#   '롯데그룹',
#   '그룹',
#   '신동',
#   '회장',
#   '일본',
#   '이자이',
#   '이자이신문',
#   '신문',
#   '인터뷰',
#   '지금',
#   '앤츠랩',
#   '롯데쇼핑',
#   '쇼핑',
#   '셔터',
#   '셔터스톡',
#   '스톡',
#   '폐점',
#   '판관비',
#   '관비',
#   '수익성',
#   '온라인',
#   '유통',
#   '삼국',
#   '삼국시대',
#   '시대',
#   '소외',
#   '변화',
#   '롯데온',
#   '대표',
#   '외부',
#   '외부인사',
#   '인사',
#   '영입',
#   '턴어라운드',
#   '라운드',
#   '증권가',
#   '2021',
#   '2021년',
#   '상황',
#   '설명',
#   '단어',
#   '바닥',
#   '올해',
#   '실적',
#   '이것',
#   '실적개선주',
#   '개선',
#   '이자',
#   '저평가주',
#   '평가',
#   '증권사',
#   '목표',
#   '목표주가',
#   '주가',
#   '계속',
#   '상향',
#   '잠깐',
#   '지난해',
#   '매출액',
#   '16',
#   '16조원',
#   '기준',
#   '롯데마트',
#   '마트',
#   '37.6',
#   '롯데하이마트',
#   '하이',
#   '25.2',
#   '롯데백화점',
#   '백화점',
#   '16.5',
#   '롯데슈퍼',
#   '슈퍼',
#   '10.3',
#   '롯데홈쇼핑',
#   '6.7',
#   '구성',
#   '흑자',
#   '전환',
#   '성공',
#   '코로나',
#   '감안',
#   '이익',
#   '하이마트',
#   '가전',
#   '수요',
#   '폭발',
#   '순항',
#   '문제',
#   '상당',
#   '상당부분',
#   '부분',
#   '절감',
#   '덕분',
#   '연간',
#   '119',
#   '119개',
#   '점포',
#   '구조',
#   '구조조정',
#   '조정',
#   '70',
#   '70여개',
#   '마무리',
#   '단계',
#   '성장',
#   '사업',
#   '축소',
#   '결과',
#   '결과라',
#   '걱정',
#   '걱정거리',
#   '거리',
#   '출범',
#   '통합',
#   '통합플랫폼',
#   '플랫폼',
#   '안정화',
#   '한참',
#   '거래액',
#   '7.0',
#   '국내',
#   '온라인쇼핑',
#   '성장률',
#   '19.1',
#   '시너지',
#   '효과',
#   '사업부',
#   '전무',
#   '지난달',
#   '유통시장',
#   '시장',
#   '말로',
#   '전쟁',
#   '현재',
#   '한국',
#   '하나',
#   '하나금융투자',
#   '금융',
#   '투자',
#   '여기',
#   '네이버',
#   '닷컴',
#   '최강자',
#   '뉴욕증시',
#   '증시',
#   '계기',
#   '독주',
#   '독주체제',
#   '체제',
#   '구축',
#   '시작',
#   '절치',
#   '절치부심',
#   '부심',
#   '베이',
#   '베이코리아',
#   '코리아',
#   '마켓',
#   '옥션',
#   '예비',
#   '예비입찰',
#   '입찰',
#   '참여',
#   '강희',
#   '강희태',
#   '대표이사',
#   '이사',
#   '부회장',
#   '23',
#   '23일',
#   '주주총회',
#   '총회',
#   '인수',
#   '관심',
#   '판단',
#   '순수',
#   '오픈',
#   '오픈마켓',
#   '이베이코리아',
#   '최저가',
#   '정책',
#   '승부',
#   '배송',
#   '배송경쟁력',
#   '경쟁력',
#   '파워',
#   '요즘',
#   '가격',
#   '편의성',
#   '중요',
#   '추세',
#   '한마디',
#   '끝물',
#   '인수가격',
#   '5조원',
#   '가능성',
#   '오프라인',
#   '결합',
#   '채널',
#   '모델',
#   '해외',
#   '여럿',
#   '미국',
#   '월마트',
#   '사례',
#   '2014',
#   '2014년',
#   '그것',
#   '주문',
#   '2018',
#   '2018년',
#   '광고',
#   '광고카피',
#   '카피',
#   '산다',
#   '정도',
#   '4개',
#   '스마트',
#   '스마트스토어',
#   '스토어',
#   '오프',
#   '라인',
#   '매장',
#   '배송거점',
#   '거점',
#   '중국',
#   '허마',
#   '부산',
#   '전역',
#   '새벽',
#   '새벽배송',
#   '도입',
#   '속도',
#   '이유',
#   '문화',
#   '2016',
#   '2016년',
#   '온라인쇼핑몰',
#   '쇼핑몰',
#   '제트',
#   '제트닷컴',
#   '창업자',
#   '출신',
#   '마크',
#   '로어',
#   '머스',
#   '전체',
#   '지휘',
#   '유통공룡',
#   '공룡',
#   '체질',
#   '디지털',
#   '부흥',
#   '정작',
#   '전문가',
#   '실패',
#   '전통적',
#   '중심',
#   '회사죠',
#   '사죠',
#   '게다',
#   '직위',
#   '직위여',
#   '계열사',
#   '협조',
#   '영호',
#   '전략',
#   '전략사업본부장',
#   '본부장',
#   '내정',
#   '전권',
#   '조직',
#   '물갈이',
#   '두고',
#   '인수전',
#   '적극적',
#   '거란',
#   '분석도',
#   '물류',
#   '물류창고',
#   '창고',
#   '역할',
#   '대형',
#   '대형마트',
#   '차별화',
#   '상품',
#   '신선',
#   '신선식품',
#   '식품',
#   '쇼룸화',
#   '전자',
#   '전자제품',
#   '자제품',
#   '제품',
#   '무엇',
#   '부동산',
#   '부잣집',
#   '잠재력',
#   '돌파구',
#   '0.34',
#   '0.34배',
#   '탈출',
#   '난망',
#   '결론',
#   '6개월',
#   '개월',
#   '티라노사우',
#   '노사',
#   '루스',
#   '사냥',
#   '앤츠랩',
#   '콘텐츠',
#   '뉴스',
#   '뉴스레터',
#   '레터',
#   '구독',
#   '관련',
#   '관련기사',
#   '기사',
#   '10',
#   '10위',
#   '바이오',
#   '왕자',
#   '치료제',
#   '신사업',
#   '신생',
#   '주력',
#   '회사',
#   '넷플릭스',
#   '플릭스',
#   '디즈니',
#   '수혜'],
#  ['스타',
#   '스타벅스커피',
#   '벅스',
#   '커피',
#   '코리아',
#   '지난해',
#   '12',
#   '12월',
#   '3일',
#   '세계',
#   '장애인',
#   '매장',
#   '직원',
#   '절반',
#   '고용',
#   '서울대',
#   '서울대치과병원점',
#   '치과',
#   '병원',
#   '사진',
#   '전자',
#   '전자노트',
#   '노트',
#   '필담',
#   '주문',
#   '모습',
#   '제공',
#   '연합',
#   '연합뉴스',
#   '뉴스',
#   '50',
#   '50인',
#   '미만',
#   '소규모',
#   '사업',
#   '신규',
#   '채용',
#   '고용장려금',
#   '장려금',
#   '공공',
#   '공공부문',
#   '부문',
#   '근로자',
#   '일정',
#   '비율',
#   '이상',
#   '의무',
#   '의무고용',
#   '여부',
#   '인건비',
#   '지원',
#   '지원중증',
#   '중증',
#   '출퇴근',
#   '비용',
#   '정부',
#   '부담',
#   '부담공공부문',
#   '고용장애인',
#   '교원',
#   '확대',
#   '학과',
#   '정원',
#   '30',
#   '고용노동부',
#   '노동부',
#   '내용',
#   '활성화',
#   '방안',
#   '26',
#   '26일',
#   '19',
#   '19차',
#   '일자리',
#   '일자리위원회',
#   '위원회',
#   '발표',
#   '사업장',
#   '의무제도',
#   '제도',
#   '적용',
#   '때문',
#   '보조',
#   '보조공학기기',
#   '공학',
#   '기기',
#   '표준',
#   '표준사업장',
#   '개선',
#   '지원금',
#   '각종',
#   '인센티브',
#   '전체',
#   '대비',
#   '3.1',
#   '초과',
#   '장애',
#   '정도',
#   '45',
#   '45만',
#   '80',
#   '80만원',
#   '관계',
#   '올해',
#   '시범',
#   '소득',
#   '상당',
#   '부분',
#   '콜택시',
#   '현실',
#   '반영',
#   '조치',
#   '5만원',
#   '만원',
#   '바우처',
#   '형태',
#   '계획',
#   '규모',
#   '의무적',
#   '상향',
#   '조정',
#   '지금',
#   '3.4',
#   '유지',
#   '2023',
#   '2023년',
#   '3.6',
#   '2024',
#   '2024년',
#   '3.8',
#   '의무고용비율',
#   '직접',
#   '2만5000명',
#   '5000',
#   '내년',
#   '2만7500명',
#   '7500',
#   '방침',
#   '이공계',
#   '인력',
#   '마련',
#   '현행',
#   '10',
#   '이내',
#   '제한',
#   '교직',
#   '교직과정',
#   '과정',
#   '4차',
#   '산업',
#   '관련',
#   '진학',
#   '특화',
#   '맞춤',
#   '맞춤훈련센터',
#   '훈련',
#   '센터',
#   '신설',
#   '고용노동전문기자',
#   '노동',
#   '전문',
#   '기자'],
#  ['기획',
#   '정부',
#   '1차관이',
#   '관이',
#   '26',
#   '26일',
#   '정부서울청사',
#   '서울',
#   '청사',
#   '11',
#   '11차',
#   '혁신',
#   '혁신성장',
#   '성장',
#   '전략',
#   '전략점검회의',
#   '점검',
#   '회의',
#   '정책',
#   '정책점검회의',
#   '한국판',
#   '한국판뉴딜',
#   '뉴딜',
#   '제7차',
#   '물가',
#   '물가관계차관회의',
#   '관계',
#   '차관',
#   '주재',
#   '1차관은',
#   '관은',
#   '과잉',
#   '과잉저축',
#   '저축',
#   '이연',
#   '시일',
#   '미룸',
#   '수요로',
#   '요로',
#   '일시적',
#   '물가상승',
#   '상승',
#   '가능성',
#   '배제',
#   '가공',
#   '가공식품',
#   '식품',
#   '생활',
#   '밀접',
#   '품목',
#   '중심',
#   '가격',
#   '인상',
#   '인상요인',
#   '요인',
#   '노력',
#   '병행',
#   '이날',
#   '전략점검',
#   '7차',
#   '에서다',
#   '최근',
#   '소비자',
#   '소비자물가',
#   '농축산물',
#   '수급',
#   '수급관리',
#   '관리',
#   '양호',
#   '기상',
#   '여건',
#   '일부',
#   '제외',
#   '안정세',
#   '전망',
#   '작년',
#   '하반기',
#   '이후',
#   '국제',
#   '곡물',
#   '즉석',
#   '즉석밥',
#   '두부',
#   '체감',
#   '상황',
#   '우려',
#   '식품업계',
#   '업계',
#   '소통',
#   '강화',
#   '동시',
#   '원자재',
#   '가격상승',
#   '어려움',
#   '기업',
#   '비축',
#   '비축물량',
#   '물량',
#   '공급',
#   '금융',
#   '세제',
#   '지원',
#   '지원확대',
#   '확대',
#   '수입',
#   '수입절차',
#   '절차',
#   '개선',
#   '관련',
#   '부담',
#   '부담완화',
#   '완화',
#   '조치',
#   '적극적',
#   '검토',
#   '한국',
#   '10',
#   '10대',
#   '대표',
#   '대표과제',
#   '과제',
#   '데이터',
#   '추진',
#   '추진경과',
#   '경과',
#   '계획',
#   '논의',
#   '2025',
#   '2025년',
#   '18',
#   '18조1000억',
#   '1000',
#   '지난해',
#   '경우',
#   '7대',
#   '핵심',
#   '핵심사업',
#   '사업',
#   '5만명',
#   '이상',
#   '참여',
#   '올해',
#   '3000',
#   '3000여개',
#   '중소기업',
#   '스타트',
#   '스타트업',
#   '대상',
#   '활용',
#   '인공',
#   '인공지능',
#   '지능',
#   '솔류션',
#   '클라우드',
#   '도입',
#   '혁신서비스',
#   '서비스',
#   '개발',
#   '세종',
#   '김남',
#   '기자'],
#  ['기의',
#   '은퇴',
#   '은퇴생활백서',
#   '생활',
#   '백서',
#   '82',
#   '신문',
#   '기고',
#   '수백',
#   '수백여',
#   '댓글',
#   '내용',
#   '마감',
#   '그동안',
#   '도움',
#   '이웃',
#   '감사',
#   '인사',
#   '말기',
#   '환자',
#   '이야기',
#   '부모님',
#   '눈물',
#   '독자',
#   '사람',
#   '연출자',
#   '연극',
#   '관객',
#   '모습',
#   '무대',
#   '보람',
#   '정도',
#   '공감',
#   '코끝',
#   '경험',
#   '오래전',
#   '영화화',
#   '소설',
#   '러브',
#   '러브스토리',
#   '스토리',
#   '감동',
#   '주인공',
#   '위로',
#   '시걸',
#   '원고',
#   '탈고',
#   '자신',
#   '짐작',
#   '시걸이',
#   '걸이',
#   '바탕',
#   '추측',
#   '작가',
#   '불평',
#   '고객',
#   '사진',
#   '기고하면',
#   '하면',
#   '반응',
#   '기사',
#   '관심',
#   '반면',
#   '뉴스',
#   '충격',
#   '자살',
#   '연예인',
#   '마음',
#   '필자',
#   '시간',
#   '쪼개어',
#   '표명',
#   '사실',
#   '일전',
#   '금융',
#   '금융회사',
#   '회사',
#   '근무',
#   '창구',
#   '경우',
#   '대개',
#   '고객서비스',
#   '서비스',
#   '모자람',
#   '지적',
#   '창구서비스',
#   '개선',
#   '필요',
#   '거래',
#   '애정',
#   '때문',
#   '마찬가지',
#   '불편',
#   '시각',
#   '입장',
#   '고려',
#   '한계',
#   '상처',
#   '목숨',
#   '기업가',
#   '정치가',
#   '대우',
#   '대우건설',
#   '건설',
#   '사장',
#   '역임',
#   '남상',
#   '남상국은',
#   '국은',
#   '서울대',
#   '졸업',
#   '1974',
#   '1974년',
#   '평사원',
#   '대우그룹',
#   '그룹',
#   '입사',
#   '1999',
#   '1999년',
#   '사장직',
#   '2003',
#   '2003년',
#   '경영',
#   '경영능력',
#   '능력',
#   '금탑',
#   '금탑산업훈장',
#   '산업',
#   '훈장',
#   '노무현',
#   '대통령',
#   '제공',
#   '뇌물',
#   '뇌물수수',
#   '수수',
#   '혐의',
#   '검찰',
#   '수사',
#   '하루',
#   '기자',
#   '기자회견',
#   '회견',
#   '석상',
#   '이름',
#   '거론',
#   '비판',
#   '직후',
#   '한강',
#   '투신',
#   '그로',
#   '얼마',
#   '퇴임',
#   '이번',
#   '수사망',
#   '마을',
#   '뒷산',
#   '평범',
#   '국가',
#   '국가지도자',
#   '지도자',
#   '인물',
#   '우리',
#   '사회',
#   '평생',
#   '도덕적',
#   '이미지',
#   '흠집',
#   '상황',
#   '인정',
#   '잘못',
#   '누구',
#   '정부',
#   '조언',
#   '아쉬움',
#   '법정',
#   '스님',
#   '절판',
#   '절판하라',
#   '하라',
#   '유언',
#   '생각',
#   '전달',
#   '우려',
#   '중앙',
#   '중앙포토',
#   '포토',
#   '표현',
#   '부족',
#   '그것',
#   '상대방',
#   '이해',
#   '나름',
#   '타인',
#   '각색',
#   '해석',
#   '오해',
#   '염려',
#   '해인',
#   '수녀',
#   '아래',
#   '씨라도',
#   '라도',
#   '어디',
#   '선가',
#   '뿌리',
#   '중략',
#   '결심',
#   '슬기',
#   '주인',
#   '허락',
#   '주여',
#   '하나',
#   '탄생',
#   '침묵',
#   '지혜',
#   '시인',
#   '사회생활',
#   '하다',
#   '불교',
#   '염화',
#   '염화미소',
#   '미소',
#   '일화',
#   '인가',
#   '세상',
#   '운명',
#   '글쓰기',
#   '고통',
#   '계속',
#   '주기',
#   '격려',
#   '용기',
#   '용기백배',
#   '백배',
#   '노력',
#   '냉소',
#   '진정',
#   '아름',
#   '인생',
#   '인생학교',
#   '학교',
#   '교장',
#   '관련',
#   '관련기사',
#   '나이',
#   '자동차',
#   '이유',
#   '가지',
#   '우리',
#   '우리나라',
#   '나라',
#   '국민',
#   '80',
#   '안락사',
#   '찬성',
#   '형법',
#   '욕망'],
#  ['성제혁',
#   '제혁',
#   '지피',
#   '지피바이오',
#   '바이오',
#   '대표',
#   '23',
#   '23일',
#   '경기',
#   '경기도',
#   '광명',
#   '본사',
#   '조기',
#   '교육',
#   '성장',
#   '전문적',
#   '체계적',
#   '관리',
#   '필요',
#   '필요하다',
#   '하다',
#   '역설',
#   '정시',
#   '정시종',
#   '기자',
#   '이제',
#   '신장',
#   '인공',
#   '인공지능',
#   '지능',
#   '빅데이터',
#   '데이터',
#   '시대',
#   '학회',
#   '후천적',
#   '요인',
#   '77',
#   '결정',
#   '전문가',
#   '유전',
#   '조절',
#   '광범위',
#   '생체',
#   '바탕',
#   '예측',
#   '솔루션',
#   '제공',
#   '경기',
#   '8년',
#   '축적',
#   '2300',
#   '2300만건',
#   '통해',
#   '성장관리',
#   '제시',
#   '성장요인',
#   '영향',
#   '모방',
#   '불가능',
#   '2300만여',
#   '설립',
#   '2013',
#   '2013년',
#   '이전',
#   '명지대',
#   '지대',
#   '체육',
#   '체육학과',
#   '학과',
#   '시절',
#   '소아',
#   '소아청소년',
#   '청소년',
#   '건강관리',
#   '정보',
#   '수집',
#   '체격',
#   '학생',
#   '오프라인',
#   '초등학생',
#   '상대',
#   '주기적',
#   '1타임',
#   '타임',
#   '90',
#   '90분',
#   '수업',
#   '18',
#   '20',
#   '20타임',
#   '소화',
#   '아이',
#   '학부모',
#   '소통',
#   '처음',
#   '수기',
#   '작성',
#   '시행',
#   '데이',
#   '생각',
#   '소프트',
#   '소프트웨어',
#   '웨어',
#   '개발',
#   '1000',
#   '1000명',
#   '발품',
#   '확보',
#   '양은',
#   '2300만',
#   '근육',
#   '근육양',
#   '단백질',
#   '단백질량',
#   '수분',
#   '체지방',
#   '지방',
#   '기초',
#   '기초대사',
#   '대사',
#   '50',
#   '50가지',
#   '가지',
#   '입력',
#   '현재',
#   '6만5000',
#   '5000',
#   '7만명가량',
#   '가량',
#   '보유',
#   '이상',
#   '활용',
#   '보통',
#   '신약',
#   '과정',
#   '임상',
#   '3상',
#   '많으',
#   '추적',
#   '7만명',
#   '시스템',
#   '구축',
#   '신뢰성',
#   '장점',
#   '표본',
#   '일정',
#   '한정',
#   '19',
#   '19세',
#   '다양',
#   '다양하다',
#   '누적',
#   '국내외',
#   '8년간',
#   '빅데이터라',
#   '최대',
#   '강점',
#   '자신',
#   '유아기',
#   '지도',
#   '성장예측',
#   '키맵',
#   '닥터',
#   '소아과',
#   '소아과연합',
#   '연합',
#   '협력',
#   '맺어',
#   '100',
#   '100여',
#   '소아과병원',
#   '병원',
#   '오차율',
#   '0.99',
#   '1.5',
#   '불과',
#   '정도로',
#   '도로',
#   '정확도',
#   '자랑',
#   '사실',
#   '중요',
#   '정확',
#   '다양화',
#   '친구',
#   '직관적',
#   '핵심',
#   '설명',
#   '최근',
#   '성조숙증',
#   '조숙',
#   '비만증',
#   '아동',
#   '아동청소년기의',
#   '기의',
#   '이슈',
#   '부각',
#   '부모',
#   '관심도',
#   '요구',
#   '시기',
#   '우리',
#   '단발',
#   '검사',
#   '지속적',
#   '변화',
#   '체성분',
#   '기준',
#   '노력',
#   '예측값',
#   '지표',
#   '가능성',
#   '도움',
#   '때문',
#   '또래',
#   '비교',
#   '마음',
#   '초등학교',
#   '4학년',
#   '학년',
#   '이후',
#   '스트레스',
#   '5세',
#   '1년',
#   '2번꼴',
#   '추천',
#   '영어',
#   '성과',
#   '중요성',
#   '주요',
#   '요소',
#   '영양',
#   '운동',
#   '수면',
#   '생활',
#   '생활습관',
#   '습관',
#   '자세',
#   '심리',
#   '8가지',
#   '한국',
#   '북한',
#   '성인',
#   '평균',
#   '차이',
#   '정도',
#   '호르몬',
#   '분비',
#   '활성화',
#   '지금',
#   '80',
#   '80점',
#   '3년',
#   '코스닥',
#   '상장',
#   '목표',
#   '7가지',
#   '압축',
#   '특허',
#   '20장',
#   '페이퍼',
#   '분석',
#   '체중',
#   '골격근',
#   '골격근량',
#   '무기질',
#   '기초대사량',
#   '대사량',
#   '시장',
#   '아동수가',
#   '수가',
#   '감소',
#   '있음',
#   '증가',
#   '국내',
#   '10',
#   '10조원',
#   '추정',
#   '세계',
#   '400',
#   '400조원',
#   '규모',
#   '일반적',
#   '성장클리닉',
#   '클리닉',
#   '센터',
#   '경우',
#   '비용',
#   '가격',
#   '의사',
#   '협업',
#   '믿음',
#   '소견',
#   '필수',
#   '결과',
#   '추가',
#   '추가적인',
#   '적인',
#   '방대',
#   '기준점',
#   '포부',
#   '심층',
#   '연구',
#   '사람',
#   '식습관',
#   '행동',
#   '패턴',
#   '작업',
#   '진행',
#   '스포츠',
#   '꿈나무',
#   '고무적',
#   '강조',
#   '6세',
#   '검진',
#   '자녀',
#   '필요성',
#   '대두',
#   '관련',
#   '기업',
#   '추진',
#   '미소',
#   '대학',
#   '쉼표',
#   '지난해',
#   '매출',
#   '20억원',
#   '가시',
#   '기술',
#   '특례',
#   '배달',
#   '배민',
#   '당일',
#   '배송',
#   '쿠팡',
#   '인류',
#   '성장발달',
#   '발달',
#   '기여'],
#  ['조선',
#   '기생집',
#   '충녕대군',
#   '구마',
#   '구마사제',
#   '사제',
#   '월병',
#   '피단',
#   '대접',
#   '장면',
#   '방송',
#   '방송화면',
#   '화면',
#   '캡처',
#   '유통',
#   '업계',
#   '반중',
#   '정서',
#   '몸살',
#   '드라마',
#   '제작',
#   '지원',
#   '광고',
#   '해당',
#   '역사',
#   '왜곡',
#   '동북',
#   '동북공정',
#   '공정',
#   '논란',
#   '기업',
#   '이미지',
#   '타격',
#   '불똥',
#   '노심초사',
#   '25',
#   '25일',
#   '최근',
#   '월화',
#   '월화극',
#   '조선구마사',
#   '구마사',
#   '관련',
#   '중단',
#   '선언',
#   '제일',
#   '제일제당',
#   '제당',
#   '하이',
#   '생활',
#   '생활건강',
#   '건강',
#   '호관원',
#   '관원',
#   '반올림',
#   '반올림식품',
#   '식품',
#   '편성',
#   '결정',
#   '에이스',
#   '에이스침대',
#   '침대',
#   '코지',
#   '코지마',
#   '안마',
#   '뉴온',
#   '바디',
#   '바디프렌드',
#   '프렌드',
#   '블랙',
#   '블랙야크',
#   '야크',
#   '금성',
#   '금성침대',
#   '쌍방울',
#   '철회',
#   '전락',
#   '22',
#   '22일',
#   '중국',
#   '빌미',
#   '제공',
#   '충녕대군',
#   '대군',
#   '장동윤',
#   '동윤',
#   '신부',
#   '파켓',
#   '중국식',
#   '만두',
#   '오리알',
#   '구성',
#   '잔칫상',
#   '때문',
#   '14',
#   '14일',
#   '청와대',
#   '국민',
#   '국민청원',
#   '청원',
#   '게시판',
#   '방영',
#   '방영중지',
#   '중지',
#   '요청',
#   '게시',
#   '게시글',
#   '하루',
#   '13',
#   '13만',
#   '이상',
#   '동의',
#   '이번',
#   '처음',
#   '대상',
#   '중인',
#   '토일드라마',
#   '주인공',
#   '즈하이궈',
#   '인스턴트',
#   '비빔밥',
#   '제품',
#   '간접',
#   '간접광고',
#   '뭇매',
#   '김치',
#   '한복',
#   '자신',
#   '문화',
#   '주장',
#   '한국',
#   '전통',
#   '음식',
#   '명분',
#   '이유',
#   '협업',
#   '의혹',
#   '제기',
#   '적극',
#   '해명',
#   '입장',
#   '입장문',
#   '청정원',
#   '정원',
#   '브랜드',
#   '합작',
#   '내용',
#   '언론',
#   '언급',
#   '사실',
#   '당사',
#   '현지',
#   '공장',
#   '소비자',
#   '생산',
#   '원료',
#   '단순',
#   '납품',
#   '국내',
#   '마케팅',
#   '활동',
#   '관여',
#   '제작지원',
#   '물론',
#   '업체',
#   '관계자',
#   '그동안',
#   '예상',
#   '시청률',
#   '분석',
#   '대행사',
#   '추천',
#   '스토리',
#   '전개',
#   '제작비용',
#   '비용',
#   '자본',
#   '관계',
#   '계획',
#   '안민',
#   '안민구',
#   '기자'],
#  ['쿠팡',
#   '배달',
#   '배달파트너',
#   '파트너',
#   '홈페이지',
#   '설치',
#   '화면',
#   '최근',
#   '쿠팡이츠',
#   '배달음식',
#   '음식',
#   '주문',
#   '흰색',
#   '롱패딩',
#   '패딩',
#   '커플',
#   '배달원',
#   '경험',
#   '남자',
#   '배민',
#   '넥트',
#   '가방',
#   '전달',
#   '전업',
#   '부업',
#   '증가',
#   '증가하루',
#   '하루',
#   '3시간',
#   '시간',
#   '100',
#   '100만원',
#   '일반인',
#   '코로나',
#   '코로나19',
#   '19',
#   '확산',
#   '수요',
#   '인력',
#   '부족',
#   '배달앱들',
#   '진입',
#   '진입장벽',
#   '장벽',
#   '때문',
#   '점심',
#   '저녁',
#   '시간',
#   '이유',
#   '주목적',
#   '하지',
#   '목적',
#   '도보',
#   '다이어트',
#   '데이트',
#   '다양',
#   '모습',
#   '25',
#   '25일',
#   '배달앱',
#   '민족',
#   '배민커넥트',
#   '등록',
#   '인원수',
#   '5만',
#   '데믹',
#   '2019',
#   '2019년',
#   '등록자',
#   '수인',
#   '1만',
#   '5배가량',
#   '가량',
#   '가운데',
#   '활동',
#   '정도',
#   '2030',
#   '중은',
#   '80',
#   '7월',
#   '시범',
#   '도입',
#   '정착',
#   '프로그램',
#   '자신',
#   '보유',
#   '자동차',
#   '오토바이',
#   '자전거',
#   '전동',
#   '전동킥보드',
#   '보드',
#   '지역',
#   '서비스',
#   '아르바이트',
#   '요즘',
#   '구직',
#   '구직난',
#   '인기',
#   '관계자',
#   '교육',
#   '처음',
#   '방법',
#   '선택',
#   '라이더',
#   '공격적',
#   '마케팅',
#   '수가',
#   '급증',
#   '빅데이터',
#   '데이터',
#   '플랫폼',
#   '기업인',
#   '아이',
#   '아이지에이웍스',
#   '지에이웍스',
#   '모바일',
#   '모바일인덱스',
#   '인덱스',
#   '전용',
#   '월간',
#   '월간순이용자',
#   '이용자',
#   '지난해',
#   '5월',
#   '3만8000명',
#   '8000',
#   '올해',
#   '1월',
#   '48',
#   '48만명',
#   '8개월',
#   '개월',
#   '12',
#   '12배',
#   '이상',
#   '운영',
#   '구조',
#   '배차',
#   '1곳',
#   '가능',
#   '차이',
#   '배달앱',
#   '시스템',
#   '형태',
#   '퇴근',
#   '여유',
#   '여유시간',
#   '이용',
#   '부수입',
#   '일부',
#   '운동',
#   '수입',
#   '이외',
#   '경우',
#   '가입',
#   '주말',
#   '접근',
#   '후기',
#   '상당',
#   '본업',
#   '컴퓨터',
#   '걷기',
#   '얼마',
#   '취미',
#   '생활',
#   '포털',
#   '포털사이트',
#   '사이트',
#   '커뮤니티',
#   '회원',
#   '해당',
#   '여자',
#   '여자친구',
#   '친구',
#   '마무리',
#   '금액',
#   '데이트통장',
#   '통장',
#   '호텔',
#   '뷔페',
#   '예정',
#   '비용',
#   '충당',
#   '수단',
#   '활용',
#   '실제',
#   '기본',
#   '수도권',
#   '건당',
#   '평균',
#   '3300',
#   '3300원임',
#   '원임',
#   '고려',
#   '3건',
#   '게다',
#   '최고',
#   '2만원',
#   '배달비',
#   '책정',
#   '배달업계',
#   '업계',
#   '여성',
#   '비율',
#   '예전',
#   '피크',
#   '피크타임',
#   '타임',
#   '2시간',
#   '권지',
#   '권지예',
#   '기자'],
#  ['네이버',
#   '본사',
#   '최근',
#   '서비스',
#   '광범위',
#   '장애',
#   '분산',
#   '분산서비스거부',
#   '거부',
#   '디도스',
#   '도스',
#   '공격',
#   '때문',
#   '정부',
#   '당국',
#   '고객',
#   '고객정보',
#   '정보',
#   '유출',
#   '여부',
#   '확인',
#   '발표',
#   '예정',
#   '네트워크',
#   '장비',
#   '부팅',
#   '과정',
#   '접속',
#   '오류',
#   '25',
#   '25일',
#   '업계',
#   '24',
#   '24일',
#   '오후',
#   '발생',
#   '외부',
#   '방어',
#   '스위치',
#   '관계자',
#   '대응',
#   '한시적',
#   '접근',
#   '불가',
#   '관련',
#   '과학',
#   '과학기술정보통신',
#   '기술',
#   '통신',
#   '이하',
#   '과기',
#   '과기정통부',
#   '정통부',
#   '구글',
#   '마찬가지',
#   '원인',
#   '파악',
#   '자료',
#   '요청',
#   '근거',
#   '필요',
#   '조처',
#   '계획',
#   '올해',
#   '넷플릭스',
#   '플릭스',
#   '페이스',
#   '페이스북',
#   '카카오',
#   '콘텐츠',
#   '콘텐츠웨이브',
#   '웨이브',
#   '안정성',
#   '확보',
#   '의무',
#   '기업',
#   '지정',
#   '문제',
#   '개선',
#   '시정',
#   '시정조치',
#   '조치',
#   '메시지',
#   '캡처',
#   '5시',
#   '20',
#   '20분',
#   '뉴스',
#   '카페',
#   '로그',
#   '모든',
#   '일시적',
#   '문구',
#   '6시',
#   '10',
#   '10분',
#   '복구',
#   '현재',
#   '내부',
#   '통신경쟁정책',
#   '경쟁',
#   '정책',
#   '사이버',
#   '사이버침해',
#   '침해',
#   '응과',
#   '협업',
#   '조사',
#   '재발',
#   '방지책',
#   '수립',
#   '사이버침해대응',
#   '주체',
#   '어디',
#   '점검',
#   '완료',
#   '공지',
#   '국내',
#   '압도',
#   '압도적인',
#   '적인',
#   '이용률',
#   '자랑',
#   '1위',
#   '포털',
#   '이용자',
#   '불안',
#   '네이버페이',
#   '본인',
#   '본인인증',
#   '인증',
#   '제공',
#   '개인',
#   '개인정보',
#   '우려',
#   '탈취',
#   '사례',
#   '회사',
#   '설명',
#   '정길',
#   '기자'],
#  ['신학',
#   '신학철',
#   '화학',
#   '부회장',
#   '합당',
#   '배상',
#   '엄정',
#   '대처',
#   '25',
#   '25일',
#   '20',
#   '20기',
#   '정기',
#   '주주',
#   '주주총회',
#   '총회',
#   '노베이션',
#   '베이',
#   '전기',
#   '전기차',
#   '배터리',
#   '영업',
#   '영업비밀',
#   '비밀',
#   '침해',
#   '분쟁',
#   '관련',
#   '소송',
#   '미국',
#   '국제',
#   '국제무역위원회',
#   '무역',
#   '위원회',
#   '세계적',
#   '경영',
#   '기조',
#   '가운데',
#   '경쟁',
#   '회사',
#   '지식',
#   '지식재산권',
#   '재산권',
#   '존중',
#   '기업',
#   '기업운영',
#   '운영',
#   '기본',
#   '준수',
#   '해당',
#   '결정',
#   '원인',
#   '글로벌',
#   '경험',
#   '미숙',
#   '지적',
#   '박성호',
#   '3대',
#   '하나',
#   '하나은행장',
#   '은행장',
#   '취임',
#   '하나은행',
#   '은행',
#   '대표',
#   '대표이사',
#   '이사',
#   '후보',
#   '행장',
#   '2015',
#   '2015년',
#   '9월',
#   '통합',
#   '통합은행',
#   '출범',
#   '초대',
#   '함영주',
#   '영주',
#   '지성규',
#   '성규',
#   '신임',
#   '이날',
#   '오후',
#   '을지로',
#   '지로',
#   '본점',
#   '6층',
#   '대강당',
#   '취임식',
#   '전임',
#   '깃발',
#   '전달',
#   '시작',
#   '취임사',
#   '아프리카',
#   '세랭게티',
#   '초원',
#   '누떼',
#   '생존',
#   '악어',
#   '악어떼',
#   '선두',
#   '무리',
#   '리더',
#   '그룹',
#   '발전',
#   '솔선수범',
#   '포부',
#   '정몽구',
#   '명예',
#   '명예회장',
#   '회장',
#   '현대',
#   '현대모비스',
#   '모비스',
#   '등기',
#   '등기이사',
#   '정몽구',
#   '등기이사직',
#   '그룹경영',
#   '현대차그룹',
#   '마지막',
#   '유지',
#   '24',
#   '24일',
#   '조성환',
#   '사장',
#   '재경부',
#   '재경부문장',
#   '문장',
#   '부사장',
#   '고영',
#   '연구',
#   '연구개발',
#   '개발',
#   '기획',
#   '기획운영실장',
#   '실장',
#   '사내',
#   '사내이사',
#   '선임',
#   '몽구',
#   '임기',
#   '1년',
#   '경영일선',
#   '일선',
#   '지난해',
#   '2월',
#   '현대차',
#   '그해',
#   '3월',
#   '이사회',
#   '의장',
#   '의장직',
#   '정의',
#   '정의선',
#   '10',
#   '10월',
#   '회장직',
#   '이재명',
#   '감사',
#   '감사편지',
#   '편지',
#   '정용진',
#   '용진',
#   '신세계',
#   '신세계그룹',
#   '제공',
#   '최근',
#   '경기',
#   '경기도',
#   '경기도지사',
#   '지사',
#   '페이스',
#   '페이스북',
#   '경제',
#   '환경',
#   '급변',
#   '고착',
#   '조짐',
#   '저성장',
#   '추세',
#   '투자',
#   '결단',
#   '주신',
#   '혜안',
#   '인사',
#   '우여곡절',
#   '첫발',
#   '만큼',
#   '차질',
#   '진행',
#   '한국',
#   '한국수자원공사',
#   '수자원',
#   '공사',
#   '화성',
#   '화성국제테마파크',
#   '테마',
#   '파크',
#   '건설',
#   '토지',
#   '토지공급계약',
#   '공급',
#   '계약',
#   '체결'],
#  ['강신영',
#   '신영',
#   '댄스',
#   '51',
#   '강사',
#   '요가',
#   '여행사',
#   '가이드',
#   '사람',
#   '인솔',
#   '입장',
#   '말조심',
#   '필요',
#   '한마디',
#   '수강생',
#   '상처',
#   '반발',
#   '적대감',
#   '결국',
#   '자신',
#   '화가',
#   '때문',
#   '대상',
#   '통제',
#   '하다',
#   '짜증',
#   '자기',
#   '생각',
#   '경우',
#   '말귀',
#   '총기',
#   '자체',
#   '아래',
#   '하대',
#   '갑질',
#   '문제',
#   '이해',
#   '설명',
#   '질문',
#   '대답',
#   '여러분',
#   '여럿',
#   '하나',
#   '조심',
#   '말투',
#   '무시',
#   '기분',
#   '얘기',
#   '사진',
#   '표현',
#   '지시',
#   '의도',
#   '행동',
#   '지방',
#   '사투리',
#   '상대방',
#   '경멸',
#   '조롱',
#   '아이',
#   '성인',
#   '주세',
#   '집중',
#   '정도',
#   '모양',
#   '자존심',
#   '상해',
#   '그것',
#   '사실',
#   '자기',
#   '말로',
#   '처음',
#   '단둘',
#   '지적',
#   '망신',
#   '모욕적',
#   '부정적',
#   '단어',
#   '즉각적',
#   '마련',
#   '누구',
#   '가정',
#   '사회',
#   '대우',
#   '표정',
#   '의사',
#   '교사',
#   '기업가',
#   '출신',
#   '부부',
#   '아내',
#   '남편',
#   '수모',
#   '인텔리',
#   '자부심',
#   '좌뇌',
#   '발달',
#   '반면',
#   '예술',
#   '문화',
#   '부문',
#   '성공',
#   '우뇌',
#   '양쪽',
#   '반쪽',
#   '바보',
#   '동작',
#   '교정',
#   '통증',
#   '고개',
#   '각도',
#   '얼굴',
#   '본인',
#   '이외',
#   '호칭',
#   '중요',
#   '선생님',
#   '어르신',
#   '일반적',
#   '선생',
#   '시비',
#   '학교',
#   '아무',
#   '불만',
#   '나이',
#   '노인',
#   '닉네임',
#   '말실수',
#   '실수',
#   '불손',
#   '세계',
#   '레슨',
#   '레슨비',
#   '반환',
#   '소송',
#   '세계적',
#   '유명',
#   '유명해진',
#   '해진',
#   '홍콩',
#   '모니카',
#   '8년간',
#   '150',
#   '150억',
#   '해당',
#   '계약',
#   '웡여사',
#   '여자',
#   '인생',
#   '말년',
#   '봐야겠다',
#   '금액',
#   '그만큼',
#   '열정',
#   '가치',
#   '인정',
#   '대회',
#   '암소',
#   '당신',
#   '머리',
#   '궁둥이',
#   '비속',
#   '언어',
#   '인격',
#   '모욕',
#   '도제',
#   '방식',
#   '선수',
#   '직장',
#   '생활',
#   '사회성',
#   '생업',
#   '기량',
#   '기준',
#   '아주',
#   '차이',
#   '반말',
#   '손해',
#   '내용',
#   '회식',
#   '자리',
#   '노골적',
#   '강습',
#   '술자리',
#   '냐며',
#   '분위기',
#   '불편',
#   '정식',
#   '엘리트',
#   '코스',
#   '경향',
#   '상대',
#   '존중',
#   '배려',
#   '현업',
#   '스트레스',
#   '취미',
#   '대부분',
#   '칼럼니스트',
#   '관련',
#   '관련기사',
#   '기사',
#   '1분30초',
#   '30',
#   '약골',
#   '감당',
#   '진짜',
#   '엉덩이',
#   '확대',
#   '수술',
#   '삼바',
#   '여인']]

# %%
from apyori import apriori 

rules = apriori(news, min_support=0.3, min_confidence=0.2)
result = list(rules)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7e7607a5dd4d> in <module>
#       1 from apyori import apriori
#       2
# ----> 3 rules = apriori(news, min_support=0.3, min_confidence=0.2)
#       4 result = list(rules)
#
# NameError: name 'news' is not defined

# %%
for r in result:
    print(r, end='\n\n')
# (lift=0.1 인 애들은 상관관계가 없으므로 빼고 확인한다.)
# Out:
# RelationRecord(items=frozenset({'10'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'10'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'26'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26'}), confidence=0.6, lift=1.0)])
#
# RelationRecord(items=frozenset({'26일'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26일'}), confidence=0.6, lift=1.0)])
#
# RelationRecord(items=frozenset({'경우'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'경우'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'계획'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'계획'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'관련'}), support=0.7333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련'}), confidence=0.7333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'국내'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'국내'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'그룹'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'그룹'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'기사'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사'}), confidence=0.4666666666666667, lift=1.0)])
#
# RelationRecord(items=frozenset({'기업'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기업'}), confidence=0.43333333333333335, lift=1.0)])
#
# RelationRecord(items=frozenset({'기자'}), support=0.7, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자'}), confidence=0.7, lift=1.0)])
#
# RelationRecord(items=frozenset({'기준'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기준'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'뉴스'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'뉴스'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'대표'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'대표'}), confidence=0.5, lift=1.0)])
#
# RelationRecord(items=frozenset({'때문'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'때문'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'사업'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사업'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'사진'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사진'}), confidence=0.4666666666666667, lift=1.0)])
#
# RelationRecord(items=frozenset({'설명'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'설명'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'성장'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'성장'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'세계'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'세계'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'시장'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시장'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'올해'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'올해'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'이날'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이날'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'이번'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이번'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'이사'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이사'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'이상'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이상'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'전망'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'전망'}), confidence=0.36666666666666664, lift=1.0)])
#
# RelationRecord(items=frozenset({'정부'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'정부'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'제공'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'제공'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'주주'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'주주'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'주주총회'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'주주총회'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'지난해'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'지난해'}), confidence=0.4666666666666667, lift=1.0)])
#
# RelationRecord(items=frozenset({'총회'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'총회'}), confidence=0.3, lift=1.0)])
#
# RelationRecord(items=frozenset({'최근'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'최근'}), confidence=0.4, lift=1.0)])
#
# RelationRecord(items=frozenset({'코로나'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'한국'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'한국'}), confidence=0.4666666666666667, lift=1.0)])
#
# RelationRecord(items=frozenset({'회사'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'회사'}), confidence=0.3333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'26일', '26'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26', '26일'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'관련', '26'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '26'}), confidence=0.43333333333333335, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'관련'}), confidence=0.7222222222222223, lift=0.9848484848484851), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'26'}), confidence=0.5909090909090909, lift=0.984848484848485)])
#
# RelationRecord(items=frozenset({'기사', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사', '26'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기사'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'26'}), confidence=0.7142857142857142, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'기자', '26'}), support=0.5333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '26'}), confidence=0.5333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기자'}), confidence=0.888888888888889, lift=1.26984126984127), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'26'}), confidence=0.761904761904762, lift=1.26984126984127)])
#
# RelationRecord(items=frozenset({'대표', '26'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26', '대표'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'대표'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'대표'}), items_add=frozenset({'26'}), confidence=0.6, lift=1.0)])
#
# RelationRecord(items=frozenset({'사진', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사진', '26'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'사진'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'26'}), confidence=0.7142857142857142, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'이날', '26'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이날', '26'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'이날'}), confidence=0.611111111111111, lift=1.5277777777777775), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'26'}), confidence=0.9166666666666665, lift=1.5277777777777777)])
#
# RelationRecord(items=frozenset({'전망', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'전망', '26'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'전망'}), confidence=0.5555555555555556, lift=1.5151515151515154), OrderedStatistic(items_base=frozenset({'전망'}), items_add=frozenset({'26'}), confidence=0.9090909090909091, lift=1.5151515151515151)])
#
# RelationRecord(items=frozenset({'26', '지난해'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26', '지난해'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'지난해'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'26'}), confidence=0.7142857142857142, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'관련', '26일'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '26일'}), confidence=0.43333333333333335, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'관련'}), confidence=0.7222222222222223, lift=0.9848484848484851), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'26일'}), confidence=0.5909090909090909, lift=0.984848484848485)])
#
# RelationRecord(items=frozenset({'기사', '26일'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사', '26일'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'기사'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'26일'}), confidence=0.7142857142857142, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'기자', '26일'}), support=0.5333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '26일'}), confidence=0.5333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'기자'}), confidence=0.888888888888889, lift=1.26984126984127), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'26일'}), confidence=0.761904761904762, lift=1.26984126984127)])
#
# RelationRecord(items=frozenset({'대표', '26일'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26일', '대표'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'대표'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'대표'}), items_add=frozenset({'26일'}), confidence=0.6, lift=1.0)])
#
# RelationRecord(items=frozenset({'사진', '26일'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사진', '26일'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'사진'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'26일'}), confidence=0.7142857142857142, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'이날', '26일'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이날', '26일'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'이날'}), confidence=0.611111111111111, lift=1.5277777777777775), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'26일'}), confidence=0.9166666666666665, lift=1.5277777777777777)])
#
# RelationRecord(items=frozenset({'전망', '26일'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'전망', '26일'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'전망'}), confidence=0.5555555555555556, lift=1.5151515151515154), OrderedStatistic(items_base=frozenset({'전망'}), items_add=frozenset({'26일'}), confidence=0.9090909090909091, lift=1.5151515151515151)])
#
# RelationRecord(items=frozenset({'26일', '지난해'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26일', '지난해'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'지난해'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'26일'}), confidence=0.7142857142857142, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'관련', '그룹'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '그룹'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'그룹'}), confidence=0.4090909090909091, lift=1.2272727272727275), OrderedStatistic(items_base=frozenset({'그룹'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.2272727272727273)])
#
# RelationRecord(items=frozenset({'관련', '기사'}), support=0.4666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기사'}), confidence=0.4666666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기사'}), confidence=0.6363636363636365, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'관련'}), confidence=1.0, lift=1.3636363636363638)])
#
# RelationRecord(items=frozenset({'관련', '기업'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기업'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기업'}), confidence=0.45454545454545453, lift=1.048951048951049), OrderedStatistic(items_base=frozenset({'기업'}), items_add=frozenset({'관련'}), confidence=0.7692307692307692, lift=1.048951048951049)])
#
# RelationRecord(items=frozenset({'관련', '기자'}), support=0.5666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기자'}), confidence=0.5666666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기자'}), confidence=0.7727272727272727, lift=1.103896103896104), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'관련'}), confidence=0.8095238095238095, lift=1.103896103896104)])
#
# RelationRecord(items=frozenset({'기준', '관련'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기준', '관련'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기준'}), confidence=0.4090909090909091, lift=1.115702479338843), OrderedStatistic(items_base=frozenset({'기준'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.115702479338843)])
#
# RelationRecord(items=frozenset({'관련', '뉴스'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '뉴스'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'뉴스'}), confidence=0.4090909090909091, lift=1.115702479338843), OrderedStatistic(items_base=frozenset({'뉴스'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.115702479338843)])
#
# RelationRecord(items=frozenset({'관련', '대표'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '대표'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'대표'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'대표'}), items_add=frozenset({'관련'}), confidence=0.7333333333333333, lift=1.0)])
#
# RelationRecord(items=frozenset({'관련', '때문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '때문'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'때문'}), confidence=0.4090909090909091, lift=1.115702479338843), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.115702479338843)])
#
# RelationRecord(items=frozenset({'관련', '사진'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '사진'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'사진'}), confidence=0.45454545454545453, lift=0.974025974025974), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'관련'}), confidence=0.7142857142857142, lift=0.974025974025974)])
#
# RelationRecord(items=frozenset({'관련', '세계'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '세계'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'세계'}), confidence=0.4090909090909091, lift=1.115702479338843), OrderedStatistic(items_base=frozenset({'세계'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.115702479338843)])
#
# RelationRecord(items=frozenset({'관련', '올해'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '올해'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'올해'}), confidence=0.4090909090909091, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'올해'}), items_add=frozenset({'관련'}), confidence=0.7499999999999999, lift=1.0227272727272727)])
#
# RelationRecord(items=frozenset({'관련', '이날'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '이날'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'이날'}), confidence=0.45454545454545453, lift=1.1363636363636362), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'관련'}), confidence=0.8333333333333333, lift=1.1363636363636362)])
#
# RelationRecord(items=frozenset({'관련', '이사'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '이사'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'이사'}), confidence=0.4090909090909091, lift=1.115702479338843), OrderedStatistic(items_base=frozenset({'이사'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.115702479338843)])
#
# RelationRecord(items=frozenset({'관련', '지난해'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '지난해'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'지난해'}), confidence=0.5, lift=1.0714285714285714), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'관련'}), confidence=0.7857142857142857, lift=1.0714285714285714)])
#
# RelationRecord(items=frozenset({'관련', '최근'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '최근'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'최근'}), confidence=0.4090909090909091, lift=1.0227272727272727), OrderedStatistic(items_base=frozenset({'최근'}), items_add=frozenset({'관련'}), confidence=0.7499999999999999, lift=1.0227272727272727)])
#
# RelationRecord(items=frozenset({'관련', '한국'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '한국'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'한국'}), confidence=0.5454545454545455, lift=1.168831168831169), OrderedStatistic(items_base=frozenset({'한국'}), items_add=frozenset({'관련'}), confidence=0.8571428571428572, lift=1.168831168831169)])
#
# RelationRecord(items=frozenset({'회사', '관련'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'회사', '관련'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'회사'}), confidence=0.4090909090909091, lift=1.2272727272727275), OrderedStatistic(items_base=frozenset({'회사'}), items_add=frozenset({'관련'}), confidence=0.9, lift=1.2272727272727273)])
#
# RelationRecord(items=frozenset({'이사', '그룹'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이사', '그룹'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'그룹'}), items_add=frozenset({'이사'}), confidence=0.9, lift=2.4545454545454546), OrderedStatistic(items_base=frozenset({'이사'}), items_add=frozenset({'그룹'}), confidence=0.8181818181818182, lift=2.454545454545455)])
#
# RelationRecord(items=frozenset({'그룹', '주주'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'그룹', '주주'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'그룹'}), items_add=frozenset({'주주'}), confidence=0.9, lift=2.7), OrderedStatistic(items_base=frozenset({'주주'}), items_add=frozenset({'그룹'}), confidence=0.9, lift=2.7)])
#
# RelationRecord(items=frozenset({'그룹', '주주총회'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'그룹', '주주총회'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'그룹'}), items_add=frozenset({'주주총회'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'주주총회'}), items_add=frozenset({'그룹'}), confidence=1.0, lift=3.0)])
#
# RelationRecord(items=frozenset({'그룹', '총회'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'그룹', '총회'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'그룹'}), items_add=frozenset({'총회'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'총회'}), items_add=frozenset({'그룹'}), confidence=1.0, lift=3.0)])
#
# RelationRecord(items=frozenset({'기자', '기사'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '기사'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'기자'}), confidence=0.7857142857142857, lift=1.1224489795918369), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'기사'}), confidence=0.5238095238095238, lift=1.1224489795918369)])
#
# RelationRecord(items=frozenset({'사진', '기사'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사진', '기사'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'사진'}), confidence=0.6428571428571428, lift=1.3775510204081631), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'기사'}), confidence=0.6428571428571428, lift=1.3775510204081631)])
#
# RelationRecord(items=frozenset({'한국', '기업'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'한국', '기업'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기업'}), items_add=frozenset({'한국'}), confidence=0.6923076923076923, lift=1.4835164835164834), OrderedStatistic(items_base=frozenset({'한국'}), items_add=frozenset({'기업'}), confidence=0.6428571428571428, lift=1.4835164835164834)])
#
# RelationRecord(items=frozenset({'기자', '뉴스'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '뉴스'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'뉴스'}), confidence=0.4761904761904762, lift=1.298701298701299), OrderedStatistic(items_base=frozenset({'뉴스'}), items_add=frozenset({'기자'}), confidence=0.9090909090909091, lift=1.2987012987012987)])
#
# RelationRecord(items=frozenset({'기자', '때문'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '때문'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'때문'}), confidence=0.4285714285714286, lift=1.168831168831169), OrderedStatistic(items_base=frozenset({'때문'}), items_add=frozenset({'기자'}), confidence=0.8181818181818182, lift=1.168831168831169)])
#
# RelationRecord(items=frozenset({'기자', '사진'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '사진'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'사진'}), confidence=0.4761904761904762, lift=1.0204081632653061), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'기자'}), confidence=0.7142857142857142, lift=1.0204081632653061)])
#
# RelationRecord(items=frozenset({'기자', '올해'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '올해'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'올해'}), confidence=0.4761904761904762, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'올해'}), items_add=frozenset({'기자'}), confidence=0.8333333333333333, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'기자', '이날'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '이날'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'이날'}), confidence=0.5238095238095238, lift=1.3095238095238095), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'기자'}), confidence=0.9166666666666665, lift=1.3095238095238093)])
#
# RelationRecord(items=frozenset({'이상', '기자'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이상', '기자'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'이상'}), confidence=0.4285714285714286, lift=1.168831168831169), OrderedStatistic(items_base=frozenset({'이상'}), items_add=frozenset({'기자'}), confidence=0.8181818181818182, lift=1.168831168831169)])
#
# RelationRecord(items=frozenset({'기자', '지난해'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '지난해'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'지난해'}), confidence=0.5714285714285715, lift=1.2244897959183676), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'기자'}), confidence=0.8571428571428572, lift=1.2244897959183676)])
#
# RelationRecord(items=frozenset({'기자', '최근'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '최근'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'최근'}), confidence=0.4285714285714286, lift=1.0714285714285714), OrderedStatistic(items_base=frozenset({'최근'}), items_add=frozenset({'기자'}), confidence=0.7499999999999999, lift=1.0714285714285714)])
#
# RelationRecord(items=frozenset({'기자', '한국'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '한국'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'한국'}), confidence=0.4285714285714286, lift=0.9183673469387755), OrderedStatistic(items_base=frozenset({'한국'}), items_add=frozenset({'기자'}), confidence=0.6428571428571428, lift=0.9183673469387755)])
#
# RelationRecord(items=frozenset({'한국', '대표'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'한국', '대표'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'대표'}), items_add=frozenset({'한국'}), confidence=0.6, lift=1.2857142857142856), OrderedStatistic(items_base=frozenset({'한국'}), items_add=frozenset({'대표'}), confidence=0.6428571428571428, lift=1.2857142857142856)])
#
# RelationRecord(items=frozenset({'이날', '주주'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이날', '주주'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'주주'}), confidence=0.7499999999999999, lift=2.25), OrderedStatistic(items_base=frozenset({'주주'}), items_add=frozenset({'이날'}), confidence=0.9, lift=2.25)])
#
# RelationRecord(items=frozenset({'이사', '주주'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이사', '주주'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'이사'}), items_add=frozenset({'주주'}), confidence=0.8181818181818182, lift=2.454545454545455), OrderedStatistic(items_base=frozenset({'주주'}), items_add=frozenset({'이사'}), confidence=0.9, lift=2.4545454545454546)])
#
# RelationRecord(items=frozenset({'이사', '주주총회'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이사', '주주총회'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'이사'}), items_add=frozenset({'주주총회'}), confidence=0.8181818181818182, lift=2.7272727272727275), OrderedStatistic(items_base=frozenset({'주주총회'}), items_add=frozenset({'이사'}), confidence=1.0, lift=2.7272727272727275)])
#
# RelationRecord(items=frozenset({'이사', '총회'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이사', '총회'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'이사'}), items_add=frozenset({'총회'}), confidence=0.8181818181818182, lift=2.7272727272727275), OrderedStatistic(items_base=frozenset({'총회'}), items_add=frozenset({'이사'}), confidence=1.0, lift=2.7272727272727275)])
#
# RelationRecord(items=frozenset({'주주총회', '주주'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'주주총회', '주주'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'주주'}), items_add=frozenset({'주주총회'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'주주총회'}), items_add=frozenset({'주주'}), confidence=1.0, lift=3.0)])
#
# RelationRecord(items=frozenset({'총회', '주주'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'총회', '주주'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'주주'}), items_add=frozenset({'총회'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'총회'}), items_add=frozenset({'주주'}), confidence=1.0, lift=3.0)])
#
# RelationRecord(items=frozenset({'주주총회', '총회'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'주주총회', '총회'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'주주총회'}), items_add=frozenset({'총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'총회'}), items_add=frozenset({'주주총회'}), confidence=1.0, lift=3.3333333333333335)])
#
# RelationRecord(items=frozenset({'관련', '26일', '26'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '26', '26일'}), confidence=0.43333333333333335, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'관련', '26일'}), confidence=0.7222222222222223, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'관련', '26'}), confidence=0.7222222222222223, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'26', '26일'}), confidence=0.5909090909090909, lift=0.984848484848485), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'관련'}), confidence=0.7222222222222223, lift=0.9848484848484851), OrderedStatistic(items_base=frozenset({'관련', '26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'관련', '26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'26일', '기사', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26', '기사', '26일'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기사', '26일'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'기사', '26'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'26', '26일'}), confidence=0.7142857142857142, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'기사'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'기사', '26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'기사', '26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'기자', '26일', '26'}), support=0.5333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '26', '26일'}), confidence=0.5333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기자', '26일'}), confidence=0.888888888888889, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'기자', '26'}), confidence=0.888888888888889, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'26', '26일'}), confidence=0.761904761904762, lift=1.26984126984127), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'기자'}), confidence=0.888888888888889, lift=1.26984126984127), OrderedStatistic(items_base=frozenset({'기자', '26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'기자', '26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'26일', '대표', '26'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26', '대표', '26일'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'대표', '26일'}), confidence=0.5, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'26', '대표'}), confidence=0.5, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'대표'}), items_add=frozenset({'26', '26일'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'대표'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'대표', '26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'대표', '26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'26일', '사진', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사진', '26', '26일'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'사진', '26일'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'사진', '26'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'26', '26일'}), confidence=0.7142857142857142, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'사진'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'사진', '26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'사진', '26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'26일', '이날', '26'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26', '이날', '26일'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'이날', '26일'}), confidence=0.611111111111111, lift=1.6666666666666665), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'이날', '26'}), confidence=0.611111111111111, lift=1.6666666666666665), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'26', '26일'}), confidence=0.9166666666666665, lift=1.5277777777777777), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'이날'}), confidence=0.611111111111111, lift=1.5277777777777775), OrderedStatistic(items_base=frozenset({'이날', '26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'이날', '26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'26일', '전망', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'전망', '26일', '26'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'전망', '26일'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'전망', '26'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'전망'}), items_add=frozenset({'26', '26일'}), confidence=0.9090909090909091, lift=1.5151515151515151), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'전망'}), confidence=0.5555555555555556, lift=1.5151515151515154), OrderedStatistic(items_base=frozenset({'전망', '26'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'전망', '26일'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'26일', '26', '지난해'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'26', '26일', '지난해'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'26일', '지난해'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'26', '지난해'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'지난해'}), items_add=frozenset({'26', '26일'}), confidence=0.7142857142857142, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'지난해'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'26', '지난해'}), items_add=frozenset({'26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일', '지난해'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# RelationRecord(items=frozenset({'관련', '기사', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '기사', '26'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'관련', '기사'}), confidence=0.5555555555555556, lift=1.1904761904761905), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기사', '26'}), confidence=0.45454545454545453, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'관련', '26'}), confidence=0.7142857142857142, lift=1.648351648351648), OrderedStatistic(items_base=frozenset({'관련', '26'}), items_add=frozenset({'기사'}), confidence=0.7692307692307692, lift=1.6483516483516483), OrderedStatistic(items_base=frozenset({'기사', '26'}), items_add=frozenset({'관련'}), confidence=1.0, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'관련', '기사'}), items_add=frozenset({'26'}), confidence=0.7142857142857142, lift=1.1904761904761905)])
#
# RelationRecord(items=frozenset({'관련', '기자', '26'}), support=0.43333333333333335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '26', '기자'}), confidence=0.43333333333333335, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'관련', '기자'}), confidence=0.7222222222222223, lift=1.2745098039215688), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기자', '26'}), confidence=0.5909090909090909, lift=1.1079545454545456), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'관련', '26'}), confidence=0.6190476190476191, lift=1.4285714285714286), OrderedStatistic(items_base=frozenset({'관련', '26'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.4285714285714286), OrderedStatistic(items_base=frozenset({'기자', '26'}), items_add=frozenset({'관련'}), confidence=0.8125, lift=1.1079545454545456), OrderedStatistic(items_base=frozenset({'관련', '기자'}), items_add=frozenset({'26'}), confidence=0.7647058823529412, lift=1.2745098039215688)])
#
# RelationRecord(items=frozenset({'관련', '이날', '26'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련', '이날', '26'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'관련', '이날'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'이날', '26'}), confidence=0.4090909090909091, lift=1.115702479338843), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'관련', '26'}), confidence=0.7499999999999999, lift=1.7307692307692304), OrderedStatistic(items_base=frozenset({'관련', '26'}), items_add=frozenset({'이날'}), confidence=0.6923076923076923, lift=1.7307692307692306), OrderedStatistic(items_base=frozenset({'이날', '26'}), items_add=frozenset({'관련'}), confidence=0.8181818181818182, lift=1.115702479338843), OrderedStatistic(items_base=frozenset({'관련', '이날'}), items_add=frozenset({'26'}), confidence=0.9, lift=1.5)])
#
# RelationRecord(items=frozenset({'기자', '기사', '26'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '기사', '26'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기자', '기사'}), confidence=0.5555555555555556, lift=1.5151515151515154), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'기자', '26'}), confidence=0.7142857142857142, lift=1.3392857142857142), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'기사', '26'}), confidence=0.4761904761904762, lift=1.4285714285714288), OrderedStatistic(items_base=frozenset({'기사', '26'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.4285714285714286), OrderedStatistic(items_base=frozenset({'기자', '26'}), items_add=frozenset({'기사'}), confidence=0.625, lift=1.3392857142857142), OrderedStatistic(items_base=frozenset({'기자', '기사'}), items_add=frozenset({'26'}), confidence=0.9090909090909091, lift=1.5151515151515151)])
#
# RelationRecord(items=frozenset({'기자', '사진', '26'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '사진', '26'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기자', '사진'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'사진', '26'}), confidence=0.4285714285714286, lift=1.2857142857142858), OrderedStatistic(items_base=frozenset({'사진'}), items_add=frozenset({'기자', '26'}), confidence=0.6428571428571428, lift=1.2053571428571428), OrderedStatistic(items_base=frozenset({'기자', '26'}), items_add=frozenset({'사진'}), confidence=0.5625, lift=1.2053571428571428), OrderedStatistic(items_base=frozenset({'사진', '26'}), items_add=frozenset({'기자'}), confidence=0.9, lift=1.2857142857142858), OrderedStatistic(items_base=frozenset({'기자', '사진'}), items_add=frozenset({'26'}), confidence=0.9, lift=1.5)])
#
# RelationRecord(items=frozenset({'기자', '이날', '26'}), support=0.36666666666666664, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기자', '이날', '26'}), confidence=0.36666666666666664, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기자', '이날'}), confidence=0.611111111111111, lift=1.6666666666666665), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'이날', '26'}), confidence=0.5238095238095238, lift=1.4285714285714288), OrderedStatistic(items_base=frozenset({'이날'}), items_add=frozenset({'기자', '26'}), confidence=0.9166666666666665, lift=1.7187499999999998), OrderedStatistic(items_base=frozenset({'기자', '26'}), items_add=frozenset({'이날'}), confidence=0.6875, lift=1.71875), OrderedStatistic(items_base=frozenset({'이날', '26'}), items_add=frozenset({'기자'}), confidence=1.0, lift=1.4285714285714286), OrderedStatistic(items_base=frozenset({'기자', '이날'}), items_add=frozenset({'26'}), confidence=1.0, lift=1.6666666666666667)])
#
# ...
#
# RelationRecord(items=frozenset({'이사', '주주총회', '총회', '주주'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이사', '주주총회', '총회', '주주'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'이사'}), items_add=frozenset({'주주총회', '총회', '주주'}), confidence=0.8181818181818182, lift=2.7272727272727275), OrderedStatistic(items_base=frozenset({'주주'}), items_add=frozenset({'이사', '주주총회', '총회'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'주주총회'}), items_add=frozenset({'이사', '총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'총회'}), items_add=frozenset({'이사', '주주총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주'}), items_add=frozenset({'주주총회', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주총회'}), items_add=frozenset({'총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '총회'}), items_add=frozenset({'주주총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'주주총회', '주주'}), items_add=frozenset({'이사', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'총회', '주주'}), items_add=frozenset({'이사', '주주총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'주주총회', '총회'}), items_add=frozenset({'이사', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주총회', '주주'}), items_add=frozenset({'총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '총회', '주주'}), items_add=frozenset({'주주총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주총회', '총회'}), items_add=frozenset({'주주'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'주주총회', '총회', '주주'}), items_add=frozenset({'이사'}), confidence=1.0, lift=2.7272727272727275)])
#
# RelationRecord(items=frozenset({'26일', '26', '기사', '기자', '관련'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'기사', '26일', '기자', '관련', '26'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'26'}), items_add=frozenset({'기자', '기사', '관련', '26일'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'26일'}), items_add=frozenset({'기자', '기사', '관련', '26'}), confidence=0.5555555555555556, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'관련'}), items_add=frozenset({'기자', '26', '기사', '26일'}), confidence=0.45454545454545453, lift=1.3636363636363638), OrderedStatistic(items_base=frozenset({'기사'}), items_add=frozenset({'기자', '26', '관련', '26일'}), confidence=0.7142857142857142, lift=1.648351648351648), OrderedStatistic(items_base=frozenset({'기자'}), items_add=frozenset({'관련', '26', '기사', '26일'}), confidence=0.4761904761904762, lift=1.4285714285714288), OrderedStatistic(items_base=frozenset({'26일', '26'}), items_add=frozenset({'기자', '기사', '관련'}), confidence=0.5555555555555556, lift=1.5151515151515154), OrderedStatistic(items_base=frozenset({'관련', '26'}), items_add=frozenset({'기자', '기사', '26일'}), confidence=0.7692307692307692, lift=2.3076923076923075), OrderedStatistic(items_base=frozenset({'기사', '26'}), items_add=frozenset({'기자', '관련', '26일'}), confidence=1.0, lift=2.3076923076923075), OrderedStatistic(items_base=frozenset({'기자', '26'}), items_add=frozenset({'관련', '기사', '26일'}), confidence=0.625, lift=1.875), OrderedStatistic(items_base=frozenset({'관련', '26일'}), items_add=frozenset({'기자', '기사', '26'}), confidence=0.7692307692307692, lift=2.3076923076923075), OrderedStatistic(items_base=frozenset({'기사', '26일'}), items_add=frozenset({'기자', '관련', '26'}), confidence=1.0, lift=2.3076923076923075), OrderedStatistic(items_base=frozenset({'기자', '26일'}), items_add=frozenset({'관련', '기사', '26'}), confidence=0.625, lift=1.875), OrderedStatistic(items_base=frozenset({'관련', '기사'}), items_add=frozenset({'기자', '26', '26일'}), confidence=0.7142857142857142, lift=1.3392857142857142), OrderedStatistic(items_base=frozenset({'관련', '기자'}), items_add=frozenset({'26', '기사', '26일'}), confidence=0.5882352941176471, lift=1.7647058823529413), OrderedStatistic(items_base=frozenset({'기자', '기사'}), items_add=frozenset({'관련', '26', '26일'}), confidence=0.9090909090909091, lift=2.097902097902098), OrderedStatistic(items_base=frozenset({'관련', '26일', '26'}), items_add=frozenset({'기자', '기사'}), confidence=0.7692307692307692, lift=2.097902097902098), OrderedStatistic(items_base=frozenset({'26일', '기사', '26'}), items_add=frozenset({'기자', '관련'}), confidence=1.0, lift=1.7647058823529411), OrderedStatistic(items_base=frozenset({'기자', '26일', '26'}), items_add=frozenset({'관련', '기사'}), confidence=0.625, lift=1.3392857142857142), OrderedStatistic(items_base=frozenset({'관련', '기사', '26'}), items_add=frozenset({'기자', '26일'}), confidence=1.0, lift=1.875), OrderedStatistic(items_base=frozenset({'관련', '기자', '26'}), items_add=frozen
set({'기자', '이날'}), confidence=0.6923076923076923, lift=1.8881118881118881), OrderedStatistic(items_base=frozenset({'기자', '26일', '26'}), items_add=frozenset({'관련', '이날'}), confidence=0.5625, lift=1.6875), OrderedStatistic(items_base=frozenset({'26일', '이날', '26'}), items_add=frozenset({'기자', '관련'}), confidence=0.8181818181818182, lift=1.4438502673796794), OrderedStatistic(items_base=frozenset({'관련', '기자', '26'}), items_add=frozenset({'이날', '26일'}), confidence=0.6923076923076923, lift=1.8881118881118881), OrderedStatistic(items_base=frozenset({'관련', '이날', '26'}), items_add=frozenset({'기자', '26일'}), confidence=1.0, lift=1.875), OrderedStatistic(items_base=frozenset({'기자', '이날', '26'}), items_add=frozenset({'관련', '26일'}), confidence=0.8181818181818182, lift=1.8881118881118881), OrderedStatistic(items_base=frozenset({'관련', '기자', '26일'}), items_add=frozenset({'이날', '26'}), confidence=0.6923076923076923, lift=1.8881118881118881), OrderedStatistic(items_base=frozenset({'관련', '이날', '26일'}), items_add=frozenset({'기자', '26'}), confidence=1.0, lift=1.875), OrderedStatistic(items_base=frozenset({'기자', '이날', '26일'}), items_add=frozenset({'관련', '26'}), confidence=0.8181818181818182, lift=1.8881118881118881), OrderedStatistic(items_base=frozenset({'관련', '이날', '기자'}), items_add=frozenset({'26', '26일'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'관련', '26일', '기자', '26'}), items_add=frozenset({'이날'}), confidence=0.6923076923076923, lift=1.7307692307692306), OrderedStatistic(items_base=frozenset({'관련', ' ...
#
# RelationRecord(items=frozenset({'이사', '그룹', '주주총회', '총회', '주주'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'이사', '주주', '그룹', '주주총회', '총회'}), confidence=0.3, lift=1.0), OrderedStatistic(items_base=frozenset({'그룹'}), items_add=frozenset({'이사', '주주총회', '총회', '주주'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'이사'}), items_add=frozenset({'그룹', '주주총회', '총회', '주주'}), confidence=0.8181818181818182, lift=2.7272727272727275), OrderedStatistic(items_base=frozenset({'주주'}), items_add=frozenset({'이사', '그룹', '총회', '주주총회'}), confidence=0.9, lift=3.0), OrderedStatistic(items_base=frozenset({'주주총회'}), items_add=frozenset({'이사', '그룹', '총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'총회'}), items_add=frozenset({'이사', '그룹', '주주', '주주총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '그룹'}), items_add=frozenset({'주주총회', '총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'그룹', '주주'}), items_add=frozenset({'이사', '주주총회', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'그룹', '주주총회'}), items_add=frozenset({'이사', '총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'그룹', '총회'}), items_add=frozenset({'이사', '주주총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주'}), items_add=frozenset({'그룹', '주주총회', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주총회'}), items_add=frozenset({'그룹', '총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '총회'}), items_add=frozenset({'그룹', '주주총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'주주총회', '주주'}), items_add=frozenset({'이사', '그룹', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'총회', '주주'}), items_add=frozenset({'이사', '그룹', '주주총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'주주총회', '총회'}), items_add=frozenset({'이사', '그룹', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '그룹', '주주'}), items_add=frozenset({'주주총회', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '그룹', '주주총회'}), items_add=frozenset({'총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '그룹', '총회'}), items_add=frozenset({'주주총회', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'그룹', '주주총회', '주주'}), items_add=frozenset({'이사', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'그룹', '총회', '주주'}), items_add=frozenset({'이사', '주주총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'그룹', '주주총회', '총회'}), items_add=frozenset({'이사', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주총회', '주주'}), items_add=frozenset({'그룹', '총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '총회', '주주'}), items_add=frozenset({'그룹', '주주총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '주주총회', '총회'}), items_add=frozenset({'그룹', '주주'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'주주총회', '총회', '주주'}), items_add=frozenset({'이사', '그룹'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '그룹', '주주총회', '주주'}), items_add=frozenset({'총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '그룹', '총회', '주주'}), items_add=frozenset({'주주총회'}), confidence=1.0, lift=3.3333333333333335), OrderedStatistic(items_base=frozenset({'이사', '그룹', '주주총회', '총회'}),  ...

# %%
result[3]
# Out:
# RelationRecord(items=frozenset({'경우'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'경우'}), confidence=0.3, lift=1.0)])

# %%
import pandas as pd 
# 위의 결과를 데이터프레임으로 
result_df = pd.DataFrame(None, 
                         columns = ['lhs', 'rhs', 'support', 'confidence', 'lift'])
index = 0
for row in result:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        lhs = ','.join(x for x in item[0]) # 데이터프레임에 담을 때에는 출력할 때처럼 []안에 담을 필요없다.
        rhs = ','.join(x.strip() for x in item[1])
        confidence = item[2]
        lift = item[3]
        if lift != 1:
            result_df.loc[index] = [lhs, rhs, support, confidence, lift]
            index += 1 
result_df

# %%
pd.options.display.max_rows = 644
result_df
# Out:
#                lhs            rhs   support  confidence      lift
# 0               26            26일  0.600000    1.000000  1.666667
# 1              26일             26  0.600000    1.000000  1.666667
# 2               26             관련  0.433333    0.722222  0.984848
# 3               관련             26  0.433333    0.590909  0.984848
# 4               26             기사  0.333333    0.555556  1.190476
# 5               기사             26  0.333333    0.714286  1.190476
# 6               26             기자  0.533333    0.888889  1.269841
# 7               기자             26  0.533333    0.761905  1.269841
# 8               26             사진  0.333333    0.555556  1.190476
# 9               사진             26  0.333333    0.714286  1.190476
# 10              26             이날  0.366667    0.611111  1.527778
# 11              이날             26  0.366667    0.916667  1.527778
# 12              26             전망  0.333333    0.555556  1.515152
# 13              전망             26  0.333333    0.909091  1.515152
# 14              26            지난해  0.333333    0.555556  1.190476
# 15             지난해             26  0.333333    0.714286  1.190476
# 16             26일             관련  0.433333    0.722222  0.984848
# 17              관련            26일  0.433333    0.590909  0.984848
# 18             26일             기사  0.333333    0.555556  1.190476
# 19              기사            26일  0.333333    0.714286  1.190476
# 20             26일             기자  0.533333    0.888889  1.269841
# 21              기자            26일  0.533333    0.761905  1.269841
# 22             26일             사진  0.333333    0.555556  1.190476
# 23              사진            26일  0.333333    0.714286  1.190476
# 24             26일             이날  0.366667    0.611111  1.527778
# 25              이날            26일  0.366667    0.916667  1.527778
# 26             26일             전망  0.333333    0.555556  1.515152
# 27              전망            26일  0.333333    0.909091  1.515152
# 28             26일            지난해  0.333333    0.555556  1.190476
# 29             지난해            26일  0.333333    0.714286  1.190476
# 30              관련             그룹  0.300000    0.409091  1.227273
# 31              그룹             관련  0.300000    0.900000  1.227273
# 32              관련             기사  0.466667    0.636364  1.363636
# 33              기사             관련  0.466667    1.000000  1.363636
# 34              관련             기업  0.333333    0.454545  1.048951
# 35              기업             관련  0.333333    0.769231  1.048951
# 36              관련             기자  0.566667    0.772727  1.103896
# 37              기자             관련  0.566667    0.809524  1.103896
# 38              관련             기준  0.300000    0.409091  1.115702
# 39              기준             관련  0.300000    0.818182  1.115702
# 40              관련             뉴스  0.300000    0.409091  1.115702
# 41              뉴스             관련  0.300000    0.818182  1.115702
# 42              관련             때문  0.300000    0.409091  1.115702
# 43              때문             관련  0.300000    0.818182  1.115702
# 44              관련             사진  0.333333    0.454545  0.974026
# 45              사진             관련  0.333333    0.714286  0.974026
# 46              관련             세계  0.300000    0.409091  1.115702
# 47              세계             관련  0.300000    0.818182  1.115702
# 48              관련             올해  0.300000    0.409091  1.022727
# 49              올해             관련  0.300000    0.750000  1.022727
# 50              관련             이날  0.333333    0.454545  1.136364
# 51              이날             관련  0.333333    0.833333  1.136364
# 52              관련             이사  0.300000    0.409091  1.115702
# 53              이사             관련  0.300000    0.818182  1.115702
# 54              관련            지난해  0.366667    0.500000  1.071429
# 55             지난해             관련  0.366667    0.785714  1.071429
# 625          이사,총회     그룹,주주총회,주주  0.300000    1.000000  3.333333
# 626        주주총회,주주       이사,그룹,총회  0.300000    1.000000  3.333333
# 627          총회,주주     이사,그룹,주주총회  0.300000    1.000000  3.333333
# 628        주주총회,총회       이사,그룹,주주  0.300000    1.000000  3.333333
# 629       이사,그룹,주주        주주총회,총회  0.300000    1.000000  3.333333
# 630     이사,그룹,주주총회          총회,주주  0.300000    1.000000  3.333333
# 631       이사,그룹,총회        주주총회,주주  0.300000    1.000000  3.333333
# 632     그룹,주주총회,주주          이사,총회  0.300000    1.000000  3.333333
# 633       그룹,총회,주주        이사,주주총회  0.300000    1.000000  3.333333
# 634     그룹,주주총회,총회          이사,주주  0.300000    1.000000  3.333333
# 635     이사,주주총회,주주          그룹,총회  0.300000    1.000000  3.333333
# 636       이사,총회,주주        그룹,주주총회  0.300000    1.000000  3.333333
# 637     이사,주주총회,총회          그룹,주주  0.300000    1.000000  3.333333
# 638     주주총회,총회,주주          이사,그룹  0.300000    1.000000  3.333333
# 639  이사,그룹,주주총회,주주             총회  0.300000    1.000000  3.333333
# 640    이사,그룹,총회,주주           주주총회  0.300000    1.000000  3.333333
# 641  이사,그룹,주주총회,총회             주주  0.300000    1.000000  3.000000
# 642  그룹,주주총회,총회,주주             이사  0.300000    1.000000  2.727273
# 643  이사,주주총회,총회,주주             그룹  0.300000    1.000000  3.000000

# %%
result_df.loc[(result_df.lhs.str.contains('기자')) & result_df.rhs.str.contains('한국')].sort_values(by=['lift'], 
                                                                                                 ascending=False)
# Out:
#        lhs    rhs  support  confidence      lift
# 267  관련,기자     한국      0.3    0.529412  1.134454
# 265     기자  관련,한국      0.3    0.428571  1.071429
# 92      기자     한국      0.3    0.428571  0.918367

# %% [markdown]
# **연습하기**

# %%
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Kkma

# %%
kkma = Kkma()
test_url = "https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%BD%94%EB%A1%9C%EB%82%98"
test_response = requests.get(test_url)
test_response
test_soup = BeautifulSoup(test_response.content, 'html.parser')
text_content = test_soup.select('.f_eb')

news = []
for text in text_content:
    news.append(list(filter(lambda word : len(word)>1 and word!='기자',
                           kkma.nouns(text.text))))

# %%
news_nouns = set()
news
for new in news:
    for n in new:
        news_nouns.add(n)
        
print('코로나 기사에 나오는 단어들: ', news_nouns)
print(len(news_nouns))
# Out:
# 코로나 기사에 나오는 단어들:  {'캠페인', '감염증', '유행', '입원', '유의사항', '일상', '100', '메드', '우리', '포스팅', '질병관리청', '예방', '요즘', '대기', '지역콜센터', '12', '병원', '센터', '모하', '동반', '미취업자', '사망자', '강도', '안내', '대상', '집회', '최대', '데이터', '호흡기증상', '120', '상담', '특징', '주최', '4월', '의료기관', '인후통', '자치구', '과테말라', '바이러스', '지급', '200만', '-19', '자료', '2주', '관심', '뉴시스', '최저가', '정리', '뉴스', '지도', '안채원', '효과', '브리핑', '광화', '광고주의', '스감염증-19', '001', '지역국번', '중국', '20210423102842628', '뮤직', '존스
ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'19'}), confidence=0.24324324324324326, lift=1.0)]),
#  RelationRecord(items=frozenset({'코로나'}), support=0.5405405405405406, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나'}), confidence=0.5405405405405406, lift=1.0)]),
#  RelationRecord(items=frozenset({'코로나19'}), support=0.24324324324324326, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나19'}), confidence=0.24324324324324326, lift=1.0)]),
#  RelationRecord(items=frozenset({'코로나', '19'}), support=0.24324324324324326, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'19', '코로나'}), confidence=0.24324324324324326, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'코로나'}), confidence=1.0, lift=1.8499999999999999), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'19'}), confidence=0.45, lift=1.8499999999999999)]),
#  RelationRecord(items=frozenset({'코로나19', '19'}), support=0.24324324324324326, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나19', '19'}), confidence=0.24324324324324326, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'코로나19'}), confidence=1.0, lift=4.111111111111111), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'19'}), confidence=1.0, lift=4.111111111111111)]),
#  RelationRecord(items=frozenset({'코로나19', '코로나'}), support=0.24324324324324326, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'코로나19', '코로나'}), confidence=0.24324324324324326, lift=1.0), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'코로나19'}), confidence=0.45, lift=1.8499999999999999), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'코로나'}), confidence=1.0, lift=1.8499999999999999)]),
#  RelationRecord(items=frozenset({'코로나', '19', '코로나19'}), support=0.24324324324324326, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'19', '코로나', '코로나19'}), confidence=0.24324324324324326, lift=1.0), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'코로나19', '코로나'}), confidence=1.0, lift=4.111111111111111), OrderedStatistic(items_base=frozenset({'코로나'}), items_add=frozenset({'코로나19', '19'}), confidence=0.45, lift=1.8499999999999999), OrderedStatistic(items_base=frozenset({'코로나19'}), items_add=frozenset({'19', '코로나'}), confidence=1.0, lift=4.111111111111111), OrderedStatistic(items_base=frozenset({'코로나', '19'}), items_add=frozenset({'코로나19'}), confidence=1.0, lift=4.111111111111111), OrderedStatistic(items_base=frozenset({'코로나19', '19'}), items_add=frozenset({'코로나'}), confidence=1.0, lift=1.8499999999999999), OrderedStatistic(items_base=frozenset({'코로나19', '코로나'}), items_add=frozenset({'19'}), confidence=1.0, lift=4.111111111111111)])]

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(news,
                 window=5,
                 min_count=2,
                 workers=-1)

# %%
model.wv.most_similar("코로나")
# Out:
# [('120', 0.21883949637413025),
#  ('호흡기', 0.21617144346237183),
#  ('서울', 0.19543619453907013),
#  ('앵커', 0.17216654121875763),
#  ('기준', 0.1691875159740448),
#  ('정부', 0.15161022543907166),
#  ('코로나바이러스', 0.14176101982593536),
#  ('보건소', 0.1403549313545227),
#  ('접종', 0.13964074850082397),
#  ('마스크', 0.1233743280172348)]
